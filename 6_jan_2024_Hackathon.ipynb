# %%
__ = 0

# %%
print(__)
# Out:
# 0

# %%
Foo = 1

# %%
print(Foo)
# Out:
# 1

# %%
My_str_1 = 5
My_str_1
# Out:
# 5

# %%
1st_str = 3
1st_str
# Out:
#   Cell In[7], line 1
#     1st_str = 3
#      ^
# SyntaxError: invalid syntax

# %%
A,b,c = 100,200,300

# %%
A,b,c
# Out:
# (100, 200, 300)

# %%
Abc = 100,000,000

# %%
Abc
# Out:
# (100, 0, 0)

# %%
A_b_c = 100,000,000

# %%
A_b_c
# Out:
# (100, 0, 0)

# %%
A b c = 100 200 300
# Out:
#   Cell In[17], line 1
#     A b c = 100 200 300
#       ^
# SyntaxError: invalid syntax

# %%
tup = (1)
type(tup)
# Out:
# int

# %%
acos(0.1512195122)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 acos(0.1512195122)
#
# NameError: name 'acos' is not defined

# %% [markdown]
# # acos(0.1512195122) =
#
# 81.3023943 degree

# %%
import numpy as np

# %%
a = [[-8,-6]]
b = [[-4,5]]
np.dot(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 a = [[-8,-6]]
#       2 b = [[-4,5]]
# ----> 3 np.dot(a,b)
#
# ValueError: shapes (1,2) and (1,2) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
np.matmul(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 np.matmul(a,b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1 is different from 2)

# %%
tup = [1, 2, 3]
tup
# Out:
# [1, 2, 3]

# %%
type(tup)
# Out:
# list

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_links = pd.read_csv('Links.csv')
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movies = pd.read_csv('movies.csv')
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings = pd.read_csv('ratings.csv')
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_tags = pd.read_csv('tags.csv')
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %% [markdown]
# # Download the data from the above link. How many ".csv" files are available in the dataset?
#
#
# 1
#
# 2
#
# 3
#
# 4 ✅

# %%
df_movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# # What is the shape of "movies.csv"?
#
# (3683, 4)
#
# (9742, 3)✅
#
# (100836, 4)
#
# None of the above

# %%
df_ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# # What is the shape of "ratings.csv"?
#
# (3683, 4)
#
# (9742, 3)
#
# (100836, 4)✅
#
# None of the above

# %% [markdown]
# # How many unique "userId" are available in "ratings.csv"?
#
# 610

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_ratings.userId.nunique()
# Out:
# 610

# %% [markdown]
# # Which movie has recieved maximum number of user ratings?
#
# Matrix
#
# Pulp Fiction
#
# Forrest Gump
#
# Shawshank Redemption✅

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
gdf = df_ratings.groupby('rating')
gdf.head()
# Out:
#      userId  movieId  rating   timestamp
# 0         1        1     4.0   964982703
# 1         1        3     4.0   964981247
# 2         1        6     4.0   964982224
# 3         1       47     5.0   964983815
# 4         1       50     5.0   964982931
# 5         1       70     3.0   964982400
# 6         1      101     5.0   964980868
# 7         1      110     4.0   964982176
# 8         1      151     5.0   964984041
# 9         1      157     5.0   964984100
# 12        1      223     3.0   964980985
# 14        1      235     4.0   964980908
# 16        1      296     3.0   964982967
# 17        1      316     3.0   964982310
# 23        1      423     3.0   964982363
# 76        1     1219     2.0   964983393
# 143       1     2253     2.0   964981775
# 148       1     2338     2.0   964983546
# 152       1     2389     2.0   964983094
# 170       1     2617     2.0   964982588
# 205       1     3176     1.0   964983504
# 234       2     1704     4.5  1445715228
# ...

# %%
gdf.movieId.value_counts(ascending=True)
# Out:
# rating  movieId
# 0.5     1            1
#         152063       1
#         151745       1
#         151687       1
#         151315       1
#                   ...
# 5.0     260        104
#         2571       109
#         356        116
#         296        123
#         318        153
# Name: count, Length: 30417, dtype: int64

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies.loc[(df_movies.movieId == 318)]
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# #
# Select all the correct tags submitted by users to "Matrix, The (1999)" movie?
#
# alternate universe
#
# karate
#
# philosophy
#
# post apocalyptic

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df_movies.loc[(df_movies.title == "Matrix, The (1999)")]
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
df_tags.loc[(df_tags.movieId == 2571)]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %% [markdown]
# # Select all the correct tags submitted by users to "Matrix, The (1999)" movie?
#
# alternate universe ✅
#
# karate
#
# philosophy ✅
#
# post apocalyptic ✅

# %% [markdown]
# # What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movies[(df_movies.title == "Terminator 2: Judgment Day (1991)")]
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
d = df_ratings[(df_ratings.movieId == 589)]

# %%
d.rating.mean()
# Out:
# 3.970982142857143

# %% [markdown]
# # Answer 3.970982142857143

# %%
gddf = df_ratings.groupby('movieId')
m = gddf.rating.value_counts()
m
# Out:
# movieId  rating
# 1        4.0       82
#          5.0       47
#          3.0       34
#          4.5       18
#          3.5       18
#                    ..
# 193581   4.0        1
# 193583   3.5        1
# 193585   3.5        1
# 193587   3.5        1
# 193609   4.0        1
# Name: count, Length: 30417, dtype: int64

# %%
type(m)
# Out:
# pandas.core.series.Series

# %%
m[2480:2500]
# Out:
# movieId  rating
# 588      4.5       11
#          2.0       10
#          2.5        2
#          1.0        1
#          0.5        1
# 589      4.0       67
#          5.0       64
#          3.0       37
#          3.5       23
#          4.5       19
#          2.5        6
#          2.0        3
#          0.5        3
#          1.0        2
# 590      4.0       60
#          3.0       35
#          5.0       35
#          3.5       14
#          2.0        9
#          4.5        8
# Name: count, dtype: int64

# %%
4.0+5.0+3.0+3.5+4.5+2.5+2.0+0.5+1.0
# Out:
# 26.0

# %%
26.0/9
# Out:
# 2.888888888888889

# %% [markdown]
# # Answer 2.8888888888

# %%
gddf.loc[(gddf.movieId == 589)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 gddf.loc[(gddf.movieId == 589)]
#
# File e:\python\lib\site-packages\pandas\core\groupby\groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %% [markdown]
# # How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?
#
# Normal Distribution
#
# Left Skewed Distribution
#
# Right Skewed Distribution
#
# Uniform Distribution

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies[(df_movies.title == "Fight Club (1999)")]
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ddd  = df_ratings[(df_ratings.movieId == 2959)]

# %%
ddd.rating
# Out:
# 192      5.0
# 458      2.0
# 1134     0.5
# 1479     2.5
# 1635     3.5
#         ...
# 95893    5.0
# 96788    4.0
# 97835    5.0
# 99107    5.0
# 99699    5.0
# Name: rating, Length: 218, dtype: float64

# %%
d = pd.DataFrame(ddd.rating)

# %%
d.head()
# Out:
#       rating
# 192      5.0
# 458      2.0
# 1134     0.5
# 1479     2.5
# 1635     3.5

# %%
sns.kdeplot(data = d, x = 'rating')
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# # Left Skewed

# %% [markdown]
# # 🟢 IMPORTANT NOTE 1 🟢
# Now that you have a good enough understanding of the given data, apply the "Mandatory Operation" given below before solving any of the following questions.
#
# Mandatory Operations:
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).
#
# Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
f = df_ratings.groupby('movieId')

# %%
ff = f.agg({'rating':['count','mean']})
ff
# Out:
#         rating
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 4            7  2.357143
# 5           49  3.071429
# ...        ...       ...
# 193581       1  4.000000
# 193583       1  3.500000
# 193585       1  3.500000
# 193587       1  3.500000
# 193609       1  4.000000
#
# [9724 rows x 2 columns]

# %%
ff = ff.reset_index()

# %%
ff
# Out:
#      movieId rating
#               count      mean
# 0          1    215  3.920930
# 1          2    110  3.431818
# 2          3     52  3.259615
# 3          4      7  2.357143
# 4          5     49  3.071429
# ...      ...    ...       ...
# 9719  193581      1  4.000000
# 9720  193583      1  3.500000
# 9721  193585      1  3.500000
# 9722  193587      1  3.500000
# 9723  193609      1  4.000000
#
# [9724 rows x 3 columns]

# %%
ff.columns = [''.join(col) for col in ff.columns.values]
ff
# Out:
#       movieId  ratingcount  ratingmean
# 0           1          215    3.920930
# 1           2          110    3.431818
# 2           3           52    3.259615
# 3           4            7    2.357143
# 4           5           49    3.071429
# ...       ...          ...         ...
# 9719   193581            1    4.000000
# 9720   193583            1    3.500000
# 9721   193585            1    3.500000
# 9722   193587            1    3.500000
# 9723   193609            1    4.000000
#
# [9724 rows x 3 columns]

# %%
<!-- ##### # In second DataFrame is MultiIndex, so is possible remove first or second level, depends of data:

# data = t1_df.join(t2_df.droplevel(0), on='race_id')
# data = t1_df.join(t2_df.droplevel(1), on='race_id')
# Or convert it to column:

# data = t1_df.join(t2_df.reset_index(0), on='race_id') -->
# <!-- data = ff.join(df_movies.reset_index(0), on='movieId') -->
# Out:
#   Cell In[172], line 1
#     <!-- ##### # In second DataFrame is MultiIndex, so is possible remove first or second level, depends of data:
#     ^
# SyntaxError: invalid syntax

# %%
type(ff)
# Out:
# pandas.core.frame.DataFrame

# %%
ff.columns
# Out:
# Index(['movieId', 'ratingcount', 'ratingmean'], dtype='object')

# %%
df_movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_note1 = pd.merge(ff , df_movies , on = 'movieId' , how = 'inner')

# %%
df_note1
# Out:
#       movieId  ratingcount  ratingmean  \
# 0           1          215    3.920930
# 1           2          110    3.431818
# 2           3           52    3.259615
# 3           4            7    2.357143
# 4           5           49    3.071429
# ...       ...          ...         ...
# 9719   193581            1    4.000000
# 9720   193583            1    3.500000
# 9721   193585            1    3.500000
# 9722   193587            1    3.500000
# 9723   193609            1    4.000000
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# 2                       Grumpier Old Men (1995)
# 3                      Waiting to Exhale (1995)
# 4            Father of the Bride Part II (1995)
# ...                                         ...
# 9719  Black Butler: Book of the Atlantic (2017)
# 9720               No Game No Life: Zero (2017)
# 9721                               Flint (2017)
# ...

# %%
fdf = df_note1[(df_note1.ratingcount > 50)]

# %%
fdf
# Out:
#       movieId  ratingcount  ratingmean                             title  \
# 0           1          215    3.920930                  Toy Story (1995)
# 1           2          110    3.431818                    Jumanji (1995)
# 2           3           52    3.259615           Grumpier Old Men (1995)
# 5           6          102    3.946078                       Heat (1995)
# 6           7           54    3.185185                    Sabrina (1995)
# ...       ...          ...         ...                               ...
# 8287   106782           54    3.916667   Wolf of Wall Street, The (2013)
# 8354   109374           52    3.778846  Grand Budapest Hotel, The (2014)
# 8358   109487           73    3.993151               Interstellar (2014)
# 8457   112852           59    4.050847    Guardians of the Galaxy (2014)
# 8673   122904           54    3.833333                   Deadpool (2016)
#
#                                            genres
# ...

# %% [markdown]
# # Which movie is the most popular based on  average user ratings?
#
# Answer this question only after applying the above mentioned "Mandatory Operration".
#
# Godfather, The (1972)
#
# Shawshank Redemption, The (1994)✅
#
# Jumanji (1995)
#
# Wolf of Wall Street, The (2013)

# %%
fdf.sort_values(by = 'ratingmean').tail()
# Out:
#       movieId  ratingcount  ratingmean  \
# 602       750           97    4.268041
# 974      1276           57    4.271930
# 2224     2959          218    4.272936
# 659       858          192    4.289062
# 277       318          317    4.429022
#
#                                                   title  \
# 602   Dr. Strangelove or: How I Learned to Stop Worr...
# 974                               Cool Hand Luke (1967)
# 2224                                  Fight Club (1999)
# 659                               Godfather, The (1972)
# 277                    Shawshank Redemption, The (1994)
#
#                            genres
# 602                    Comedy|War
# 974                         Drama
# 2224  Action|Crime|Drama|Thriller
# 659                   Crime|Drama
# 277                   Crime|Drama

# %% [markdown]
# # Select all the correct options which comes under top 5 popular movies based on number of user ratings.
#
# Answer this question only after applying the above mentioned "Mandatory Operration".
#
# Pulp Fiction (1994)✅
#
# Bad Boys (1995)
#
# Silence of the Lambs, The (1991)✅
#
# Matrix, The (1999)✅

# %%
fdf.sort_values(by = 'ratingcount').tail()
# Out:
#       movieId  ratingcount  ratingmean                             title  \
# 1938     2571          278    4.192446                Matrix, The (1999)
# 510       593          279    4.161290  Silence of the Lambs, The (1991)
# 257       296          307    4.197068               Pulp Fiction (1994)
# 277       318          317    4.429022  Shawshank Redemption, The (1994)
# 314       356          329    4.164134               Forrest Gump (1994)
#
#                            genres
# 1938       Action|Sci-Fi|Thriller
# 510         Crime|Horror|Thriller
# 257   Comedy|Crime|Drama|Thriller
# 277                   Crime|Drama
# 314      Comedy|Drama|Romance|War

# %% [markdown]
# # Which Sci-Fi movie is "third most popular" based on the number of user ratings?
#
# Answer this question only after applying the above mentioned "Mandatory Operration".
#
# Deadpool (2016)
#
# Terminator 2: Judgment Day (1991)
#
# X-Men: The Last Stand (2006)
#
# Jurassic Park (1993)

# %%
fdf.head()
# Out:
#    movieId  ratingcount  ratingmean                    title  \
# 0        1          215    3.920930         Toy Story (1995)
# 1        2          110    3.431818           Jumanji (1995)
# 2        3           52    3.259615  Grumpier Old Men (1995)
# 5        6          102    3.946078              Heat (1995)
# 6        7           54    3.185185           Sabrina (1995)
#
#                                         genres Sci-Fi
# 0  Adventure|Animation|Children|Comedy|Fantasy    NaN
# 1                   Adventure|Children|Fantasy    NaN
# 2                               Comedy|Romance    NaN
# 5                        Action|Crime|Thriller    NaN
# 6                               Comedy|Romance    NaN

# %%
fdf.genres.str.split('|')
# Out:
# 0       [Adventure, Animation, Children, Comedy, Fantasy]
# 1                          [Adventure, Children, Fantasy]
# 2                                       [Comedy, Romance]
# 5                               [Action, Crime, Thriller]
# 6                                       [Comedy, Romance]
#                               ...
# 8287                               [Comedy, Crime, Drama]
# 8354                                      [Comedy, Drama]
# 8358                                       [Sci-Fi, IMAX]
# 8457                          [Action, Adventure, Sci-Fi]
# 8673                  [Action, Adventure, Comedy, Sci-Fi]
# Name: genres, Length: 436, dtype: object

# %%
l = []
for i in fdf.genres.str.split("|"):
    for j in [i]:
        if "Sci-Fi" in j:
            l.append("Sci-Fi")
        else:
            l.append(np.nan)

# %%
fdf['Sci-Fi'] = l
fdf[fdf['Sci-Fi'] == 'Sci-Fi'].sort_values(by='ratingcount').tail(3)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_7480\735211875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdf['Sci-Fi'] = l
#       movieId  ratingcount  ratingmean  \
# 418       480          238    3.750000
# 224       260          251    4.231076
# 1938     2571          278    4.192446
#
#                                           title  \
# 418                        Jurassic Park (1993)
# 224   Star Wars: Episode IV - A New Hope (1977)
# 1938                         Matrix, The (1999)
#
#                                 genres  Sci-Fi
# 418   Action|Adventure|Sci-Fi|Thriller  Sci-Fi
# 224            Action|Adventure|Sci-Fi  Sci-Fi
# 1938            Action|Sci-Fi|Thriller  Sci-Fi

# %%
if 'Sci-Fi' in fdf.genres.str.split('|')

# %%
l = []
for i in fdf.genres.str.split('|'):
    if i == 'Sci-Fi':
        l.append(i)

l
        # fdf.Sci_fi = i
    # else:
    #     np.nan
# Out:
# []

# %%
fdf
# Out:
#       movieId  ratingcount  ratingmean                             title  \
# 0           1          215    3.920930                  Toy Story (1995)
# 1           2          110    3.431818                    Jumanji (1995)
# 2           3           52    3.259615           Grumpier Old Men (1995)
# 5           6          102    3.946078                       Heat (1995)
# 6           7           54    3.185185                    Sabrina (1995)
# ...       ...          ...         ...                               ...
# 8287   106782           54    3.916667   Wolf of Wall Street, The (2013)
# 8354   109374           52    3.778846  Grand Budapest Hotel, The (2014)
# 8358   109487           73    3.993151               Interstellar (2014)
# 8457   112852           59    4.050847    Guardians of the Galaxy (2014)
# 8673   122904           54    3.833333                   Deadpool (2016)
#
#                                            genres  Sci-Fi
# ...

# %% [markdown]
# # 🟢 IMPORTANT NOTE 2 🟢
# You already have a subset of data containing only those movies which has recieved more than 50 user ratings.
#
# Using "links.csv", scrape the IMDB reviews of each movie with more than 50 user ratings. "README.md" file contains the required details.
#
# If you are unable to write the webscraping script yourself, you can request the same by commenting LinkedIn Post.

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
fdf.head()
# Out:
#    movieId  ratingcount  ratingmean                    title  \
# 0        1          215    3.920930         Toy Story (1995)
# 1        2          110    3.431818           Jumanji (1995)
# 2        3           52    3.259615  Grumpier Old Men (1995)
# 5        6          102    3.946078              Heat (1995)
# 6        7           54    3.185185           Sabrina (1995)
#
#                                         genres Sci-Fi
# 0  Adventure|Animation|Children|Comedy|Fantasy    NaN
# 1                   Adventure|Children|Fantasy    NaN
# 2                               Comedy|Romance    NaN
# 5                        Action|Crime|Thriller    NaN
# 6                               Comedy|Romance    NaN

# %%
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
imdb = pd.merge(fdf , df_links , on = 'movieId' , how = 'inner')
imdb.head()
# Out:
#    movieId  ratingcount  ratingmean                    title  \
# 0        1          215    3.920930         Toy Story (1995)
# 1        2          110    3.431818           Jumanji (1995)
# 2        3           52    3.259615  Grumpier Old Men (1995)
# 3        6          102    3.946078              Heat (1995)
# 4        7           54    3.185185           Sabrina (1995)
#
#                                         genres Sci-Fi  imdbId   tmdbId
# 0  Adventure|Animation|Children|Comedy|Fantasy    NaN  114709    862.0
# 1                   Adventure|Children|Fantasy    NaN  113497   8844.0
# 2                               Comedy|Romance    NaN  113228  15602.0
# 3                        Action|Crime|Thriller    NaN  113277    949.0
# 4                               Comedy|Romance    NaN  114319  11860.0

# %%
imdb[(imdb.title == 'Shawshank Redemption, The (1994)')]
# Out:
#     movieId  ratingcount  ratingmean                             title  \
# 53      318          317    4.429022  Shawshank Redemption, The (1994)
#
#          genres Sci-Fi  imdbId  tmdbId
# 53  Crime|Drama    NaN  111161   278.0

# %% [markdown]
# # Mention the movieId of the movie which has the highest IMDB rating.

# %% [markdown]
# # Answer 318

# %% [markdown]
# # Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
imdb.head()
# Out:
#    movieId  ratingcount  ratingmean                    title  \
# 0        1          215    3.920930         Toy Story (1995)
# 1        2          110    3.431818           Jumanji (1995)
# 2        3           52    3.259615  Grumpier Old Men (1995)
# 3        6          102    3.946078              Heat (1995)
# 4        7           54    3.185185           Sabrina (1995)
#
#                                         genres Sci-Fi  imdbId   tmdbId
# 0  Adventure|Animation|Children|Comedy|Fantasy    NaN  114709    862.0
# 1                   Adventure|Children|Fantasy    NaN  113497   8844.0
# 2                               Comedy|Romance    NaN  113228  15602.0
# 3                        Action|Crime|Thriller    NaN  113277    949.0
# 4                               Comedy|Romance    NaN  114319  11860.0

# %%
imdb.loc[(imdb['Sci-Fi'] == 'Sci-Fi')].head(20)
# Out:
#      movieId  ratingcount  ratingmean  \
# 12        32          177    3.983051
# 30       160           57    2.877193
# 35       172           53    2.679245
# 36       173           62    2.669355
# 38       208          115    2.913043
# 44       260          251    4.231076
# 47       292          101    3.425743
# 51       316          140    3.375000
# 54       329          108    3.393519
# 73       435           63    2.420635
# 75       442           81    3.092593
# 80       480          238    3.750000
# 88       541          124    4.100806
# 96       589          224    3.970982
# 107      673           53    2.707547
# 113      780          202    3.445545
# 116      788           82    2.731707
# 124      924          109    3.894495
# 134     1097          122    3.766393
# 136     1127           62    3.475806
#
#                                          title  \
# 12   Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 30                                Congo (1995)
# ...

# %%
q.iloc[90:100]
# Out:
#     Unnamed: 0             Movie Name Certificate Duration  \
# 90          90                 Asuran   Not Rated  141 min
# 91          91             Drishyam 2         NaN  152 min
# 92          92      Top Gun: Maverick       PG-13  130 min
# 93          93    Requiem for a Dream           R  102 min
# 94          94                   Heat           R  170 min
# 95          95        American Beauty           R  122 min
# 96          96               Scarface         18+  170 min
# 97          97      Good Will Hunting           R  126 min
# 98          98     A Clockwork Orange           R  136 min
# 99          99  2001: A Space Odyssey           G  149 min
#
#                      Genre  IMDb Rating  Metascore          Director  \
# 90           Action, Drama          8.4        NaN       Vetrimaaran
# 91  Crime, Drama, Thriller          8.4        NaN     Jeethu Joseph
# 92           Action, Drama          8.3       78.0   Joseph Kosinski
# ...

# %% [markdown]
# # Answer is 924 Movie ID	2001: A Space Odyssey (1968)

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   movieId      436 non-null    int64
#  1   ratingcount  436 non-null    int64
#  2   ratingmean   436 non-null    float64
#  3   title        436 non-null    object
#  4   genres       436 non-null    object
#  5   imdbId       436 non-null    int64
#  6   tmdbId       436 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 24.0+ KB

# %%
imdb.shape
# Out:
# (436, 7)

# %%
imdbId = imdb.movieId
# # imdbId = imdbId.apply(pd.to_numeric)
# # imdbId = imdbId.astype(int)

# imdbId = pd.to_numeric(imdbId, errors='coerce')
type(imdbId)
# # imdbId = pd.DataFrame(imdbId)
# Out:
# pandas.core.series.Series

# %%
# We thought of giving you a gift this new year by sharing the web scraping script
# Understanding the script before using is always appreciated
# We left few blanks in the script for your exploration
# Make sure to replace FILL_IN_THE_BLANK in the code to make it work
# %%time
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(imdbId)
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    # request_header = {'Content-Type': 'text/html; charset=UTF-8', 
    #                   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
    #                   'Accept-Encoding': 'gzip, deflate, br'}
    # response = requests.get(URL, headers=request_header)
    response = requests.get(URL)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', class_ = 'sc-bde20123-1 cMEQkK')
    return imdb_rating.text if imdb_rating else np.nan

imdb['rating'] = imdb.imdbId.apply(scrapper)

# %%
imdb
# Out:
#      movieId  ratingcount  ratingmean                             title  \
# 0          1          215    3.920930                  Toy Story (1995)
# 1          2          110    3.431818                    Jumanji (1995)
# 2          3           52    3.259615           Grumpier Old Men (1995)
# 3          6          102    3.946078                       Heat (1995)
# 4          7           54    3.185185                    Sabrina (1995)
# ..       ...          ...         ...                               ...
# 431   106782           54    3.916667   Wolf of Wall Street, The (2013)
# 432   109374           52    3.778846  Grand Budapest Hotel, The (2014)
# 433   109487           73    3.993151               Interstellar (2014)
# 434   112852           59    4.050847    Guardians of the Galaxy (2014)
# 435   122904           54    3.833333                   Deadpool (2016)
#
#                                           genres   imdbId    tmdbId  rating
# ...

# %%
sc-bde20123-2 cdQqzc

# %%
# We thought of giving you a gift this new year by sharing the web scraping script
# Understanding the script before using is always appreciated
# We left few blanks in the script for your exploration
# Make sure to replace FILL_IN_THE_BLANK in the code to make it work
# %%time
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(imdbId)
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    # request_header = {'Content-Type': 'text/html; charset=UTF-8', 
    #                   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
    #                   'Accept-Encoding': 'gzip, deflate, br'}
    # response = requests.get(URL, headers=request_header)
    response = requests.get(URL)
    soup = BeautifulSoup(response.text)
    # imdb_rating = soup.find('div', class_ = 'sc-bde20123-2 cdQqzc')sc-bde20123-0 dLwiNw
    imdb_rating = soup.find('div', class_ = 'sc-bde20123-0 dLwiNw')
    return imdb_rating.text if imdb_rating else np.nan

imdb['rating'] = imdb.imdbId.apply(scrapper)

# %%
imdb
# Out:
#      movieId  ratingcount  ratingmean                             title  \
# 0          1          215    3.920930                  Toy Story (1995)
# 1          2          110    3.431818                    Jumanji (1995)
# 2          3           52    3.259615           Grumpier Old Men (1995)
# 3          6          102    3.946078                       Heat (1995)
# 4          7           54    3.185185                    Sabrina (1995)
# ..       ...          ...         ...                               ...
# 431   106782           54    3.916667   Wolf of Wall Street, The (2013)
# 432   109374           52    3.778846  Grand Budapest Hotel, The (2014)
# 433   109487           73    3.993151               Interstellar (2014)
# 434   112852           59    4.050847    Guardians of the Galaxy (2014)
# 435   122904           54    3.833333                   Deadpool (2016)
#
#                                           genres   imdbId    tmdbId  rating
# ...

# %%
# import requests
# import numpy as np
# from bs4 import BeautifulSoup
l = []
def scrapper(imdbId):
    id = str(imdbId)
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    # request_header = {'Content-Type': 'text/html; charset=UTF-8', 
    #                   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
    #                   'Accept-Encoding': 'gzip, deflate, br'}
    # response = requests.get(URL, headers=request_header)
    response = requests.get(URL)
    soup = BeautifulSoup(response.text)
    # imdb_rating = soup.find('div', class_ = 'sc-bde20123-2 cdQqzc')sc-bde20123-0 dLwiNw
    imdb_rating = soup.find('div', class_ = 'sc-bde20123-1 cMEQkK')
    l.append(imdb_rating)
#     return imdb_rating.text if imdb_rating else np.nan

# imdb['rating'] = imdb.imdbId.apply(scrapper)

# %%
l
# Out:
# []

# %%
q = pd.read_csv('movi.csv')
q.head()
# Out:
#    Unnamed: 0                                     Movie Name Certificate  \
# 0           0                       The Shawshank Redemption           R
# 1           1                                  The Godfather           R
# 2           2                                The Dark Knight       PG-13
# 3           3                               Schindler's List           R
# 4           4  The Lord of the Rings: The Return of the King       PG-13
#
#   Duration                      Genre  IMDb Rating  Metascore  \
# 0  142 min                      Drama          9.3       82.0
# 1  175 min               Crime, Drama          9.2      100.0
# 2  152 min       Action, Crime, Drama          9.0       84.0
# 3  195 min  Biography, Drama, History          9.0       95.0
# 4  201 min   Action, Adventure, Drama          9.0       94.0
#
#                Director                                              Stars  \
# ...

# %%
q.columns
# Out:
# Index(['Unnamed: 0', 'Movie Name', 'Certificate', 'Duration', 'Genre',
#        'IMDb Rating', 'Metascore', 'Director', 'Stars', 'Votes',
#        'Grossed in $', 'Plot'],
#       dtype='object')

# %%
q['IMDb Rating'].max()
# Out:
# 9.3

# %%
# Step 1: Import the necessary required libraries.
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# Step 2: Grab the top 100, sort the result by title.
# imdb_url = "https://www.imdb.com/search/title/?groups=top_100&ref_=adv_prv"
imdb_url = f"https://www.imdb.com/title/tt{new_id}/"

# Step 3: Set headers.
headers = {"Accept-Language": "en-US, en;q=0.5"}

# Step 4: Save all values to the results objects coming back from the .get on IMDb URL.
results = requests.get(imdb_url, headers=headers)

# Step 5: Parse the results object to movie_soup using the html parser.
movie_soup = BeautifulSoup(results.text, "html.parser")

# Step 6: I want to extract these attributes (to a list) from the movie_soup.
movie_name = []
movie_years = []
movie_runtime = []
imdb_ratings = []
metascores = []
number_votes = []
us_gross = []

# Step 7: Create a movie_div object to find all div objects in movie_soup.
movie_div = movie_soup.find_all('div', class_='lister-item mode-advanced')

# Step 8: Loop through each object in the movie_div.
for container in movie_div:

# Step 9: Add each result from each attribute for each list.

        # name
        name = container.h3.a.text
        movie_name.append(name)

        # year
        year = container.h3.find('span', class_='lister-item-year').text
        movie_years.append(year)

        # runtime
        runtime = container.p.find('span', class_='runtime').text if container.p.find('span', class_='runtime').text else '-'
        movie_runtime.append(runtime)

        # IMDB rating
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)

        # metascore
        m_score = container.find('span', class_='metascore').text if container.find('span', class_='metascore') else '-'
        metascores.append(m_score)

        # There are two NV containers, grab both of them as they hold both the votes and the grosses
        nv = container.find_all('span', attrs={'name': 'nv'})

        # filter nv for votes
        vote = nv[0].text
        number_votes.append(vote)

        # filter nv for gross
        grosses = nv[1].text if len(nv) > 1 else '-'
        us_gross.append(grosses)

# Step 10: Build and store all of the attributes into the Pandas movie dataframe.        
movies = pd.DataFrame({
'movie_name': movie_name,
'movie_year': movie_years,
'movie_runtime': movie_runtime,
'imdb_ratings': imdb_ratings,
'metascore': metascores,
'number_votes': number_votes,
'us_gross_millions': us_gross,
})

# Step 11: Use Pandas str.extract to remove all String characters, and save the value as type int for cleaning up the data with Pandas.
movies['movie_year'] = movies['movie_year'].apply(lambda x : x.str.extract('(\d+)').astype(int))

# movies['movie_year'] = movies['movie_year'].str.extract('(\d+)').astype(int)
# movies['movie_runtime'] = movies['movie_runtime'].str.extract('(\d+)').astype(int)
movies['movie_runtime'] = movies['movie_runtime'].apply(lambda x : x.str.extract('(\d+)').astype(int))

movies['metascore'] = movies['metascore'].astype(int)
# movies['number_votes'] = movies['number_votes'].str.replace(',', '').astype(int)
movies['number_votes'] = movies['number_votes'].apply(lambda x : x.str.replace(',', '').astype(int))

movies['us_gross_millions'] = movies['us_gross_millions'].map(lambda x: x.lstrip('$').rstrip('M'))
movies['us_gross_millions'] = pd.to_numeric(movies['us_gross_millions'], errors='coerce')

# Step 12: Export our movie results to a pretty little .csv file.
# movies.to_csv('top_100_movies2.csv')

# %%
imdb_ratings
# Out:
# []

# %%
# %%time
def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span',attrs={'class':'sc-bde20123-1 cMEQkK'})
    return imdb_rating.text if imdb_rating else np.nan

final_df['Imdb_rating'] = final_df['imdbId'].apply(scrapper)

# %%
scrapper(imdbId)

# %%
imdb.imdbId = imdb.imdbId.apply(scrapper)

# %%
imdb

# %%
114709

# %%
id = str(int(113497))
n_zeroes = 7 - len(id)
new_id = "0"*n_zeroes + id
URL = f"https://www.imdb.com/title/tt{new_id}/"
URL
# Out:
# 'https://www.imdb.com/title/tt0113497/'
