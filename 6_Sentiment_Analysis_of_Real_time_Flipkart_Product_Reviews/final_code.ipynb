# %% [markdown]
# # Team-5

# %% [markdown]
# # Web_Scrapping - Sports : Badminton

# %%
import requests

# %%
import numpy as np
from bs4 import BeautifulSoup

# %%
URL="https://www.flipkart.com/search?q=yonex-mavis-350-nylon-shuttle-yellow"

# %%
request_header={'content-type': 'text/plain','User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36",'Accept-Encoding': 'gzip, deflate, br'}

# %%
response= requests.get(URL,headers=request_header)

# %%
print(response.status_code)
# Out:
# 200

# %%
response.headers
# Out:
# {'server': 'nginx', 'date': 'Sat, 04 Nov 2023 14:04:56 GMT', 'content-type': 'text/html; charset=utf-8', 'transfer-encoding': 'chunked', 'content-security-policy': "default-src 'self'; script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://tnc.phonepe.com https://captcha.px-cdn.net https://js-agent.newrelic.com https://bam.nr-data.net https://www.googletagmanager.com 'nonce-8078702297021207852'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://images.ixigo.com https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://pay.payzippy.com https://1.pay.
# ...

# %%
html_code=response.text

# %%
html_code
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.ccbde3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
type(html_code)
# Out:
# str

# %%
soup=BeautifulSoup(html_code)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.ccbde3.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [raw]
# BOX : tag - div , class - col _2wzgFH K0kLPL
#
# rating : tag - <div> , class - _3LWZlK _1BLPMq
#
# reaction : tag - <p> , class -  _2-N8zT
#
# customer name : tag - <p> , class - _2sc7ZR _2V5EHH
#
# Date : tag - <p> , class - _2sc7ZR
#
# certified : tag <span>
#
# place - tag <span>
#
# likes (useful) - <div> , class - _1LmwT9  ,<span>
#
# dislikes (not useful) - tag - <div> , class - _1LmwT9 pkR4jH , <span>
#
# https://www.flipkart.com/yonex-mavis-350-nylon-shuttle-yellow/product-reviews/itmfcjdyhnghfyey?pid=STLEFJ7UFQGRUUR3&lid=LSTSTLEFJ7UFQGRUUR3SUDA2S&marketplace=FLIPKART&page=1

# %% [markdown]
# ### Rating

# %%
rating= soup.find('div',attrs={'class':'_3LWZlK _1BLPMq'})

# %%
print(rating.text)
# Out:
# 4

# %% [markdown]
# ### Review text

# %%
description=soup.find('div',attrs={'class':'t-ZTKy'})

# %%
print(description.text)
# Out:
# It's a really good shuttle by keeping budget in mind for beginners it will last longer but for intermediate players it will hardly last for 4,5days and withi...Read full review

# %% [markdown]
# ### Rviewer_Name

# %%
customer_name=soup.find('p',attrs={'class':'_2sc7ZR _2V5EHH'})

# %%
print(customer_name.text)
# Out:
# Shankar Sajeev

# %%
Review_date=soup.find('p',attrs={'class':'_2sc7ZR'})

# %%
print(Review_date.text)
# Out:
# Shankar Sajeev

# %% [markdown]
# ### Type of user

# %%
Buyer=soup.find('p',attrs={'class':'_2mcZGG'})

# %%
print(Buyer.text)
# Out:
# Certified Buyer

# %%
place=soup.find('p',attrs={'class':'_2sc7ZR'})

# %%
print(place.text)
# Out:
# Shankar Sajeev

# %%
useful=soup.find('p',attrs={'class':'_2sc7ZR'})

# %%
print(useful.text)
# Out:
# Shankar Sajeev

# %%
date=soup.find_all('div',attrs={'class':'row _3n8db9'})

# %%
for name in date:
    print(name.text)
# Out:
# Kamal SureshCertified Buyer, ChirakkalFeb, 202188964PermalinkReport Abuse
# Flipkart CustomerCertified Buyer, HyderabadFeb, 20211096PermalinkReport Abuse
# A. S. Raja Srinivasan Certified Buyer, DharmapuriApr, 2021423PermalinkReport Abuse
# Suresh NarayanasamyCertified Buyer, Chennai9 months ago251PermalinkReport Abuse
# ASHIK P AApr, 201614724PermalinkReport Abuse
# Baji SankarCertified Buyer, HyderabadOct, 201817345PermalinkReport Abuse
# Flipkart CustomerCertified Buyer, Doom DoomaJan, 2020403121PermalinkReport Abuse
# Flipkart CustomerCertified Buyer, PanjimOct, 20185913PermalinkReport Abuse
#  Jafar  QureshiCertified Buyer, SheopurAug, 2018141PermalinkReport Abuse
# BheemeshCertified Buyer, KurnoolMay, 20185012PermalinkReport Abuse

# %%
da=soup.find_all('div',attrs={'class':'_2bmov8'})

# %%
for d in da:
    print(d.text)
# Out:
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse
# PermalinkReport Abuse

# %%
#_2sc7ZR
date=soup.find_all('p',attrs={'class':'_2sc7ZR'})

# %%
for names in date:
    print(names.text)
# Out:
# Kamal Suresh
# Feb, 2021
# Flipkart Customer
# Feb, 2021
# A. S. Raja Srinivasan
# Apr, 2021
# Suresh Narayanasamy
# 9 months ago
# ASHIK P A
# Apr, 2016
# Baji Sankar
# Oct, 2018
# Flipkart Customer
# Jan, 2020
# Flipkart Customer
# Oct, 2018
#  Jafar  Qureshi
# Aug, 2018
# Bheemesh
# May, 2018

# %% [markdown]
# ## Review_title

# %%
review_title=soup.find('p',attrs={'class':'_2-N8zT'})

# %%
print(review_title.text)
# Out:
# Very Good

# %%
details= soup.find_all('p',attrs={'class':'_2-N8zT'})

for detail in details:
    print(detail.text)
# Out:
# Useless product
# Simply awesome
# Value-for-money
# Wonderful
# Best in the market!
# Worst experience ever!
# Mind-blowing purchase
# Terrible product
# Must buy!
# Mind-blowing purchase

# %%
print(detail.text)
# Out:
# Kamal SureshCertified Buyer, ChirakkalFeb, 202188964PermalinkReport Abuse

# %%
# %%time

Place=[]
title=[]
Name=[]
rtext=[]
Rat1=[]
Rat2 = []
up=[]
down=[]
mth=[]

pages=853
for i in range(1,pages):
    URL=f"https://www.flipkart.com/yonex-mavis-350-nylon-shuttle-yellow/product-reviews/itmfcjdyhnghfyey?pid=STLEFJ7UFQGRUUR3&lid=LSTSTLEFJ7UFQGRUUR3SUDA2S&marketplace=FLIPKART&page={i}"
    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL,headers=request_header)
    html_code = response.text
    soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'col _2wzgFH K0kLPL'})
    for container in containers:
        locations=container.find('p',attrs={'class':'_2mcZGG'})
        if locations is None:
            Place.append(np.NaN)
        else:
            Place.append(locations.text)
        #Reviewer_data.append(locations.text)
        
        
        titles=container.find('p',attrs={'class':'_2-N8zT'})
        if titles is None:
            title.append(np.NaN)
    #for title in titles:
        else:
            title.append(titles.text)
        
        
        Names=container.find('p',attrs={'class':'_2sc7ZR _2V5EHH'})
        if Names is None:
            Name.append(np.NaN)
        else:
            Name.append(Names.text)
            
            
        rtexts = container.find('div',attrs={'class':'row'})
        if rtexts is None:
            rtext.append(np.NaN)
        else:
            rtext.append(rtexts.text)
            
            
        #upvotes    
        month=container.find('span',attrs={'class':'_3c3Px5'})
        if month is None:
            up.append(np.NaN)
        else:
            up.append(month.text)
            
        #down votes
        down=container.find('div',attrs={'class','_1LmwT9 pkR4jH'})
        if down is None:
            down.append(np.NaN)
        else:
            down.append(down.text)
            
            
        #month
        mont=container.find('div',attrs={'class':'row _3n8db9'})
        if mont is None:
            mth.append(np.NaN)
        else:
            mth.append(mont.text)
        
        star=container.find('div',attrs={'class':'row'})
        if star is None:
            ratings_star.append(np.NaN)
        else:
            ratings_star.append(star.text)
# Out:
# Wall time: 7min 27s

# %%
len(Review_title)
# Out:
# 490

# %%
len(Place_Review)
# Out:
# 490

# %%
len(Reviewer_Name)
# Out:
# 490

# %%
len(Reviews_text)
# Out:
# 490

# %%
len(Rating)
# Out:
# 490

# %%
len(Rating1)
# Out:
# 490

# %%
len(s)
# Out:
# 490

# %%
len(ds)
# Out:
# 490

# %%
len(mth)
# Out:
# 490

# %%
dm
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
Place=[]
title=[]
Name=[]
rtext=[]
Rat1=[]
Rat2 = []
up=[]
down=[]
mth=[]

# %%
len(Place)
# Out:
# 8508

# %%
len(title)
# Out:
# 8508

# %%
len(Name)
# Out:
# 8508

# %%
len(rtext)
# Out:
# 8508

# %%
len(Rat1)
# Out:
# 8508

# %%
len(Rat2)
# Out:
# 8508

# %%
len(up)
# Out:
# 8508

# %%
len(down)
# Out:
# 3

# %%
len(mth)
# Out:
# 8508

# %%
# %%time
tt=[]

pages=852
for i in range(1,pages):
    URL=f"https://www.flipkart.com/yonex-mavis-350-nylon-shuttle-yellow/product-reviews/itmfcjdyhnghfyey?pid=STLEFJ7UFQGRUUR3&lid=LSTSTLEFJ7UFQGRUUR3SUDA2S&marketplace=FLIPKART&page={i}"
    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL,headers=request_header)
    html_code = response.text
    soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'col _2wzgFH K0kLPL'})
    for container in containers:
        #down votes
        rtexts = container.find('div',attrs={'class':'t-ZTKy'})
        if rtexts is None:
            tt.append(np.NaN)
        else:
            tt.append(rtexts.text)
# Out:
# Wall time: 5min 58s

# %%
len(tt)
# Out:
# 8510

# %%
len(dwns)
# Out:
# 8508

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Reviewer Name':Name,
                "Reviewer Rating >2":Rat1,
                "Reviewer Rating <2":Rat2,
                "Review Title":title,
                "Review Text":rtext,
                "Place of Review":Place,
                "Date of Review":mth,
                "Up Votes":up,
                "Down Votes":dwns})

# %%
df.head()
# Out:
#             Reviewer Name Reviewer Rating >2 Reviewer Rating <2  \
# 0            Kamal Suresh                  4                NaN
# 1       Flipkart Customer                NaN                  1
# 2  A. S. Raja Srinivasan                 NaN                  1
# 3     Suresh Narayanasamy                  3                NaN
# 4               ASHIK P A                NaN                  1
#
#                 Review Title                 Review Text  \
# 0               Nice product               4Nice product
# 1     Don't waste your money     1Don't waste your money
# 2  Did not meet expectations  1Did not meet expectations
# 3                       Fair                       3Fair
# 4                Over priced                1Over priced
#
#                Place of Review  \
# 0   Certified Buyer, Chirakkal
# 1   Certified Buyer, Hyderabad
# 2  Certified Buyer, Dharmapuri
# 3     Certified Buyer, Chennai
# 4                          NaN
#
# ...

# %%
df.to_csv('sports.csv', index=False)

# %%
print(df['Date of Review'])
# Out:
# 0       Kamal SureshCertified Buyer, ChirakkalFeb, 202...
# 1       Flipkart CustomerCertified Buyer, HyderabadFeb...
# 2       A. S. Raja Srinivasan Certified Buyer, Dharmap...
# 3       Suresh NarayanasamyCertified Buyer, Chennai9 m...
# 4          ASHIK P AApr, 20161472424PermalinkReport Abuse
#                               ...
# 8503              darwinApr, 2016200PermalinkReport Abuse
# 8504            naresh gAug, 2016211PermalinkReport Abuse
# 8505          MD. JabbarSep, 2016100PermalinkReport Abuse
# 8506        Abani BeheraSep, 2016022PermalinkReport Abuse
# 8507    vishnu varmaCertified Buyer, AgartalaSep, 2016...
# Name: Date of Review, Length: 8508, dtype: object

# %%
import re

# Load CSV 

# Extract month and year into new columns
df[['Month', 'Year']] = df['Date of Review'].str.extract(r'([A-Za-z]+), (\d{4})') 

# Add new column from extracted values
df['Month of Review'] = df['Month'] + ' ' + df['Year']

# Drop temporary columns
#df.drop(columns=['Month', 'Year'], inplace=True)

# Save updated CSV
df.to_csv('reviews_updated.csv', index=False)

# %%
df=pd.read_csv("reviews_updated.csv")

# %%
df.head()
# Out:
#             Reviewer Name  Reviewer Rating >2  Reviewer Rating <2  \
# 0            Kamal Suresh                 4.0                 NaN
# 1       Flipkart Customer                 NaN                 1.0
# 2  A. S. Raja Srinivasan                  NaN                 1.0
# 3     Suresh Narayanasamy                 3.0                 NaN
# 4               ASHIK P A                 NaN                 1.0
#
#                 Review Title                 Review Text  \
# 0               Nice product               4Nice product
# 1     Don't waste your money     1Don't waste your money
# 2  Did not meet expectations  1Did not meet expectations
# 3                       Fair                       3Fair
# 4                Over priced                1Over priced
#
#                Place of Review  \
# 0   Certified Buyer, Chirakkal
# 1   Certified Buyer, Hyderabad
# 2  Certified Buyer, Dharmapuri
# 3     Certified Buyer, Chennai
# 4                          NaN
#
# ...

# %%
df
# Out:
#                Reviewer Name  Reviewer Rating >2  Reviewer Rating <2  \
# 0               Kamal Suresh                 4.0                 NaN
# 1          Flipkart Customer                 NaN                 1.0
# 2     A. S. Raja Srinivasan                  NaN                 1.0
# 3        Suresh Narayanasamy                 3.0                 NaN
# 4                  ASHIK P A                 NaN                 1.0
# ...                      ...                 ...                 ...
# 8503                  darwin                 5.0                 NaN
# 8504                naresh g                 NaN                 NaN
# 8505              MD. Jabbar                 4.0                 NaN
# 8506            Abani Behera                 NaN                 1.0
# 8507            vishnu varma                 4.0                 NaN
#
#                    Review Title                 Review Text  \
# 0                  Nice product               4Nice product
# ...

# %%
df.drop(['Date of Review', 'Year'], axis=1, inplace=True)

# %%
df.head()
# Out:
#             Reviewer Name  Reviewer Rating >2  Reviewer Rating <2  \
# 0            Kamal Suresh                 4.0                 NaN
# 1       Flipkart Customer                 NaN                 1.0
# 2  A. S. Raja Srinivasan                  NaN                 1.0
# 3     Suresh Narayanasamy                 3.0                 NaN
# 4               ASHIK P A                 NaN                 1.0
#
#                 Review Title                 Review Text  \
# 0               Nice product               4Nice product
# 1     Don't waste your money     1Don't waste your money
# 2  Did not meet expectations  1Did not meet expectations
# 3                       Fair                       3Fair
# 4                Over priced                1Over priced
#
#                Place of Review  Up Votes  Down Votes     Month
# 0   Certified Buyer, Chirakkal       889          64  Feb 2021
# 1   Certified Buyer, Hyderabad       109           6  Feb 2021
# ...

# %%
df.to_csv('data_updated.csv', index=False)

# %%
df1['Review text']=tt

# %%
df1=pd.read_csv("data_updated.csv")

# %%
df1.head()
# Out:
#             Reviewer Name  Reviewer Rating >2  Reviewer Rating <2  \
# 0            Kamal Suresh                 4.0                 NaN
# 1       Flipkart Customer                 NaN                 1.0
# 2  A. S. Raja Srinivasan                  NaN                 1.0
# 3     Suresh Narayanasamy                 3.0                 NaN
# 4               ASHIK P A                 NaN                 1.0
#
#                 Review Title                 Review Text  \
# 0               Nice product               4Nice product
# 1     Don't waste your money     1Don't waste your money
# 2  Did not meet expectations  1Did not meet expectations
# 3                       Fair                       3Fair
# 4                Over priced                1Over priced
#
#                Place of Review  Up Votes  Down Votes     Month
# 0   Certified Buyer, Chirakkal       889          64  Feb 2021
# 1   Certified Buyer, Hyderabad       109           6  Feb 2021
# ...

# %%
df = df.append([new_row1, new_row2], ignore_index=True)

# %%
new_row1 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
           'Down Votes':'NaN','Month':'NaN'} 
new_row2 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
           'Down Votes':'NaN','Month':'NaN'}

# %%
df1 = df1.append([new_row1, new_row2], ignore_index=True)

# %%
df1.tail()
# Out:
#      Reviewer Name Reviewer Rating >2  Reviewer Rating <2  \
# 8505    MD. Jabbar                4.0                 NaN
# 8506  Abani Behera                NaN                 1.0
# 8507  vishnu varma                4.0                 NaN
# 8508           NaN                NaN                 NaN
# 8509           NaN                NaN                 NaN
#
#                 Review Title              Review Text  \
# 8505               Very Good               4Very Good
# 8506  Don't waste your money  1Don't waste your money
# 8507             Really Nice             4Really Nice
# 8508                     NaN                      NaN
# 8509                     NaN                      NaN
#
#                 Place of Review Up Votes Down Votes     Month  \
# 8505                        NaN        1          0  Sep 2016
# 8506                        NaN        0          2  Sep 2016
# 8507  Certified Buyer, Agartala        0          1  Sep 2016
# ...

# %%
df1.drop(['Review Text'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#             Reviewer Name Reviewer Rating >2  Reviewer Rating <2  \
# 0            Kamal Suresh                4.0                 NaN
# 1       Flipkart Customer                NaN                 1.0
# 2  A. S. Raja Srinivasan                 NaN                 1.0
# 3     Suresh Narayanasamy                3.0                 NaN
# 4               ASHIK P A                NaN                 1.0
#
#                 Review Title              Place of Review Up Votes Down Votes  \
# 0               Nice product   Certified Buyer, Chirakkal      889         64
# 1     Don't waste your money   Certified Buyer, Hyderabad      109          6
# 2  Did not meet expectations  Certified Buyer, Dharmapuri       42          3
# 3                       Fair     Certified Buyer, Chennai       25          1
# 4                Over priced                          NaN      147         24
#
#       Month                                        Review text
# ...

# %%
df1.to_csv('final_data_updated.csv', index=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8510 entries, 0 to 8509
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Reviewer Name       8510 non-null   object
#  1   Reviewer Rating >2  7433 non-null   object
#  2   Reviewer Rating <2  769 non-null    float64
#  3   Review Title        8510 non-null   object
#  4   Place of Review     8470 non-null   object
#  5   Up Votes            8510 non-null   object
#  6   Down Votes          8510 non-null   object
#  7   Month               8055 non-null   object
#  8   Review text         8510 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 598.5+ KB

# %%
df1['Month']=pd.to_datetime(df['Month'])

# %%
df1['Month']
# Out:
# 0      2021-02-01
# 1      2021-02-01
# 2      2021-04-01
# 3             NaT
# 4      2016-04-01
#           ...
# 8505   2016-09-01
# 8506   2016-09-01
# 8507   2016-09-01
# 8508          NaT
# 8509          NaT
# Name: Month, Length: 8510, dtype: datetime64[ns]

# %%
df1.head()
# Out:
#             Reviewer Name Reviewer Rating >2  Reviewer Rating <2  \
# 0            Kamal Suresh                4.0                 NaN
# 1       Flipkart Customer                NaN                 1.0
# 2  A. S. Raja Srinivasan                 NaN                 1.0
# 3     Suresh Narayanasamy                3.0                 NaN
# 4               ASHIK P A                NaN                 1.0
#
#                 Review Title              Place of Review Up Votes Down Votes  \
# 0               Nice product   Certified Buyer, Chirakkal      889         64
# 1     Don't waste your money   Certified Buyer, Hyderabad      109          6
# 2  Did not meet expectations  Certified Buyer, Dharmapuri       42          3
# 3                       Fair     Certified Buyer, Chennai       25          1
# 4                Over priced                          NaN      147         24
#
#        Month                                        Review text
# ...

# %% [markdown]
# ### This step done in new file that's why i kept in markdown format

# %% [raw]
# ratings_star=[]
#
# pages=854
# for i in range(1,pages):
#     URL=f"https://www.flipkart.com/yonex-mavis-350-nylon-shuttle-yellow/product-reviews/itmfcjdyhnghfyey?pid=STLEFJ7UFQGRUUR3&lid=LSTSTLEFJ7UFQGRUUR3SUDA2S&marketplace=FLIPKART&page={i}"
#     request_header={'Accept-Encoding': 'gzip, deflate, br',
#                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
#                'content-type': 'text/plain'}
#     response=requests.get(URL,headers=request_header)
#     html_code = response.text
#     soup = BeautifulSoup(html_code)
#     containers = soup.find_all('div',attrs={'class':'col _2wzgFH K0kLPL'})
#     for container in containers:
#         star=container.find('div',attrs={'class':'row'})
#         if star is None:
#             ratings_star.append(np.NaN)
#         else:
#             ratings_star.append(star.text)
#
# new_row1 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row2 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row3 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row4 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row5 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row6 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row7 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
# new_row8 = {'Reviewer Name': 'NaN', 'Reviewer Rating >2': 'NaN', 'Review Title': 'NaN','Review Text':'NaN','Place of Review':'NaN','Up Votes':'NaN',
#            'Down Votes':'NaN','Month':'NaN'}
#
#
# df = df.append([new_row3,new_row4,new_row5,new_row6,new_row7,new_row8,], ignore_index=True)
#
# df['Rating']=ratings_star
#
# import re
#
#
# data = df['Rating']
#
# # Extract number from Rating column
# df['Ratings'] = data.str.extract(r'(\d+)', expand=False)
#
# print(df)
#
# df.drop(['Reviewer Rating >2', 'Reviewer Rating <2','Rating','Review Text'], axis=1, inplace=True)
#
# df.to_csv("final_dataset.csv",index=False)

# %% [markdown]
# ## Final Output

# %%
import pandas as pd

# %%
df=pd.read_csv('final_csv.csv')

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB
