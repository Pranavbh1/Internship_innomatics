# %% [markdown]
# # **Project Hint - Reading the Data from Database**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from google.colab import drive
# drive.flush_and_unmount()

# %%
import sqlite3
import pandas as pd

# %%
# !ls -l /eng_subtitles_database.db
# Out:
# -rw-r--r-- 1 root root 59768832 Apr 10 05:22 /eng_subtitles_database.db

# %%
# !wc -c /eng_subtitles_database.db
# Out:
# 59768832 /eng_subtitles_database.db

# %% [markdown]
# ## **Step 1 - Reading the Tables from Database file**

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect('/content/eng_subtitles_database.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='zipfiles'")
print(cursor.fetchall())
# Out:
# []

# %% [markdown]
# **In the above cell, I am able to read the table inside the database. As mentioned earlier, table name is `zipfiles`. We also know from README.txt that this table contains three columns: 'num', 'name' and 'content'.**

# %% [markdown]
# ## **Step 2 - Reading the columns of Table**

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])

# %% [markdown]
# **The above code helps in checking the column names in the database table.**
#
# **Let's now use `SELECT * FROM zipfiles` to read all the data into a `df` variable.**

# %% [markdown]
# ## **Step 3 - Loading the Database Table inside a Pandas DataFrame**

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: no such table: zipfiles
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-42-f20e58dc0a1b> in <cell line: 1>()
# ----> 1 df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     467
#     468     with pandasSQL_builder(con) as pandas_sql:
# --> 469         return pandas_sql.read_query(
#     470             sql,
#     471             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT * FROM zipfiles': no such table: zipfiles

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   num      82498 non-null  int64
#  1   name     82498 non-null  object
#  2   content  82498 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# **Looks like the `content` column donot contain the subtitles text. Instead as mentioned in README.txt, it might be latin-1 encoded.**

# %% [markdown]
# ## **Step 4 - Printing `content` of 0th Row**

# %%
b_data = df.iloc[0, 2]

# here 2 represent the index of content column
# 0 represents the row number

# %%
print(b_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x99V\x9fx\x96\xf0\x8c\x9e\x00\x00\x86\x9b\x01\x00;\x00\x00\x00The.Message.1976.REMASTERED.1080p.BluRay.x264-PiGNUS.EN.srt\xad\xbdm\x93\xdc\xc6\x91.\xfa\x9d\x11\xfc\x0f-}\xe1=\x11-\x9d\x06P\x85\x17\x9d\x8d\xd5%%[\xa4-Y>&u\x15>\xdf\xd0\xd3\x98\x19x\xfae\x0cts<\xfe\xf57\x9f\'\xb3\n\xd9\xa4\xbc\xbb\xf7\xc6Fl\xacELW\xa2\xaa\x90\x95\x95\xafO\x16/_l6\xdf\xe0\xff\xea\xf5f\xb3Y}\xf5\xd5\xbf\xaf\xf4AQ\xae7Mx\xf9\xe2\xd7\xfe|s\xbf\xea\x8f\xcf\xab\x8f\xe3n8\xadN\xc7\xfdx\x1cVO\xe3\xf9~\xf5\xf3\xe3p\xfc\xea\xfd/o>\xbc\xfb\xf0\xe3\xef\xde\xbf|\xf1\xfbi\x18Vo\xa6\xd3\xd3<L\xab\xe1\x1f\xe7\xe18\x8f\xa7\xe37\xab\xd3\xbc\xdb~-\xc3\x1e\xfe\xa7<|\xf9\xe2\xe5\x8bR_[~S\xd6\xeb\xa2k\xf3k\xe5A\xb7\xeeb\xf5\xf2\xc5\xbb\xe3\xea|?\xac\x8e\xfdaX\x9dnW?\x9cvk>8\x9c\xe6\xf3\xean\xeao\xc6\xd3ev\x8f~\x1a\xa6\x9b\xf1\xf6\xb2\xff\x1a\xe4\xabD\xbe*d\x11\xa5#_U\xeb\xaa\xd9`\xa6\xa7\xc3\xea\xa7\xcb}\x7f8\xf4F\xf9\xa7a\x9e\x87\xe3\x9d\xcc\\\xdf\x07B!\x13\xaa\xd61n<!\xd9\xaf\xd0\xbc|q>\xad\xde\x0e2\x9d\xfd\x98\xa63\x1c\x1e\x87\xe9D*o\x9e\xff\xd9\x1f\xcf\xe3\xe5\xc0Y\xc5L\xac^\x87M\xe3\x89u\xebP\xcb\xbb\xeed\xff\xce\xe3\xf1n^\t\xd9\xfb\xf1\xb0z\xba?\xad\xc6\x19d_\xbe\xb8=\xed\xf7\xa7\'\x9d\xde4\xde\xdd\x9f\x07\xd9\x81\xd5\xdde\xdc\xf5\xc7\x9b\x81o\xa8\xf3\x1b\xbau\xd3V\xee\r\xa1\\\xc7\xae\x90m]m\xc7\xdd\xea\xf9t\xe1\x1b\x86~\xe2\x94w\xe3G|\xd3\x9b~\xaf\xfb\xd7$:\xa1Z\x17\xb5_v\x88\xeb\xb6h@\xa7?\xe8\xe6\x7f\xb2k\xa0\x8b\xe7\x8f\xc3\xe9q?\xfc/Pk3\xb5z]U~\xdd\xa1\x95i\xca\xba\xfb\x9b\x9b\xe1\xf1\xbcz7\xef\x85\xea\xad\xec\x9dLpZ\xcd\xfd\xfec\x7f\x16\x06\xe2\x9c\xbaD%\x96\xeb\xb2*\x1c\x95\x18\xd6\xcdF\xfe\xfcvX\xcd\x8fC\xff0c*\xfd\xea8<\xad\x1e\xa7\xd3\xe3\xfdp^\x8d\xc7\xd5\xeb\xa9\xdf\x8e=I\x15\x9bL+\xae7\xb5g\xbf\xd8\xac\xdb2\x82\xeb\xe7\xd5x^\xed\xc7\x87A\x96#\x9f\xe0\xe9~8\xae\xfep\xba?\xeaG~\xd3?\x9e\xc7Yx\xf9\x06\x0c*k~\x90\xcf\x06NP\xbe)\x8a\xfc\x86v]\x84\x98\xdfP}\xb3)\xd6e#\xfc\x7f\xba\x9c1On\xff \xe7\xe5\xbc^\xddL\xcf\xa0\xd2o\xf1\xb7\xbc\xfaoI\xd0NL\xc5\x13S\xd5\x8e`\xd9\xae\xbb\x8dp\xfc\x87\x930\xf4\xdf\xfb\xa7\xbf\x8f\xc2\x88\x7f\xee\xcf\xd3\xd8Orr\xe5\x1d\xaf\xf7\xc3?\xfa\xe3nJ\xcb\xaf\x12-\xe1\x8a\xe0\x0e\xbd<\x08\xeb\xba\x92\xef\xf5\xc7q\x9e\xfa\xb5g\xe5?\x0f\xd3\x9c\xc6\x87<^v>6~|\xb3\x0e\x9dl_:Yd\xa9\x99\xfcF\x81\x81\xd5\xe2\x911\x8b\x92\x8b\x99\\\xb3n\x8a\xe0\xc8\xc5\x8d\x9c:\xd9\xca\xd7\xff\t\x7f|\xad\x84\xeaDH\xc6\xb5\x9d_\x97\xf0L\x08\xc2"\xc3a+guPJ:\xa8\xc9\x83\xc2\xba\xac\xfdb\xe4\xd35\xa5\xec\xfb_e\xf67\'\xc8\xa1\xcf>\xd9\xcb\x17\xf3a\xd8\xef\xf1\xd5\xe4\x0f\xe0\x85\xbd\x88\xca\xdd\xea\xee\xd4\x9f\x95|\x9b\xc9\x83\xd7\x17Q\x14D\xc6\xcaQ\xda\xf0\xbb\x9d\x85\x86\xed0\x18m\x1a\xe4h\xae\xe6\xfb\xd3e\xbf[=\x1c\x87a\xaf<`G@\x86vr\x90<\xad\xa2X\xd7\x9b\xcd\xb2\xef\xeb\xcf\xa4\x19gSn\x12\x85\xa2Z\xd7\xa1\xf5\x14\xe2\xba\xda\xc8\x06\xfe*\x12\xe7\xae\xff8P\xfc\x90\xf3\xfb\xcb\xf9\xfe4\x8d\xe7gN\xa2,2\x89(\x0b\x8a\x9e\x84\xac0\xc8~A\n\xc8\xbb\xcfY\xbe\xca\x01\x172"*\xa6\x9bg\x9c\x95C\x7f\x94\xe3bS2\xc6\x8e\x98R\xe5\x98)~SF9)\xc2k\x1fd3\xde\xdf\xdc\x9f\xf6\xfd4sw\xdf\xca\xc9\x93\x19\xf5G\x9et\xe5\x8a\xaf\xf4w\xbf\x1c\xc7\x8f\xd8\xc7\xf3\xb32\xfeW\xaf\xffy/BN\xce\xffw\xfd8\x9d\xf4GoEz\xea\xb0\xf1f\xf5\xdd\xe9(bw\x9e\xd3\x97}\x7f?\xf6\x14\x18?\x0e\xdb\xfex:r\x92U\x9a$N\xdf\xa6r\x93\x94\x8b\xa1\tQ\xe9\x1e\xfa\x07y\xb7\x12\x92\x8d\xbb\x1d\xf7\x87\xd5\xfd\xe9\x08^\x05\xe5\xf4\xc6\xf3\xd4\xefF\xf0\xed\xcb\x17O\xf7\xa3\x1cQY\xda\x0eB^\xde\xcb\xdf\xe1\xd4\xcd\xa7#y;M\xeb\xcf*\xc9Dn\xdc\xde\x0eG\xf9y\x7f\xd7\x8f\xc7YG\xcc\x8f\xa3|\xa0K\xbf\xb7u\xe3\xed\x10\xcc\xfd\x9d\xde\x0beH\xf3\xc7t\xddG\x8b\x10\xe8U\xab\x9b<\rr\xb4\x86\xb5\x89o\xcc\x00\xb4~:\xa5\x8f\xf84\n\x97\x1eO\xe7\xd5\x96\xcc\xf9\xa4r\xb9\x8c\x89\xb6\x9c\xba\xcd\xa6s\xb4c%w\xa4\xf0\xd4\xbf\x8d\xff.\xdc\xb9z\x1e\xf8\x01o\xcf\xc2\x94\xdf\xddO\xf2\x11\xe5\xe2\x19v\xeb\x7f\xfb\x9f\xe3\xbf\x93R\x9d)U\xeb2\xd4\x9eRT\xd6\x12J\x14\xc4\xbf\xbb\xc8v\x88\x12"|5_\x8e\x0f\xf8\\<\x95\xfd\xf4 \x1b3\xcc\x99d\x93I\xca\xc5\xb5)=\xc9v]7\x1dI\x82\xa7\x06a\x9bg={\xa0$_Dd\xbb\\\x8b\x ...

# %% [markdown]
# **From the content, it appears to start with the bytes "PK\x03\......", which suggests that it might be a ZIP archive file. How do I know it? Experience! I have worked with something similar earlier.**

# %% [markdown]
# ## **Step 5 - Unzipping the content of 385th row and decoding using `latin-1`**

# %%
import zipfile
import io

# Assuming 'content' is the binary data from your database
binary_data = df.iloc[385, 2]

# Decompress the binary data using the zipfile module
with io.BytesIO(binary_data) as f:
    with zipfile.ZipFile(f, 'r') as zip_file:
        # Reading only one file in the ZIP archive
        subtitle_content = zip_file.read(zip_file.namelist()[0])

# Now 'subtitle_content' should contain the extracted subtitle content
print(subtitle_content.decode('latin-1'))  # Assuming the content is latin-1 encoded text
# Out:
# 1
# 00:00:06,000 --> 00:00:12,074
# Watch any video online with Open-SUBTITLES
# Free Browser extension: osdb.link/ext
#
# 2
# 00:00:15,370 --> 00:00:16,506
# You lose everything, my girl.
#
# 3
# 00:00:16,530 --> 00:00:19,360
# So you've said - four times.
#
# 4
# 00:00:20,330 --> 00:00:22,120
# I definitely had
# it on yesterday.
#
# 5
# 00:00:22,465 --> 00:00:25,785
# Your gloves, your keys, that
# handkerchief I embroidered for you
#
# 6
# 00:00:25,809 --> 00:00:26,168
# Everything!
#
# 7
# 00:00:26,192 --> 00:00:27,280
# Five times.
#
# 8
# 00:00:31,610 --> 00:00:32,920
# Miss Scarlet?
# - Yes.
#
# 9
# 00:00:36,390 --> 00:00:37,390
# I'm Miss Scarlet.
#
# 10
# 00:00:37,872 --> 00:00:40,880
# May I inquire if
# you've lost something?
#
# 11
# 00:00:41,350 --> 00:00:42,530
# Some jewellery perhaps?
#
# 12
# 00:00:42,870 --> 00:00:45,130
# Yes, my mother's wedding ring.
#
# 13
# 00:00:45,220 --> 00:00:45,840
# Have you found it?
#
# 14
# 00:00:45,950 --> 00:00:47,656
# Does your ring have
# an inscription?
#
# 15
# 00:00:48,650 --> 00:00:51,720
# From my father to my mother 'For
# my beloved, Livinia Scarlet'
#
# 16
# 00:00:52,370 --> 00:00:53,370
# Then it is yours.
#
# 17
# 00:00:53,630 --> 00:00:56,760
# I told you so many times to get
# it resized, but does she listen?
#
# 18
# 00:00:57,350 --> 00:01:00,392
# It was found last night in the
# city mortuary by a Mr Potts.
#
# 19
# 00:01:00,532 --> 00:01:01,798
# Is she the one that calls you
#
# 20
# 00:01:01,821 --> 00:01:04,235
# an unchristian woman the
# morals of an alley cat.
#
# 21
# 00:01:04,490 --> 00:01:05,490
# Yes, that's the one.
#
# 22
# 00:01:07,320 --> 00:01:08,330
# You're under arrest.
#
# 23
# 00:01:08,678 --> 00:01:10,709
# What? Why?
#
# 24
# 00:01:10,826 --> 00:01:13,180
# For breaking and entering
# the city mortuary.
#
# 25
# 00:01:14,810 --> 00:01:15,940
# Find Inspector Wellington.
#
# 26
# 00:01:28,060 --> 00:01:29,900
# Duke, the door.
#
# 27
# 00:01:32,280 --> 00:01:33,280
# Hmm.
#
# 28
# 00:01:34,420 --> 00:01:35,420
# Duke.
#
# 29
# 00:01:36,540 --> 00:01:38,730
# It's your house, you get it.
#
# 30
# 00:01:51,500 --> 00:01:52,640
# Sorry to bother you,
#
# 31
# 00:01:52,720 --> 00:01:55,090
# but I wondered if Inspector
# Wellington was there.
#
# 32
# 00:01:57,850 --> 00:01:58,850
# You've got a visitor.
#
# 33
# 00:01:59,279 --> 00:02:00,959
# Inspector Wellington!
#
# 34
# 00:02:01,730 --> 00:02:02,780
# I need your help.
#
# 35
# 00:02:04,840 --> 00:02:05,840
# It's Eliza.
#
# 36
# 00:02:06,778 --> 00:02:08,166
# She's been arrested.
#
# 37
# 00:02:08,190 --> 00:02:10,550
# Tell her it's my day off.
#
# 38
# 00:02:13,980 --> 00:02:15,060
# Who is this Eliza?
#
# 39
# 00:02:25,180 --> 00:02:26,350
# She's not my wife.
#
# 40
# 00:02:31,940 --> 00:02:32,940
# Ready inspector?
#
# 41
# 00:02:34,000 --> 00:02:35,830
# Miss Scarlet really
# does need your help.
#
# 42
# 00:03:20,936 --> 00:03:23,430
# There's clearly been a
# misunderstanding Detective Phelps.
#
# 43
# 00:03:23,570 --> 00:03:25,530
# Not that I wish to tell
# you how to do your job.
#
# 44
# 00:03:25,720 --> 00:03:28,870
# You being an extremely
# experienced, well regarded officer,
#
# 45
# 00:03:29,420 --> 00:03:31,180
# I'm simply perplexed as
# to what has happened.
#
# 46
# 00:03:32,240 --> 00:03:33,940
# Well, let me enlighten
# you, Miss Scarlet.
#
# 47
# 00:03:37,310 --> 00:03:42,290
# Last night someone smashed the window
# of the city mortuary and broke in.
#
# 48
# 00:03:43,270 --> 00:03:45,740
# They then gained access
# to the clerical office
#
# 49
# 00:03:45,820 --> 00:03:50,350
# inside and stole some
# highly confidential files.
#
# 50
# 00:03:51,780 --> 00:03:52,520
# Well, if that is true
#
# 51
# 00:03:52,600 --> 00:03:54,276
# then it's both deplorable
# and a disgrace.
#
# 52
# 00:03:54,345 --> 00:03:56,923
# Words shared by the clerk
# of the mortuary, Mr Potts,
#
# 53
# 00:03:56,960 --> 00:04:00,670
# although in his case he used them to
# describe you rather than the situation.
#
# 54
# 00:04:00,710 --> 00:04:02,246
# I know that man's opinion of me.
#
# 55
# 00:04:02,271 --> 00:04:04,122
# 'An unscrupulous woman'
#
# 56
# 00:04:04,260 --> 00:04:07,030
# 'who is as trustworthy
# as a bag of snakes'.
#
# 57
# 00:04:07,780 --> 00:04:09,680
# The fact is, I'm no thief.
#
# 58
# 00:04:10,040 --> 00:04:12,020
# So glad you brought up
# facts, Miss Scarlet,
#
# 59
# 00:04:12,100 --> 00:04:14,420
# because the fact
# remains that your ring
#
# 60
# 00:04:14,500 --> 00:04:15,810
# was found at the crime scene.
#
# 61
# 00:04:23,510 --> 00:04:25,500
# Well, I have no idea
# how it got there.
#
# 62
# 00:04:26,490 --> 00:04:29,220
# Women aren't even allowed in
# the mortuary - quite right too.
#
# 63
# 00:04:29,310 --> 00:04:30,820
# It's no place for a lady.
#
# 64
# 00:04:33,580 --> 00:04:34,580
# Morning to you.
#
# 65
# 00:04:36,875 --> 00:04:38,960
# I'll take you from
# here Detective Phelps.
#
# 66
# 00:04:39,830 --> 00:04:40,830
# Thank God for that.
#
# 67
# 00:04:43,950 --> 00:04:45,606
# I'm sorry to have dragged
# you into this, William.
#
# 68
# 00:04:45,630 --> 00:04:47,100
# On my day off.
#
# 69
# 00:04:47,880 --> 00:04:49,970
# Oh. Were you doing
# something nice?
#
# 70
# 00:04:52,350 --> 00:04:55,070
# I have no idea how my mother's ring
# found its way to the crime scene.
#
# 71
# 00:04:55,760 --> 00:04:56,679
# It's a puzzle indeed.
#
# 72
# 00:04:56,757 --> 00:04:58,957
# Do you think I was
# born yesterday?
#
# 73
# 00:05:00,200 --> 00:05:00,950
# I'm warning you, Eliza.
#
# 74
# 00:05:01,000 --> 00:05:03,340
# The next words out of your
# mouth better be the truth
#
# 75
# 00:05:03,420 --> 00:05:05,130
# or I'll take you down
# to the cells myself.
#
# 76
# 00:05:07,334 --> 00:05:09,720
# All right. I did go to
# the mortuary yesterday.
#
# 77
# 00:05:10,130 --> 00:05:12,530
# I have numerous outstanding
# cases which I could progress with
#
# 78
# 00:05:12,590 --> 00:05:14,750
# if Mr Potts would share some
# basic information with me.
#
# 79
# 00:05:14,810 --> 00:05:16,726
# But he refuses to treat me
# like a fellow professional.
#
# 80
# 00:05:16,750 --> 00:05:19,160
# So I have no choice but to
# break in like a common criminal
#
# 81
# 00:05:19,240 --> 00:05:20,440
# and check the files myself.
#
# 82
# 00:05:20,790 --> 00:05:22,496
# I must have dropped my
# mother's ring whilst there,
#
# 83
# 00:05:22,520 --> 00:05:23,890
# hence this misunderstanding.
#
# 84
# 00:05:24,350 --> 00:05:25,385
# So let me get this straight..
#
# 85
# 00:05:25,409 --> 00:05:26,954
# Last night you broke
# into the city mortuary
#
# 86
# 00:05:26,978 --> 00:05:29,186
# and stole files
# from Potts' office.
#
# 87
# 00:05:29,210 --> 00:05:31,290
# Where exactly is the
# misunderstanding?
#
# 88
# 00:05:31,380 --> 00:05:32,450
# I never stole anything.
#
# 89
# 00:05:33,100 --> 00:05:35,007
# I looked at the files
# and put them back.
#
# 90
# 00:05:35,367 --> 00:05:37,159
# And it wasn't last night,
# it was yesterday afternoon
#
# 91
# 00:05:37,183 --> 00:05:38,628
# when Mr Potts was out for lunch.
#
# 92
# 00:05:38,785 --> 00:05:40,416
# And I didn't break in.
#
# 93
# 00:05:40,440 --> 00:05:41,680
# Why would I want to have a key?
#
# 94
# 00:05:43,378 --> 00:05:45,760
# You duplicated a key
# for the city mortuary?
#
# 95
# 00:05:45,800 --> 00:05:46,800
# What choice do I have?
#
# 96
# 00:05:49,270 --> 00:05:51,830
# Someone else broke into the mortuary
# last night and it wasn't me.
#
# 97
# 00:05:52,382 --> 00:05:53,765
# I wouldn't lie to you, William.
#
# 98
# 00:05:53,796 --> 00:05:55,460
# That's a blatant lie in itself.
#
# 99
# 00:05:59,840 --> 00:06:01,780
# Miss Scarlet.
# - Detective Fitzroy.
#
# 100
# 00:06:03,020 --> 00:06:04,020
# New haircut?
#
# 101
# 00:06:04,450 --> 00:06:05,450
# Very smart.
#
# 102
# 00:06:07,540 --> 00:06:09,570
# Sir, I have a message for you.
#
# 103
# 00:06:09,840 --> 00:06:12,390
# I thought I told you I wasn't
# here. I'm on my day off.
#
# 104
# 00:06:12,660 --> 00:06:14,620
# Yes Sir, but the Superintendent
# has asked for you.
#
# 105
# 00:06:14,800 --> 00:06:15,800
# He says it's urgent.
#
# 106
# 00:06:20,920 --> 00:06:23,290
# Do not move.
#
# 107
# 00:06:25,110 --> 00:06:26,110
# William.
#
# 108
# 00:06:26,700 --> 00:06:27,700
# William..
#
# 109
# 00:06:30,480 --> 00:06:31,640
# You do believe me, don't you?
#
# 110
# 00:06:32,060 --> 00:06:34,530
# This is an extremely serious
# offence that you're accused of.
#
# 111
# 00:06:34,900 --> 00:06:36,910
# It's going to be damn hard
# to prove it wasn't you.
#
# 112
# 00:06:40,270 --> 00:06:41,270
# Come in!
#
# 113
# 00:06:43,170 --> 00:06:45,080
# Ah, Wellington. This
# is Mr Thackeray.
#
# 114
# 00:06:46,130 --> 00:06:47,130
# Good morning, sir.
#
# 115
# 00:06:47,250 --> 00:06:48,140
# I hope it is a good
# morning, Inspector..
#
# 116
# 00:06:48,220 --> 00:06:49,620
# It's been a bloody awful night,
#
# 117
# 00:06:49,700 --> 00:06:50,700
# that's for sure.
#
# 118
# 00:06:51,350 --> 00:06:52,880
# Mr Thackery is
# the chief coroner.
#
# 119
# 00:06:54,550 --> 00:06:55,898
# The break in at city mortuary?
#
# 120
# 00:06:55,961 --> 00:06:56,961
# Break ins.
#
# 121
# 00:06:57,710 --> 00:07:00,169
# Plural. We've just had word that
# the mortuaries in Kentish Town
#
# 122
# 00:07:00,193 --> 00:07:02,580
# and Swiss Cottage were
# broken into last night.
#
# 123
# 00:07:02,817 --> 00:07:04,727
# Confidential files
# stolen from each.
#
# 124
# 00:07:04,809 --> 00:07:06,620
# I believe you have the
# perpetrator in custody.
#
# 125
# 00:07:07,010 --> 00:07:08,010
# We do indeed, Edmund.
#
# 126
# 00:07:08,870 --> 00:07:10,890
# That woman has a history
# of breaking the law.
#
# 127
# 00:07:11,370 --> 00:07:14,050
# My man in the city has had to
# deal with her time and time again,
#
# 128
# 00:07:14,130 --> 00:07:15,560
# but this time
# she's gone too far.
#
# 129
# 00:07:16,170 --> 00:07:17,640
# The lady detective..
#
# 130
# 00:07:18,271 --> 00:07:19,271
# What nonsense.
#
# 131
# 00:07:19,590 --> 00:07:22,990
# So Miss Scarlet has had some
# minor grievances with the clerk
#
# 132
# 00:07:23,070 --> 00:07:24,456
# who runs the city
# mortuary service.
#
# 133
# 00:07:24,480 --> 00:07:26,326
# There was evidence found
# at one of the crime scenes
#
# 134
# 00:07:26,350 --> 00:07:27,401
# that places her there.
#
# 135
# 00:07:27,441 --> 00:07:28,948
# Surely you are working
# under the assumption
#
# 136
# 00:07:28,972 --> 00:07:31,340
# that whoever did one break in
# must have done the other two.
#
# 137
# 00:07:31,490 --> 00:07:33,105
# Yes, that would be
# the assumption, sir.
#
# 138
# 00:07:33,130 --> 00:07:34,901
# I want that woman
# charged without delay.
#
# 139
# 00:07:35,129 --> 00:07:36,129
# It's all in hand.
#
# 140
# 00:07:37,465 --> 00:07:39,892
# Take Miss Scarlet directly to
# Holloway. She can be kept there whilst
#
# 141
# 00:07:39,916 --> 00:07:41,438
# further investigations
# are undertaken.
#
# 142
# 00:07:41,462 --> 00:07:43,172
# Further Investgation? What
# need is there of that?
#
# 143
# 00:07:43,196 --> 00:07:44,956
# You've got all the
# evidence you need. Fergus.
#
# 144
# 00:07:46,210 --> 00:07:47,447
# Charge her.
# - But Sir..
#
# 145
# 00:07:47,471 --> 00:07:48,751
# That's an order, Inspector.
#
# 146
# 00:07:51,030 --> 00:07:52,030
# Yes, Sir.
#
# 147
# 00:08:04,360 --> 00:08:05,360
# Sorry, Eliza.
#
# 148
# 00:08:13,880 --> 00:08:14,430
# Where is she?
#
# 149
# 00:08:14,580 --> 00:08:17,410
# I wish I knew so I could
# give her a piece of my mind.
#
# 150
# 00:08:17,580 --> 00:08:20,110
# She does nothing but
# worry the life out of me.
#
# 151
# 00:08:20,360 --> 00:08:21,730
# Not only is she now a fugitive,
#
# 152
# 00:08:21,810 --> 00:08:25,700
# but she's also made a
# complete fool out of me again.
#
# 153
# 00:08:26,680 --> 00:08:28,390
# I'm as frantic to
# find her as you are.
#
# 154
# 00:08:28,520 --> 00:08:29,790
# God knows where she is.
#
# 155
# 00:08:29,880 --> 00:08:31,850
# God knows what danger she's in.
#
# 156
# 00:08:32,020 --> 00:08:34,580
# Well, not as much danger as she'll
# be when I get my hands on her.
#
# 157
# 00:08:34,700 --> 00:08:37,230
# Please do not talk
# like that Inspector,
#
# 158
# 00:08:37,320 --> 00:08:39,020
# it's not gentlemanly.
#
# 159
# 00:08:39,520 --> 00:08:41,890
# Do you have any idea how
# much trouble she's in?
#
# 160
# 00:08:42,740 --> 00:08:43,850
# Then you must help her.
#
# 161
# 00:08:44,120 --> 00:08:45,990
# How can I when I don't
# know where she is?
#
# 162
# 00:08:50,160 --> 00:08:52,036
# There was one person who
# might know her whereabouts
#
# 163
# 00:08:52,060 --> 00:08:54,290
# and I have my men hunting
# him down as we speak.
#
# 164
# 00:08:54,680 --> 00:08:56,900
# If Moses so much as sneezes,
#
# 165
# 00:08:56,980 --> 00:08:58,700
# we will be down on him
# like a ton of bricks.
#
# 166
# 00:08:58,970 --> 00:09:01,210
# What makes you think
# Moses knows anything?
#
# 167
# 00:09:01,780 --> 00:09:03,100
# Those two are thick as thieves?
#
# 168
# 00:09:04,060 --> 00:09:06,330
# If you see her or
# you hear from her,
#
# 169
# 00:09:06,440 --> 00:09:08,490
# then you send for
# me Ivy, immediately.
#
# 170
# 00:09:20,720 --> 00:09:22,040
# Are you sure you
# weren't followed?
#
# 171
# 00:09:26,990 --> 00:09:29,190
# Why do people
# always ask me that?
#
# 172
# 00:09:30,270 --> 00:09:31,550
# I'm worried about my girl.
#
# 173
# 00:09:32,940 --> 00:09:34,970
# Are you certain this is
# the right thing to do?
#
# 174
# 00:09:35,970 --> 00:09:36,970
# Just stick to the plan.
#
# 175
# 00:09:39,360 --> 00:09:40,400
# I don't think I can do it.
#
# 176
# 00:09:42,420 --> 00:09:44,590
# You just lied to the
# Detective Inspector.
#
# 177
# 00:09:45,450 --> 00:09:46,860
# You can do this.
#
# 178
# 00:09:55,500 --> 00:09:56,500
# Gone.
#
# 179
# 00:09:56,610 --> 00:09:57,438
# Gone where?
#
# 180
# 00:09:57,594 --> 00:09:58,594
# I don't know sir.
#
# 181
# 00:09:58,641 --> 00:10:02,031
# So a prime suspect who was in
# your custody has done a runner.
#
# 182
# 00:10:02,830 --> 00:10:04,860
# You're unable to
# locate her, a woman.
#
# 183
# 00:10:05,350 --> 00:10:06,590
# She's a private detective, Sir.
#
# 184
# 00:10:06,630 --> 00:10:08,460
# She has contacts..
# - Are you not one of them?
#
# 185
# 00:10:08,790 --> 00:10:10,486
# I can assure you that I've
# had no hand in this, sir.
#
# 186
# 00:10:10,510 --> 00:10:12,220
# I can also assure you
# that Eliza Scarlet
#
# 187
# 00:10:12,300 --> 00:10:14,565
# is not the perpetrator. We're
# barking up the wrong tree.
#
# 188
# 00:10:14,604 --> 00:10:15,604
# Enough!
#
# 189
# 00:10:20,340 --> 00:10:21,776
# Now it seems to me
# we have a conflict
#
# 190
# 00:10:21,800 --> 00:10:22,800
# of interest here,
#
# 191
# 00:10:23,089 --> 00:10:25,750
# so I'm going to recommend
# you'll move to another case,
#
# 192
# 00:10:25,987 --> 00:10:27,087
# With all due respect, Sir,
#
# 193
# 00:10:27,160 --> 00:10:28,020
# that would be a mistake.
#
# 194
# 00:10:28,137 --> 00:10:30,146
# The chief coroner's a man
# of connection and influence.
#
# 195
# 00:10:30,170 --> 00:10:32,330
# Whose going to make my
# life extremely difficult.
#
# 196
# 00:10:33,470 --> 00:10:34,510
# Give me one more day, sir.
#
# 197
# 00:10:37,185 --> 00:10:39,785
# Now, I have not long been in this
# job laddie and I can assure you
#
# 198
# 00:10:39,850 --> 00:10:41,980
# you do not want to be
# the reason I lose it.
#
# 199
# 00:10:43,580 --> 00:10:44,580
# You have your day.
#
# 200
# 00:10:45,990 --> 00:10:46,990
# Find her!
#
# 201
# 00:10:48,230 --> 00:10:49,230
# Yes, Sir.
#
# 202
# 00:10:56,830 --> 00:10:59,620
# What a privilege it is
# to have such a visit.
#
# 203
# 00:11:00,290 --> 00:11:02,430
# Not since Prince Albert himself
#
# 204
# 00:11:02,510 --> 00:11:04,420
# graced us to open
# our new autopsy wing
#
# 205
# 00:11:04,518 --> 00:11:06,282
# have I been so honoured.
#
# 206
# 00:11:06,344 --> 00:11:08,429
# And the honour is
# all mine, Mr. Potts.
#
# 207
# 00:11:08,610 --> 00:11:12,766
# I am merely here at the request
# of my husband, Mr Thackery.
#
# 208
# 00:11:12,961 --> 00:11:16,883
# 'Cecilia', he said. 'You
# must pay Mr Potts a visit'
#
# 209
# 00:11:16,946 --> 00:11:20,726
# 'and see is he quite well after
# such a distressing episode'.
#
# 210
# 00:11:20,781 --> 00:11:25,670
# The notion of the chief coroner
# giving an employee as lowly as myself
#
# 211
# 00:11:25,725 --> 00:11:29,020
# any thought is.. That's
# comfort indeed, Mrs Thackery.
#
# 212
# 00:11:30,270 --> 00:11:34,060
# But this business, with the break-in
# has left me feeling somewhat violated.
#
# 213
# 00:11:34,450 --> 00:11:36,640
# To think someone
# came into this, my
#
# 214
# 00:11:37,302 --> 00:11:40,820
# private sanctuary
# without authorization.
#
# 215
# 00:11:41,550 --> 00:11:45,940
# I say someone, but I know exactly
# who it was and so do the police.
#
# 216
# 00:11:46,250 --> 00:11:48,240
# Yes, my husband told
# me all about it.
#
# 217
# 00:11:48,417 --> 00:11:50,027
# Some young woman, was it not?
#
# 218
# 00:11:50,080 --> 00:11:54,500
# I hear she's a private investigator.
# What a curious job for a lady.
#
# 219
# 00:11:54,620 --> 00:11:56,380
# There's nothing of the
# lady about that woman.
#
# 220
# 00:11:57,020 --> 00:11:58,640
# What exactly was it she stole?
#
# 221
# 00:11:59,940 --> 00:12:02,986
# I thought you said your husband
# told you all about it, Mrs Thackery?
#
# 222
# 00:12:03,361 --> 00:12:05,090
# He did indeed, but..
#
# 223
# 00:12:05,790 --> 00:12:09,360
# I have quite forgotten. Ah,
# you know how us ladies are..
#
# 224
# 00:12:09,440 --> 00:12:13,880
# It's hard to retain too much
# information at any one time.
#
# 225
# 00:12:16,110 --> 00:12:17,110
# I do not believe you.
#
# 226
# 00:12:20,560 --> 00:12:23,850
# It is abundantly clear to me
# that a lady such as yourself
#
# 227
# 00:12:26,640 --> 00:12:28,950
# possesses great brains
# as well as beauty.
#
# 228
# 00:12:31,190 --> 00:12:32,190
# You're kind, Mr. Potts.
#
# 229
# 00:12:33,190 --> 00:12:37,836
# But it is nevertheless true that
# the details have quite evaded me.
#
# 230
# 00:12:38,031 --> 00:12:41,430
# Would you mind if we did
# not discuss that woman?
#
# 231
# 00:12:42,340 --> 00:12:44,410
# I have to be mindful
# of my blood pressure
#
# 232
# 00:12:44,490 --> 00:12:47,740
# and she has a habit of
# causing me great vexation.
#
# 233
# 00:12:50,726 --> 00:12:51,726
# Tea.
#
# 234
# 00:12:53,580 --> 00:12:56,450
# Goodness, I'd quite forgotten
# the reason for my visit.
#
# 235
# 00:12:56,740 --> 00:13:00,160
# My husband and I would like
# to invite you for dinner.
#
# 236
# 00:13:01,570 --> 00:13:02,570
# This evening.
#
# 237
# 00:13:03,500 --> 00:13:04,940
# At the chief coroner's house?
#
# 238
# 00:13:05,020 --> 00:13:08,130
# And I will endeavour to keep
# my questions to a minimum.
#
# 239
# 00:13:08,560 --> 00:13:11,400
# I'd hate to cause
# undue vexation.
#
# 240
# 00:13:12,026 --> 00:13:14,440
# I... Mrs Thackery, nonsense...
#
# 241
# 00:13:15,590 --> 00:13:16,920
# What is it you wish to know?
#
# 242
# 00:13:24,980 --> 00:13:28,070
# Confidential files were stolen
# from all three mortuaries.
#
# 243
# 00:13:28,260 --> 00:13:32,350
# They contained lists of unidentified
# bodies who died 25 years ago
#
# 244
# 00:13:32,490 --> 00:13:34,190
# in the August of 1857.
#
# 245
# 00:13:36,185 --> 00:13:37,300
# Anything else taken?
#
# 246
# 00:13:38,638 --> 00:13:39,950
# We should let Eliza know.
#
# 247
# 00:13:40,099 --> 00:13:41,099
# Not yet.
#
# 248
# 00:13:41,297 --> 00:13:43,531
# She must lie low until
# I've found out more.
#
# 249
# 00:13:43,875 --> 00:13:46,880
# Where exactly is this safe
# house she's holed up in?
#
# 250
# 00:13:47,210 --> 00:13:48,420
# I hope it's respectable.
#
# 251
# 00:13:48,930 --> 00:13:51,820
# It's not exactly
# Claridges, but it will do.
#
# 252
# 00:13:55,128 --> 00:13:56,128
# Oh my God.
#
# 253
# 00:13:58,932 --> 00:14:00,815
# Miss Scarlet,
# welcome to my castle.
#
# 254
# 00:14:00,980 --> 00:14:02,260
# I hope you've made
# yourself home.
#
# 255
# 00:14:02,412 --> 00:14:03,612
# Yes, yes.
#
# 256
# 00:14:04,128 --> 00:14:06,560
# Moses has shown me
# all the amenities.
#
# 257
# 00:14:07,120 --> 00:14:08,800
# Thank you for allowing
# me to shelter here.
#
# 258
# 00:14:09,200 --> 00:14:11,810
# I have allegations made against
# me that are completely false.
#
# 259
# 00:14:12,320 --> 00:14:13,320
# Aren't they always?
#
# 260
# 00:14:15,290 --> 00:14:19,000
# So what are these
# false allegations?
#
# 261
# 00:14:19,330 --> 00:14:22,020
# It's a break in at
# the city mortuary
#
# 262
# 00:14:22,059 --> 00:14:24,255
# and for your information
# the claims are false.
#
# 263
# 00:14:24,372 --> 00:14:25,614
# On Bow Lane?
#
# 264
# 00:14:25,911 --> 00:14:26,395
# Mm..
#
# 265
# 00:14:26,419 --> 00:14:28,660
# My sister Clementine
# works that steet?
#
# 266
# 00:14:29,370 --> 00:14:30,840
# Your sister's called
# Clementine, too?
#
# 267
# 00:14:30,990 --> 00:14:33,790
# All my sisters are. Made it easy for
# our mother to remember who's who..
#
# 268
# 00:14:35,760 --> 00:14:37,391
# If something happened
# on my sister's patch
#
# 269
# 00:14:37,415 --> 00:14:39,860
# she'd know about it,
# 'orrible though she is.
#
# 270
# 00:14:40,720 --> 00:14:42,220
# I could pay her a visit though.
#
# 271
# 00:14:42,980 --> 00:14:44,350
# See if she knows anything.
#
# 272
# 00:14:44,571 --> 00:14:45,868
# I'd be most grateful.
#
# 273
# 00:14:45,931 --> 00:14:46,971
# How grateful?
#
# 274
# 00:14:58,880 --> 00:15:00,650
# I take great risk
# in going to see her.
#
# 275
# 00:15:00,776 --> 00:15:03,442
# Last week she punched
# a dog in the face.
#
# 276
# 00:15:06,760 --> 00:15:08,550
# This Moses is the key.
#
# 277
# 00:15:08,680 --> 00:15:10,690
# If anyone can lead
# us to her, it's him.
#
# 278
# 00:15:10,781 --> 00:15:12,804
# Sir, I've got the information
# that you asked for.
#
# 279
# 00:15:12,930 --> 00:15:13,930
# Get to it.
#
# 280
# 00:15:18,290 --> 00:15:19,396
# Did I say something wrong, Sir?
#
# 281
# 00:15:19,420 --> 00:15:20,420
# Shut the door first, Roy.
#
# 282
# 00:15:23,860 --> 00:15:26,064
# Now, I do not believe that
# Miss Scarlet is guilty in this
#
# 283
# 00:15:26,088 --> 00:15:27,748
# but my orders are to find her,
#
# 284
# 00:15:27,835 --> 00:15:29,685
# not to go looking for
# alternative perpetrators.
#
# 285
# 00:15:29,800 --> 00:15:32,610
# So this line of inquiry is to
# remain strictly between us.
#
# 286
# 00:15:35,770 --> 00:15:37,290
# You have a problem
# with that detective?
#
# 287
# 00:15:40,580 --> 00:15:41,705
# No, Sir.
#
# 288
# 00:15:41,963 --> 00:15:43,323
# I do not have a
# problem with that.
#
# 289
# 00:15:43,378 --> 00:15:44,378
# Good.
#
# 290
# 00:15:45,370 --> 00:15:46,530
# And what have you got for me?
#
# 291
# 00:15:46,790 --> 00:15:48,766
# The files stolen from each
# of the three mortuaries
#
# 292
# 00:15:48,790 --> 00:15:51,530
# contain a list of unidentified
# bodies from August 1857.
#
# 293
# 00:15:51,680 --> 00:15:53,146
# Yes, yes, tell me
# something I don't know.
#
# 294
# 00:15:53,170 --> 00:15:54,250
# Then I searched for a link,
#
# 295
# 00:15:54,310 --> 00:15:55,830
# male, female, similar ages,
#
# 296
# 00:15:55,910 --> 00:15:56,910
# cause of death,
#
# 297
# 00:15:57,170 --> 00:16:00,361
# but unfortunately those details only exist
# in records at the cemeteries themselves,
#
# 298
# 00:16:00,385 --> 00:16:02,605
# but I managed to find
# maps of each cemetery
#
# 299
# 00:16:02,662 --> 00:16:04,006
# and where the
# graves are located.
#
# 300
# 00:16:04,061 --> 00:16:05,319
# I've marked them with an X.
#
# 301
# 00:16:07,470 --> 00:16:08,670
# How many cemeteries are there?
#
# 302
# 00:16:09,110 --> 00:16:11,800
# 14 Sir, with one
# pauper grave in each.
#
# 303
# 00:16:12,917 --> 00:16:13,807
# Shall I come with you, Sir?
#
# 304
# 00:16:13,890 --> 00:16:15,280
# No, I need to do this quietly.
#
# 305
# 00:16:15,430 --> 00:16:16,260
# Go back to your duties.
#
# 306
# 00:16:16,430 --> 00:16:17,430
# Yes, Sir.
#
# 307
# 00:16:25,900 --> 00:16:27,770
# Clementine, where have you been?
#
# 308
# 00:16:27,860 --> 00:16:29,130
# You've been gone for hours.
#
# 309
# 00:16:31,350 --> 00:16:32,350
# Did you see your sister?
#
# 310
# 00:16:32,781 --> 00:16:33,491
# What did she say?
#
# 311
# 00:16:33,593 --> 00:16:35,186
# Does she know anything
# about the break-in?
#
# 312
# 00:16:35,210 --> 00:16:37,120
# Saw her.. very nice.. well..
#
# 313
# 00:16:37,233 --> 00:16:38,233
# Whatever..
#
# 314
# 00:16:38,435 --> 00:16:41,315
# Yeah, it wasn't very good since the
# wrestling match with our grandmother.
#
# 315
# 00:16:41,420 --> 00:16:42,420
# She saw the real thief?
#
# 316
# 00:16:43,430 --> 00:16:44,430
# Clementine..
#
# 317
# 00:16:45,060 --> 00:16:46,060
# Clementine.
#
# 318
# 00:16:48,977 --> 00:16:49,977
# Oh!
#
# 319
# 00:17:21,470 --> 00:17:22,920
# You should be
# ashamed of yourself.
#
# 320
# 00:17:23,850 --> 00:17:25,060
# I'm calling the police!
#
# 321
# 00:17:28,110 --> 00:17:29,110
# Stop.
#
# 322
# 00:17:32,960 --> 00:17:34,080
# I'm a police officer, madam.
#
# 323
# 00:17:34,820 --> 00:17:35,820
# Are you all right?
#
# 324
# 00:17:36,910 --> 00:17:38,880
# Just a little shaken, my
# husband's the vicar here.
#
# 325
# 00:17:39,690 --> 00:17:40,690
# He's away on business.
#
# 326
# 00:17:40,830 --> 00:17:41,830
# I'm all alone.
#
# 327
# 00:17:44,880 --> 00:17:45,880
# Poor soul.
#
# 328
# 00:17:46,300 --> 00:17:47,300
# Those grave robbers,
#
# 329
# 00:17:47,370 --> 00:17:48,380
# they have no morals.
#
# 330
# 00:17:49,180 --> 00:17:50,380
# Do you know who's buried here?
#
# 331
# 00:17:51,890 --> 00:17:52,890
# No one knows.
#
# 332
# 00:17:53,400 --> 00:17:54,400
# Pauper grave.
#
# 333
# 00:18:07,629 --> 00:18:10,080
# I was in my parlour
# in the vicarage.
#
# 334
# 00:18:10,148 --> 00:18:12,630
# I like to carry out my
# correspondence there.
#
# 335
# 00:18:13,293 --> 00:18:14,965
# So, what alerted
# you to the robbers?
#
# 336
# 00:18:15,113 --> 00:18:18,020
# I was writing to
# my sister Agatha,
#
# 337
# 00:18:18,570 --> 00:18:20,180
# I heard a noise outside.
#
# 338
# 00:18:20,590 --> 00:18:22,940
# We weren't expecting
# any burials today.
#
# 339
# 00:18:23,070 --> 00:18:25,660
# My husband's away
# on church business,
#
# 340
# 00:18:26,230 --> 00:18:30,380
# staying with the Archbishop
# himself in Canterbury
#
# 341
# 00:18:30,830 --> 00:18:33,260
# So you heard a noise outside?
#
# 342
# 00:18:33,510 --> 00:18:35,870
# I went out to see what it
# was and instantly I knew.
#
# 343
# 00:18:36,950 --> 00:18:42,750
# Body snatchers. It's a lucrative trade
# selling corpses to the medical profession.
#
# 344
# 00:18:42,900 --> 00:18:45,140
# They supply bodies
# for anatomy classes.
#
# 345
# 00:18:46,386 --> 00:18:47,811
# Dissections.
#
# 346
# 00:18:47,874 --> 00:18:49,940
# Yes, I am aware of the practice.
#
# 347
# 00:18:50,410 --> 00:18:51,720
# I shouted at them to stop.
#
# 348
# 00:18:53,110 --> 00:18:55,760
# They was so shocked that
# someone was at the vicarage.
#
# 349
# 00:18:56,600 --> 00:18:58,170
# They must have assumed it empty.
#
# 350
# 00:18:59,760 --> 00:19:01,580
# Then they saw you, a man..
#
# 351
# 00:19:03,060 --> 00:19:04,420
# Had you not been
# there inspector..
#
# 352
# 00:19:06,640 --> 00:19:08,830
# I dread to think what
# might have happened.
#
# 353
# 00:19:09,900 --> 00:19:11,020
# You got a good look at them?
#
# 354
# 00:19:11,500 --> 00:19:14,110
# One had dark hair
# and the other was..
#
# 355
# 00:19:15,150 --> 00:19:16,150
# Fairer?
#
# 356
# 00:19:16,860 --> 00:19:17,940
# Average build, the pair.
#
# 357
# 00:19:19,190 --> 00:19:22,665
# Any scars, tattoos
# distinguishing features?
#
# 358
# 00:19:22,695 --> 00:19:25,633
# None that I saw but
# they were very grubby.
#
# 359
# 00:19:26,790 --> 00:19:29,730
# Dirt all over their
# faces, their hands.
#
# 360
# 00:19:32,420 --> 00:19:33,420
# I'm sorry.
#
# 361
# 00:19:33,920 --> 00:19:34,920
# I haven't been much help.
#
# 362
# 00:19:35,280 --> 00:19:36,660
# No, you've been most helpful.
#
# 363
# 00:19:37,890 --> 00:19:38,940
# See Mrs Ellis home.
#
# 364
# 00:19:48,597 --> 00:19:49,597
# Jake
#
# 365
# 00:19:50,026 --> 00:19:51,581
# There's been a
# sighting: the Jamaican.
#
# 366
# 00:19:51,644 --> 00:19:52,715
# Do you want me to bring him in?
#
# 367
# 00:19:52,739 --> 00:19:55,090
# No. He's mine.
#
# 368
# 00:20:03,505 --> 00:20:05,120
# And a pound of
# potatoes, please Jim.
#
# 369
# 00:20:05,210 --> 00:20:05,920
# Jim, right?
#
# 370
# 00:20:06,010 --> 00:20:07,100
# Right you are, young lady.
#
# 371
# 00:20:08,530 --> 00:20:09,540
# Mrs Thackery.
#
# 372
# 00:20:11,050 --> 00:20:12,090
# How nice to see you again.
#
# 373
# 00:20:13,580 --> 00:20:14,580
# Mr. Potts..
#
# 374
# 00:20:15,000 --> 00:20:16,900
# What a small world?
#
# 375
# 00:20:17,216 --> 00:20:20,120
# Not really. Mother is
# just around the corner.
#
# 376
# 00:20:20,200 --> 00:20:23,130
# Had to pay her visit to
# impart my most wonderful news.
#
# 377
# 00:20:24,145 --> 00:20:25,145
# Oh?
#
# 378
# 00:20:25,640 --> 00:20:28,676
# The honour of dining with yourself
# and the chief coroner this evening.
#
# 379
# 00:20:28,854 --> 00:20:31,918
# I said mother, I might just
# purchase a new tie for the occasion.
#
# 380
# 00:20:31,943 --> 00:20:32,950
# This one's so special.
#
# 381
# 00:20:34,068 --> 00:20:36,369
# Mother would so love
# to have joined us.
#
# 382
# 00:20:36,393 --> 00:20:38,659
# Well, bring her
# along if you like.
#
# 383
# 00:20:39,791 --> 00:20:42,160
# Mrs Thackery, you
# misunderstand me..
#
# 384
# 00:20:42,710 --> 00:20:43,710
# Mother is dead.
#
# 385
# 00:20:44,710 --> 00:20:46,120
# It is her grave which I visit.
#
# 386
# 00:20:46,760 --> 00:20:50,840
# I felt compelled to share the news
# of this great honor bestowed upon me.
#
# 387
# 00:20:51,258 --> 00:20:53,780
# Well, I really should be going.
#
# 388
# 00:20:53,920 --> 00:20:55,750
# Dinner will not prepare itself.
#
# 389
# 00:20:56,930 --> 00:21:00,083
# I am more than a
# little confused.
#
# 390
# 00:21:00,653 --> 00:21:05,440
# It's most unusual that a lady, such
# as yourself, does her own shopping.
#
# 391
# 00:21:07,430 --> 00:21:11,130
# Indeed, however,
# I wanted to ensure
#
# 392
# 00:21:11,210 --> 00:21:15,200
# that all the ingredients for tonight's
# dinner were of the highest quality.
#
# 393
# 00:21:17,400 --> 00:21:18,400
# I don't know what to say.
#
# 394
# 00:21:19,344 --> 00:21:20,460
# Until this evening, then.
#
# 395
# 00:21:21,368 --> 00:21:22,888
# Until this evening.
#
# 396
# 00:21:26,980 --> 00:21:28,050
# What a delightful lady.
#
# 397
# 00:21:29,200 --> 00:21:32,981
# It is a treat to be in her
# company. A treat indeed.
#
# 398
# 00:21:33,780 --> 00:21:36,330
# Yeah, Ivy is one in a million.
#
# 399
# 00:21:38,433 --> 00:21:39,433
# Ivy?
#
# 400
# 00:21:48,520 --> 00:21:49,520
# Clementine,
#
# 401
# 00:21:49,980 --> 00:21:50,980
# Clementine.
#
# 402
# 00:21:51,534 --> 00:21:53,667
# I've just had the
# loveliest dream.
#
# 403
# 00:21:53,762 --> 00:21:57,059
# Moses took me to Gilbert's, and
# my God did he look handsome.
#
# 404
# 00:21:57,210 --> 00:21:58,900
# What did your sister
# Clementine say?
#
# 405
# 00:21:59,538 --> 00:22:01,148
# Which one - there's five of us?
#
# 406
# 00:22:01,224 --> 00:22:03,497
# The one that witnessed the
# break-in in the city mortuary.
#
# 407
# 00:22:03,584 --> 00:22:07,630
# Oh. Uh.. she said it
# was raining that night
#
# 408
# 00:22:07,710 --> 00:22:10,760
# so she took shelter under
# the arches near the mortuary.
#
# 409
# 00:22:10,853 --> 00:22:12,946
# That's when she saw him him.
# - Him?
#
# 410
# 00:22:13,463 --> 00:22:14,463
# A man.
#
# 411
# 00:22:14,821 --> 00:22:17,180
# Yes, I've gathered that
# but what did he look like?
#
# 412
# 00:22:17,422 --> 00:22:20,071
# Blackest of hair,
# bluest of eyes..
#
# 413
# 00:22:20,141 --> 00:22:22,461
# A crooked smile that would
# make the devil whimper.
#
# 414
# 00:22:22,830 --> 00:22:23,960
# Did she recognise him?
#
# 415
# 00:22:27,160 --> 00:22:28,210
# It's something I suppose.
#
# 416
# 00:22:28,895 --> 00:22:31,082
# Man, black hair, blue eyes.
#
# 417
# 00:22:32,015 --> 00:22:33,695
# You said she was
# sheltering from the rain.
#
# 418
# 00:22:34,175 --> 00:22:35,231
# It wasn't raining that night.
#
# 419
# 00:22:35,255 --> 00:22:37,695
# In fact, it hasn't rained
# for weeks and if it was dark,
#
# 420
# 00:22:37,775 --> 00:22:39,345
# how did she see
# he had blue eyes?
#
# 421
# 00:22:39,795 --> 00:22:41,165
# She's got good eyesight.
#
# 422
# 00:22:41,515 --> 00:22:42,995
# You said she had
# only one working eye.
#
# 423
# 00:22:45,477 --> 00:22:46,777
# You didn't go and see
# your sister, did you?
#
# 424
# 00:22:46,797 --> 00:22:47,836
# You drank my money.
#
# 425
# 00:22:47,852 --> 00:22:49,008
# She's terrifying
#
# 426
# 00:22:49,094 --> 00:22:51,640
# When I was a girl she stole my
# pet mouse and baked it in a pot.
#
# 427
# 00:22:51,657 --> 00:22:53,367
# I want my money back now.
#
# 428
# 00:22:53,517 --> 00:22:55,823
# I'd love to stay and chat
# but I've got to get to work.
#
# 429
# 00:23:12,514 --> 00:23:13,514
# Where is she?
#
# 430
# 00:23:14,154 --> 00:23:16,071
# Grave robbers drink here.
#
# 431
# 00:23:16,571 --> 00:23:18,171
# I said where is she?
#
# 432
# 00:23:18,427 --> 00:23:21,009
# Let me go in, ask around,
#
# 433
# 00:23:21,100 --> 00:23:24,044
# see about those two who
# were running from you.
#
# 434
# 00:23:24,158 --> 00:23:24,897
# How do you know about that?
#
# 435
# 00:23:24,987 --> 00:23:26,359
# You've been following me.
#
# 436
# 00:23:26,390 --> 00:23:30,567
# You're going... forget it, they
# will smell police a mile away.
#
# 437
# 00:23:32,097 --> 00:23:33,457
# And why would you
# want to help me?
#
# 438
# 00:23:33,767 --> 00:23:35,251
# We both know she's innocent
#
# 439
# 00:23:35,259 --> 00:23:38,523
# and those body snatchers
# will lead to the real thief.
#
# 440
# 00:23:38,617 --> 00:23:42,487
# So I will help you help her.
#
# 441
# 00:23:45,427 --> 00:23:46,777
# For a fee, of course.
#
# 442
# 00:23:48,417 --> 00:23:49,537
# I don't work with criminals.
#
# 443
# 00:23:52,007 --> 00:23:53,997
# Shame Miss Scarlet
# doesn't follow my example.
#
# 444
# 00:23:55,757 --> 00:23:56,757
# Good luck.
#
# 445
# 00:24:02,377 --> 00:24:03,887
# You're gonna need it.
#
# 446
# 00:24:16,527 --> 00:24:17,527
# Whiskey.
#
# 447
# 00:24:21,787 --> 00:24:22,787
# There you go.
#
# 448
# 00:24:23,927 --> 00:24:24,927
# Inspector.
#
# 449
# 00:24:39,697 --> 00:24:40,697
# Eliza
#
# 450
# 00:24:47,957 --> 00:24:50,597
# Mr Potts..
# - Do not bother Miss Woods.
#
# 451
# 00:24:52,457 --> 00:24:53,737
# It's your real name, is it not?
#
# 452
# 00:24:54,757 --> 00:24:56,387
# Miss Ivy Woods.
#
# 453
# 00:24:56,951 --> 00:24:59,427
# Yes. Yes it is.
#
# 454
# 00:25:01,132 --> 00:25:02,982
# And I'm so sorry to
# have deceived you.
#
# 455
# 00:25:03,847 --> 00:25:05,037
# It was for a good reason.
#
# 456
# 00:25:05,227 --> 00:25:08,287
# That's never a good reason
# to deceive, Miss Woods.
#
# 457
# 00:25:09,127 --> 00:25:10,545
# It comes as no surprise to me
#
# 458
# 00:25:10,585 --> 00:25:11,945
# that the lady who runs
# the house with that woman
#
# 459
# 00:25:11,969 --> 00:25:15,293
# should herself be
# unchristian in her ways.
#
# 460
# 00:25:15,887 --> 00:25:18,270
# I can assure you I don't
# make a habit of lying.
#
# 461
# 00:25:18,727 --> 00:25:22,043
# I love that girl and I
# do anything to help her.
#
# 462
# 00:25:22,857 --> 00:25:26,117
# I should never have believed
# that the chief coroner
#
# 463
# 00:25:26,197 --> 00:25:29,607
# would even consider inviting
# someone like me for dinner.
#
# 464
# 00:25:29,977 --> 00:25:33,447
# He'd think I'd know my
# place in the world by now.
#
# 465
# 00:25:34,040 --> 00:25:35,467
# And you haven't
# learned Barnabas..
#
# 466
# 00:25:35,617 --> 00:25:37,431
# I really am very sorry Mr Potts.
#
# 467
# 00:25:38,577 --> 00:25:40,759
# I've never done anything
# like this before.
#
# 468
# 00:25:40,939 --> 00:25:41,939
# Hah!
#
# 469
# 00:25:42,797 --> 00:25:43,797
# Take heart, Miss Woods.
#
# 470
# 00:25:45,017 --> 00:25:46,400
# Because you had me fooled.
#
# 471
# 00:25:47,117 --> 00:25:48,117
# Good day.
#
# 472
# 00:25:53,452 --> 00:25:57,014
# Mr Potts, did you spend
# money on a new tie?
#
# 473
# 00:26:08,677 --> 00:26:10,327
# Come on, cough up.
#
# 474
# 00:26:12,247 --> 00:26:14,047
# I think I'll take a lady
# out with my winnings.
#
# 475
# 00:26:16,067 --> 00:26:17,207
# How about..
#
# 476
# 00:26:18,287 --> 00:26:19,287
# Your mum?
#
# 477
# 00:26:24,677 --> 00:26:25,677
# Who's there?
#
# 478
# 00:26:27,067 --> 00:26:28,901
# I'm looking for a
# man about a job.
#
# 479
# 00:26:35,957 --> 00:26:38,551
# The kind that can make
# you serious money.
#
# 480
# 00:26:41,557 --> 00:26:42,557
# Is business good?
#
# 481
# 00:26:43,097 --> 00:26:46,307
# Booming, mate. Be even better if
# I weren't stuck with this ingrate.
#
# 482
# 00:26:47,597 --> 00:26:48,627
# Get on with you.
#
# 483
# 00:27:08,907 --> 00:27:10,707
# Take them to the cells.
# Keep them separate.
#
# 484
# 00:27:10,973 --> 00:27:12,452
# I'll question this one first.
#
# 485
# 00:27:12,477 --> 00:27:13,312
# I've done nothing!
#
# 486
# 00:27:13,344 --> 00:27:14,500
# Shut your mouth!
#
# 487
# 00:27:19,287 --> 00:27:20,755
# I do not like to be manhandled.
#
# 488
# 00:27:21,837 --> 00:27:23,677
# Best part of my
# day, arresting you.
#
# 489
# 00:27:24,647 --> 00:27:25,787
# We need it to look real.
#
# 490
# 00:27:27,357 --> 00:27:28,407
# This was your idea.
#
# 491
# 00:27:30,037 --> 00:27:32,941
# I got you your thief.
# Now it's your turn.
#
# 492
# 00:27:33,677 --> 00:27:35,778
# Well, I'd like to say it was a
# pleasure doing business with you,
#
# 493
# 00:27:35,802 --> 00:27:36,847
# but you know I'd be lying.
#
# 494
# 00:27:38,727 --> 00:27:41,247
# More where that came from, if you
# tell me where Miss Scarlet is.
#
# 495
# 00:27:45,647 --> 00:27:46,777
# I'll be watching you.
#
# 496
# 00:27:48,217 --> 00:27:51,529
# I'd expect nothing
# less, Inspector.
#
# 497
# 00:27:55,327 --> 00:27:57,637
# Why is this Miss Scarlet
# not in prison as we speak?
#
# 498
# 00:27:57,887 --> 00:28:00,497
# How has she evaded the entire
# Metropolitan Police force?
#
# 499
# 00:28:00,727 --> 00:28:02,156
# I know it's not
# ideal, but trust me.
#
# 500
# 00:28:02,180 --> 00:28:03,133
# You had this woman here
#
# 501
# 00:28:03,157 --> 00:28:04,597
# and she slipped
# through your fingers.
#
# 502
# 00:28:04,674 --> 00:28:06,514
# Well, I've had enough of
# this nonsense, Fergus.
#
# 503
# 00:28:06,667 --> 00:28:08,187
# I'm taking this up
# with your superiors.
#
# 504
# 00:28:08,927 --> 00:28:10,996
# Edmund..
# - Out of my way.
#
# 505
# 00:28:13,567 --> 00:28:15,887
# Sir, we have a
# development in the case.
#
# 506
# 00:28:15,981 --> 00:28:17,949
# You have the woman
# back in custody?
#
# 507
# 00:28:18,167 --> 00:28:20,184
# No, Sir, I have
# something better.
#
# 508
# 00:28:23,377 --> 00:28:27,257
# So just to confirm, this is not the
# woman who hired you to rob the grave
#
# 509
# 00:28:27,352 --> 00:28:28,352
# at Highgate Cemetery?
#
# 510
# 00:28:28,577 --> 00:28:29,894
# She was much older.
#
# 511
# 00:28:30,145 --> 00:28:31,843
# And this older woman is the same
#
# 512
# 00:28:31,867 --> 00:28:34,907
# as who you believe broke into
# the three burgled mortuaries.
#
# 513
# 00:28:40,937 --> 00:28:42,177
# How do you know this?
#
# 514
# 00:28:43,837 --> 00:28:46,547
# Because these nicked files
# that you keep banging on about
#
# 515
# 00:28:46,674 --> 00:28:49,293
# - she had them. Paid us to
# dig up every name on there.
#
# 516
# 00:28:49,333 --> 00:28:51,514
# When I say name the
# graves didn't have any.
#
# 517
# 00:28:51,767 --> 00:28:53,005
# All of them pauper graves.
#
# 518
# 00:28:55,227 --> 00:28:56,585
# And what was she looking for?
#
# 519
# 00:28:57,317 --> 00:28:58,632
# Not a bleeding clue.
#
# 520
# 00:28:59,537 --> 00:29:00,547
# But whatever it was
#
# 521
# 00:29:01,377 --> 00:29:03,662
# all she found were
# bags of bones.
#
# 522
# 00:29:04,077 --> 00:29:05,077
# So, what happened?
#
# 523
# 00:29:05,527 --> 00:29:07,037
# Tell me about this woman.
#
# 524
# 00:29:07,817 --> 00:29:10,237
# Name, age, appearance.
#
# 525
# 00:29:10,617 --> 00:29:11,686
# I don't know her name.
#
# 526
# 00:29:12,927 --> 00:29:14,209
# Only that they call her
#
# 527
# 00:29:14,647 --> 00:29:15,709
# Bloody Mary.
#
# 528
# 00:29:16,217 --> 00:29:17,560
# Been inside for years.
#
# 529
# 00:29:18,397 --> 00:29:19,521
# Newgate, I think.
#
# 530
# 00:29:19,977 --> 00:29:23,151
# And as for what she looked like,
# well, you should know - you met her.
#
# 531
# 00:29:23,517 --> 00:29:24,517
# What?
#
# 532
# 00:29:24,597 --> 00:29:26,213
# When me and Watts did
# a runner at Highgate
#
# 533
# 00:29:26,237 --> 00:29:29,603
# We thought she was done for but the silly
# tart couldn't run away in a dress, could she?
#
# 534
# 00:29:29,627 --> 00:29:31,671
# No, the only person I
# met was the vicar's wife,
#
# 535
# 00:29:31,737 --> 00:29:33,258
# a Mrs Ellis.
#
# 536
# 00:29:33,321 --> 00:29:35,254
# That was no vicar's wife mate.
#
# 537
# 00:29:36,577 --> 00:29:37,657
# That was Bloody Mary.
#
# 538
# 00:29:42,157 --> 00:29:44,210
# Just so I'm clear,
# crystal clear,
#
# 539
# 00:29:44,265 --> 00:29:46,263
# you had the perpetrator
# in that very room
#
# 540
# 00:29:46,295 --> 00:29:47,093
# and you let her go.
#
# 541
# 00:29:47,137 --> 00:29:47,945
# Sir, I can only apolo..
#
# 542
# 00:29:47,970 --> 00:29:49,371
# This is very
# disappointing laddie..
#
# 543
# 00:29:49,937 --> 00:29:50,787
# Clearly I should have stuck
#
# 544
# 00:29:50,837 --> 00:29:52,817
# with first instinct. I will
# not make that mistake again.
#
# 545
# 00:29:52,841 --> 00:29:53,504
# Sorry..
#
# 546
# 00:29:53,528 --> 00:29:55,591
# Another officer will take
# over the investigation.
#
# 547
# 00:29:55,615 --> 00:29:56,615
# Sir, that..
#
# 548
# 00:30:10,047 --> 00:30:11,160
# What happened here?
#
# 549
# 00:30:11,824 --> 00:30:13,120
# Went to see my sister.
#
# 550
# 00:30:13,191 --> 00:30:14,691
# What, she did that?
#
# 551
# 00:30:14,722 --> 00:30:17,754
# I gave as good as I got. Actually
# I think she came off worse.
#
# 552
# 00:30:18,117 --> 00:30:19,587
# Now, I have some information.
#
# 553
# 00:30:19,709 --> 00:30:22,679
# My sister did see the thief. It was
# a woman, fair hair, black dress.
#
# 554
# 00:30:22,817 --> 00:30:24,907
# Old, very old, at least 50.
#
# 555
# 00:30:25,057 --> 00:30:25,937
# Did she recognise her?
#
# 556
# 00:30:26,037 --> 00:30:28,627
# Not a clue. Unlike the
# constable from Scotland Yard
#
# 557
# 00:30:28,722 --> 00:30:29,941
# who drinks at my local.
#
# 558
# 00:30:29,996 --> 00:30:32,065
# How he loves the chat
# when he's had a few.
#
# 559
# 00:30:32,357 --> 00:30:34,729
# Reckon I'd make a good
# lady detective myself.
#
# 560
# 00:30:35,437 --> 00:30:36,607
# Tell me everything you know.
#
# 561
# 00:30:40,077 --> 00:30:41,607
# I was just coming to get you.
#
# 562
# 00:30:41,842 --> 00:30:43,405
# She's a wily one,
# that Clementine.
#
# 563
# 00:30:43,444 --> 00:30:44,944
# Remind me to employ
# her more often.
#
# 564
# 00:30:44,981 --> 00:30:46,423
# Where are you going?
#
# 565
# 00:30:46,453 --> 00:30:47,545
# To solve the case.
#
# 566
# 00:30:47,702 --> 00:30:49,403
# But you have not been
# working the case.
#
# 567
# 00:30:49,427 --> 00:30:51,850
# I have and I have news.
#
# 568
# 00:30:51,920 --> 00:30:53,520
# You're in the clear.
#
# 569
# 00:30:56,107 --> 00:30:57,107
# Come on Moses.
#
# 570
# 00:30:57,517 --> 00:30:58,517
# We've work to do.
#
# 571
# 00:31:05,617 --> 00:31:06,617
# So.
#
# 572
# 00:31:07,237 --> 00:31:08,345
# What did the vicar say?
#
# 573
# 00:31:09,397 --> 00:31:10,400
# What I expected.
#
# 574
# 00:31:11,057 --> 00:31:12,345
# He has no wife.
#
# 575
# 00:31:13,797 --> 00:31:15,237
# Where's the information
# I requested?
#
# 576
# 00:31:17,617 --> 00:31:20,207
# Since you are officially
# off the investigation,
#
# 577
# 00:31:20,317 --> 00:31:21,672
# I thought it safer
# to memorise it
#
# 578
# 00:31:21,697 --> 00:31:23,233
# just in case I was stopped
# coming out of the yard.
#
# 579
# 00:31:23,257 --> 00:31:24,718
# Don't get carried away, man.
#
# 580
# 00:31:24,843 --> 00:31:25,993
# But you are off the case, Sir?
#
# 581
# 00:31:26,017 --> 00:31:27,203
# I don't wish to talk about it.
#
# 582
# 00:31:27,227 --> 00:31:28,353
# It's all anyone can talk about.
#
# 583
# 00:31:28,377 --> 00:31:29,377
# Good for them.
#
# 584
# 00:31:29,467 --> 00:31:31,367
# If you would kindly
# impart the information
#
# 585
# 00:31:31,447 --> 00:31:34,127
# that has been so carefully
# concealed in that brain of yours
#
# 586
# 00:31:34,217 --> 00:31:35,217
# and hurry up about it.
#
# 587
# 00:31:35,357 --> 00:31:37,547
# This bloody Mary's real
# name is Mary Dawson.
#
# 588
# 00:31:37,737 --> 00:31:40,207
# She was part of a gang of diamond
# smugglers back in the 50s.
#
# 589
# 00:31:40,457 --> 00:31:43,027
# She served 25 years at Newgate,
# was released last week.
#
# 590
# 00:31:44,427 --> 00:31:45,427
# What is it, Sir?
#
# 591
# 00:31:57,867 --> 00:32:00,338
# Who sends flowers
# to a pauper grave?
#
# 592
# 00:32:03,137 --> 00:32:06,427
# Yes, that particular grave receives
# flowers each and every month.
#
# 593
# 00:32:06,937 --> 00:32:08,613
# Write down the address
# of the sender for me.
#
# 594
# 00:32:08,637 --> 00:32:09,882
# Certainly, Inspector.
#
# 595
# 00:32:11,877 --> 00:32:12,877
# What?
#
# 596
# 00:32:13,677 --> 00:32:14,677
# Sorry Sir.
#
# 597
# 00:32:15,727 --> 00:32:17,473
# Have you ever been
# taken off a case before?
#
# 598
# 00:32:17,511 --> 00:32:19,663
# I thought I made it clear that
# I do not wish to talk about it.
#
# 599
# 00:32:19,687 --> 00:32:21,317
# You did Sir. Sorry,
# Sir. Understood.
#
# 600
# 00:32:22,967 --> 00:32:25,897
# For what it's worth, Sir, the
# officer Munro replaced you with is..
#
# 601
# 00:32:27,297 --> 00:32:29,327
# Sorry Sir, you do not
# wish to talk about it.
#
# 602
# 00:32:29,757 --> 00:32:30,757
# Thank you detective.
#
# 603
# 00:32:35,987 --> 00:32:36,987
# Who is it?
#
# 604
# 00:32:37,534 --> 00:32:38,335
# Carmichael, Sir.
#
# 605
# 00:32:38,360 --> 00:32:42,172
# Carmichael? Couldn't investigate
# a booze up in a brewery, that one.
#
# 606
# 00:32:43,147 --> 00:32:44,147
# As requested, Sir.
#
# 607
# 00:32:45,687 --> 00:32:47,237
# Address of the account holder.
#
# 608
# 00:32:47,767 --> 00:32:48,767
# Thank you.
#
# 609
# 00:32:48,857 --> 00:32:52,447
# It's a curious thing, but you're not
# the first person who has inquired
#
# 610
# 00:32:52,527 --> 00:32:54,437
# about that particular
# account today.
#
# 611
# 00:32:54,927 --> 00:32:56,677
# Who else has inquired about it?
#
# 612
# 00:32:57,307 --> 00:33:01,113
# A lady. Blond hair
# determined demeanour.
#
# 613
# 00:33:13,037 --> 00:33:14,239
# I don't know where to begin.
#
# 614
# 00:33:14,264 --> 00:33:15,147
# I can explain.
#
# 615
# 00:33:15,171 --> 00:33:16,211
# Don't bother.
#
# 616
# 00:33:19,497 --> 00:33:21,487
# See to it that Miss Scarlet
# stays in the carriage.
#
# 617
# 00:33:21,637 --> 00:33:22,098
# Yes, Sir.
#
# 618
# 00:33:22,657 --> 00:33:23,657
# Hello Miss Scarlet.
#
# 619
# 00:33:24,107 --> 00:33:26,417
# Do not converse with her or
# let her out of your sight.
#
# 620
# 00:33:26,647 --> 00:33:27,647
# I'll deal with you later.
#
# 621
# 00:33:45,217 --> 00:33:46,217
# Inspector
#
# 622
# 00:33:50,737 --> 00:33:53,127
# I thought you'd been replaced
# on the investigation.
#
# 623
# 00:33:55,340 --> 00:33:59,120
# And I thought sending flowers to
# a grave listed in the stolen files
#
# 624
# 00:33:59,147 --> 00:34:01,330
# might have been something
# that you would have mentioned.
#
# 625
# 00:34:01,354 --> 00:34:02,393
# No, it's merely a coincidence
#
# 626
# 00:34:02,417 --> 00:34:03,768
# that my connection
# with that grave
#
# 627
# 00:34:03,793 --> 00:34:06,537
# should have dovetailed
# with this investigation.
#
# 628
# 00:34:07,003 --> 00:34:08,588
# I've been in the force a
# long time, Mr. Thackery
#
# 629
# 00:34:08,612 --> 00:34:10,257
# and in my experience,
#
# 630
# 00:34:10,527 --> 00:34:12,727
# a coincidence never holds
# up to much scrutiny.
#
# 631
# 00:34:13,287 --> 00:34:14,567
# Well, in this
# case, you're wrong.
#
# 632
# 00:34:15,127 --> 00:34:17,027
# It is a simple explanation,
#
# 633
# 00:34:17,107 --> 00:34:19,103
# However it's not something
# I'm comfortable to speak of,
#
# 634
# 00:34:19,127 --> 00:34:21,037
# nor should I have to
# explain myself to you.
#
# 635
# 00:34:21,227 --> 00:34:24,457
# Well, if you prefer, you can explain
# yourself to Detective Carmichael,
#
# 636
# 00:34:24,747 --> 00:34:26,477
# who I believe
# Superintendent Munro
#
# 637
# 00:34:26,557 --> 00:34:28,577
# has now assigned to this case.
#
# 638
# 00:34:28,727 --> 00:34:31,968
# And I can assure you he will
# not be as discrete as I am.
#
# 639
# 00:34:37,187 --> 00:34:38,187
# The fact is.
#
# 640
# 00:34:39,557 --> 00:34:42,457
# I had a humble upbringing.
#
# 641
# 00:34:43,677 --> 00:34:44,677
# It was more than humble.
#
# 642
# 00:34:45,657 --> 00:34:46,777
# I was born in the workhouse.
#
# 643
# 00:34:47,787 --> 00:34:49,427
# It's something I don't
# like to talk about.
#
# 644
# 00:34:50,417 --> 00:34:54,107
# And rarely reveal, particularly
# being a man of such status,
#
# 645
# 00:34:54,437 --> 00:34:56,305
# but from a young age I was.
#
# 646
# 00:34:56,757 --> 00:34:58,787
# Utterly determined to
# make something of myself,
#
# 647
# 00:34:59,117 --> 00:35:00,133
# and as you can see.
#
# 648
# 00:35:00,767 --> 00:35:01,852
# I was successful.
#
# 649
# 00:35:03,397 --> 00:35:05,517
# There were many people who
# helped me along the way.
#
# 650
# 00:35:06,367 --> 00:35:07,407
# Not least of all, my wife.
#
# 651
# 00:35:08,747 --> 00:35:10,107
# And for that I'm
# forever grateful.
#
# 652
# 00:35:14,287 --> 00:35:15,287
# So in short,
#
# 653
# 00:35:16,357 --> 00:35:18,037
# my fate could have been
# somewhat different.
#
# 654
# 00:35:19,037 --> 00:35:22,966
# And as a Christian man, and in
# my position as chief coroner
#
# 655
# 00:35:23,397 --> 00:35:26,267
# whenever I happen upon a pauper
# grave, I like to send flowers.
#
# 656
# 00:35:26,597 --> 00:35:27,907
# It is a small kindness
#
# 657
# 00:35:29,697 --> 00:35:30,697
# and it helps me remember.
#
# 658
# 00:35:31,737 --> 00:35:32,737
# Remember?
#
# 659
# 00:35:33,197 --> 00:35:35,196
# There, but for the grace of God,
#
# 660
# 00:35:36,727 --> 00:35:37,727
# Go I.
#
# 661
# 00:35:41,547 --> 00:35:42,547
# So.
#
# 662
# 00:35:45,637 --> 00:35:47,317
# Well, I appreciate
# your candor, Sir,
#
# 663
# 00:35:47,397 --> 00:35:51,647
# but I'm afraid there's still some questions
# that I need to ask regarding the case.
#
# 664
# 00:35:51,877 --> 00:35:52,572
# What, why?
#
# 665
# 00:35:52,597 --> 00:35:53,597
# Surely we're done here?
#
# 666
# 00:35:54,077 --> 00:35:55,607
# We're done when
# I say we're done.
#
# 667
# 00:35:55,737 --> 00:35:56,737
# Mr Thackery.
#
# 668
# 00:36:15,337 --> 00:36:16,597
# How did you know I was here?
#
# 669
# 00:36:17,214 --> 00:36:20,534
# Inspector Wellington specifically ordered
# me not to converse with you, Miss Scarlet.
#
# 670
# 00:36:21,497 --> 00:36:22,497
# Very well.
#
# 671
# 00:36:23,237 --> 00:36:25,636
# Although I'm surprised that a
# gentleman with impeccable manners,
#
# 672
# 00:36:25,660 --> 00:36:27,363
# such as yourself,
# would be so rude,
#
# 673
# 00:36:27,461 --> 00:36:28,687
# I'm only following orders.
#
# 674
# 00:36:29,537 --> 00:36:31,967
# Please forgive me, I do hold
# you in the highest regard.
#
# 675
# 00:36:34,147 --> 00:36:36,425
# I don't wish to get you
# into trouble Detective.
#
# 676
# 00:36:37,277 --> 00:36:39,839
# By answering one simple question,
# can you really do any harm?
#
# 677
# 00:36:42,402 --> 00:36:46,253
# The florist advised that you'd been asking
# who sent the flowers to the pauper grave?
#
# 678
# 00:36:47,227 --> 00:36:48,941
# But I didn't speak
# to the florist.
#
# 679
# 00:36:49,667 --> 00:36:51,197
# Moses got that
# information to me.
#
# 680
# 00:36:51,672 --> 00:36:53,833
# Well then, who was the blond
# lady the florist spoke of?
#
# 681
# 00:36:56,037 --> 00:36:58,445
# No, I do not know this
# Mary Dawson or Bloody Mary,
#
# 682
# 00:36:58,470 --> 00:36:59,693
# or whatever the
# devil she's called.
#
# 683
# 00:36:59,717 --> 00:37:01,413
# I'm as anxious as you to get
# this criminal into custody
#
# 684
# 00:37:01,437 --> 00:37:02,773
# and find out what
# the hell is going on.
#
# 685
# 00:37:02,797 --> 00:37:04,857
# And I've answered all
# your questions inspector.
#
# 686
# 00:37:04,951 --> 00:37:07,112
# My wife and the maid will be
# back from my errands soon.
#
# 687
# 00:37:07,527 --> 00:37:09,240
# I'd like you gone
# before they return.
#
# 688
# 00:37:12,122 --> 00:37:15,794
# You seem extremely keen to
# get rid of me, Mr. Thackery.
#
# 689
# 00:37:16,487 --> 00:37:18,497
# Well, a reputation can be
# undone by such a visit.
#
# 690
# 00:37:19,497 --> 00:37:21,587
# I do not want to be the
# topic of idle gossip.
#
# 691
# 00:37:27,647 --> 00:37:28,647
# I thought you were alone.
#
# 692
# 00:37:30,827 --> 00:37:32,655
# No, that'll just be the maid.
#
# 693
# 00:37:34,087 --> 00:37:36,237
# The maid who's running
# errands with your wife?
#
# 694
# 00:37:40,897 --> 00:37:43,267
# No, do not open
# that door. Please!
#
# 695
# 00:37:50,457 --> 00:37:52,237
# Nice to see you
# again, Inspector.
#
# 696
# 00:37:52,354 --> 00:37:54,167
# Put the revolver down Mary.
#
# 697
# 00:37:55,057 --> 00:37:56,417
# I was about to say
# the same to you.
#
# 698
# 00:37:57,797 --> 00:37:58,797
# And if you don't,
#
# 699
# 00:37:58,877 --> 00:38:00,687
# I will shoot Mrs
# Thackery in the head.
#
# 700
# 00:38:01,017 --> 00:38:02,764
# No, Mary, please,
# please do not do this.
#
# 701
# 00:38:02,795 --> 00:38:03,795
# Shut up.
#
# 702
# 00:38:04,987 --> 00:38:05,987
# I'll deal with you later.
#
# 703
# 00:38:10,567 --> 00:38:11,567
# I said
#
# 704
# 00:38:11,937 --> 00:38:14,300
# put it down.
#
# 705
# 00:38:28,347 --> 00:38:29,347
# Kick it towards me.
#
# 706
# 00:38:32,399 --> 00:38:33,399
# Good.
#
# 707
# 00:38:36,337 --> 00:38:40,155
# But on second thoughts, I think
# I'm gonna kill her anyway.
#
# 708
# 00:38:42,867 --> 00:38:44,663
# I would recommend
# that you do not.
#
# 709
# 00:39:01,757 --> 00:39:04,447
# You know that using a
# policeman's weapon is an offence.
#
# 710
# 00:39:05,217 --> 00:39:08,217
# Would you have preferred if I
# had dispatched Detective Fitzroy?
#
# 711
# 00:39:21,667 --> 00:39:24,595
# My real name is Alfie Frampton.
#
# 712
# 00:39:26,024 --> 00:39:28,134
# Mary Dawson was my fiancée.
#
# 713
# 00:39:29,047 --> 00:39:30,247
# We were small time crooks
#
# 714
# 00:39:30,327 --> 00:39:32,595
# but we managed to pull
# off a diamond heist.
#
# 715
# 00:39:36,727 --> 00:39:37,517
# When can I see my wife?
#
# 716
# 00:39:37,607 --> 00:39:38,927
# She knows nothing
# of any of this.
#
# 717
# 00:39:39,637 --> 00:39:40,715
# Get on with it.
#
# 718
# 00:39:43,897 --> 00:39:45,127
# I took the diamonds and ran.
#
# 719
# 00:39:46,089 --> 00:39:47,089
# But Mary tracked me down.
#
# 720
# 00:39:47,182 --> 00:39:48,182
# She's like a..
#
# 721
# 00:39:48,370 --> 00:39:49,370
# Like a mad woman.
#
# 722
# 00:39:49,797 --> 00:39:51,245
# She was attacking
# me. She was..
#
# 723
# 00:39:51,917 --> 00:39:53,117
# Desperate to get hold of them.
#
# 724
# 00:39:54,237 --> 00:39:55,380
# So I swallowed them.
#
# 725
# 00:39:56,327 --> 00:39:57,606
# You swallowed the diamonds?
#
# 726
# 00:39:58,327 --> 00:39:59,841
# And in return she gave me this.
#
# 727
# 00:40:04,647 --> 00:40:07,132
# The police turned up after
# a tip-off and arrested Mary.
#
# 728
# 00:40:08,417 --> 00:40:09,703
# But I managed to escape.
#
# 729
# 00:40:11,387 --> 00:40:12,387
# And with her inside.
#
# 730
# 00:40:13,557 --> 00:40:14,557
# I saw a way out.
#
# 731
# 00:40:15,547 --> 00:40:16,703
# To leave her behind.
#
# 732
# 00:40:17,837 --> 00:40:19,321
# To leave my past behind.
#
# 733
# 00:40:21,427 --> 00:40:22,899
# So I faked my own death.
#
# 734
# 00:40:23,617 --> 00:40:25,962
# You used the corpse from the
# pauper's grave in Highgate.
#
# 735
# 00:40:26,557 --> 00:40:28,735
# That's why you sent
# flowers to it each month.
#
# 736
# 00:40:29,507 --> 00:40:30,507
# Poor soul..
#
# 737
# 00:40:32,267 --> 00:40:33,507
# Whoever he was
#
# 738
# 00:40:35,707 --> 00:40:36,890
# gave me a new life.
#
# 739
# 00:40:41,237 --> 00:40:43,574
# Frampton took the body
# to one of their hideouts,
#
# 740
# 00:40:43,590 --> 00:40:44,573
# changed clothes with the man,
#
# 741
# 00:40:44,597 --> 00:40:46,053
# and then gave him a
# cut down his cheek,
#
# 742
# 00:40:46,077 --> 00:40:47,667
# just like Dawson
# had done to him.
#
# 743
# 00:40:48,377 --> 00:40:51,491
# I'm pretty sure he always told you that
# he got that scar from the Crimea, Sir.
#
# 744
# 00:40:51,592 --> 00:40:52,933
# I'm not the only one
# who believed him.
#
# 745
# 00:40:52,957 --> 00:40:54,163
# He told everyone that.
#
# 746
# 00:40:57,647 --> 00:40:59,247
# I wasn't questioning
# your judgment, Sir.
#
# 747
# 00:41:00,767 --> 00:41:01,707
# From her prison cell,
#
# 748
# 00:41:01,787 --> 00:41:03,027
# Mary Dawson read about the body
#
# 749
# 00:41:03,087 --> 00:41:05,647
# in the papers and assumed
# it was that of her fiancé.
#
# 750
# 00:41:06,010 --> 00:41:07,647
# And then when she'd
# served her time,
#
# 751
# 00:41:07,727 --> 00:41:09,437
# she went about tracking
# down his grave.
#
# 752
# 00:41:11,197 --> 00:41:12,197
# Come.
#
# 753
# 00:41:14,097 --> 00:41:16,449
# Detective Phelps
# come and take a seat.
#
# 754
# 00:41:26,777 --> 00:41:27,777
# Continue.
#
# 755
# 00:41:28,279 --> 00:41:30,703
# Dawson believed that she
# would find the diamonds
#
# 756
# 00:41:30,807 --> 00:41:32,807
# that Frampton had swallowed
# in one of those graves.
#
# 757
# 00:41:33,157 --> 00:41:36,217
# But what she didn't know was that
# he'd sold them to reinvent himself.
#
# 758
# 00:41:36,307 --> 00:41:37,937
# He put himself through
# medical school,
#
# 759
# 00:41:38,027 --> 00:41:39,357
# he changed his whole life.
#
# 760
# 00:41:39,855 --> 00:41:41,417
# Whiskey, detective Phelps.
#
# 761
# 00:41:44,497 --> 00:41:45,497
# Thank you Sir.
#
# 762
# 00:41:47,727 --> 00:41:49,517
# What of your friend,
# Miss Scarlet?
#
# 763
# 00:41:49,834 --> 00:41:52,152
# Thackery wanted to pin this on
# her at the earliest opportunity
#
# 764
# 00:41:52,176 --> 00:41:54,971
# in the hope that the trail
# would end there and then.
#
# 765
# 00:41:54,996 --> 00:41:58,121
# If Dawson did find him, then
# he would cut a deal with him.
#
# 766
# 00:41:59,567 --> 00:42:01,883
# Well, I think I'm fully briefed.
#
# 767
# 00:42:01,953 --> 00:42:04,086
# That will be all,
# Inspector Wellington.
#
# 768
# 00:42:05,317 --> 00:42:08,547
# Sir, I know that I disobeyed
# orders by continuing with the case.
#
# 769
# 00:42:08,637 --> 00:42:10,297
# That will be all Inspector.
#
# 770
# 00:42:13,137 --> 00:42:14,137
# Yes, Sir.
#
# 771
# 00:42:15,527 --> 00:42:17,101
# Well, detective Phelps.
#
# 772
# 00:42:17,923 --> 00:42:19,881
# I've heard nothing but
# good reports about you.
#
# 773
# 00:42:19,929 --> 00:42:21,483
# Tell me more about yourself.
#
# 774
# 00:42:22,014 --> 00:42:24,467
# We're always on the look
# out for a good loyal man.
#
# 775
# 00:42:24,697 --> 00:42:25,697
# Yes, Sir.
#
# 776
# 00:42:27,727 --> 00:42:28,727
# Thank you, Sir.
#
# 777
# 00:42:36,507 --> 00:42:37,507
# How childish men are.
#
# 778
# 00:42:38,655 --> 00:42:40,667
# Still, he'll get over it.
#
# 779
# 00:42:41,277 --> 00:42:42,307
# No, he won't.
#
# 780
# 00:42:42,357 --> 00:42:44,314
# Loyalty is everything
# to men like Munro,
#
# 781
# 00:42:44,417 --> 00:42:45,607
# and I disobeyed an order.
#
# 782
# 00:42:46,437 --> 00:42:47,674
# Oh, so this is my fault?
#
# 783
# 00:42:48,937 --> 00:42:49,963
# Actually, yes.
#
# 784
# 00:42:51,047 --> 00:42:53,537
# I was the one who saved
# Mrs Thackey's life
#
# 785
# 00:42:53,627 --> 00:42:55,287
# and most probably yours, too.
#
# 786
# 00:42:59,607 --> 00:43:01,955
# So I hear you and Moses
# made quite the partnership.
#
# 787
# 00:43:03,627 --> 00:43:04,627
# First of many.
#
# 788
# 00:43:07,207 --> 00:43:08,988
# I'm just teasing you, William.
#
# 789
# 00:43:09,137 --> 00:43:10,949
# But I don't - you know
# - I don't like him.
#
# 790
# 00:43:15,207 --> 00:43:16,749
# Now, I should get back to work.
#
# 791
# 00:43:17,867 --> 00:43:19,421
# It's probably a good idea,
#
# 792
# 00:43:19,500 --> 00:43:23,020
# trying to get back into the
# superintendent's good books.
#
# 793
# 00:43:23,047 --> 00:43:25,393
# Eliza, will you at least pretend
# that you say that for my sake,
#
# 794
# 00:43:25,417 --> 00:43:26,797
# rather than your own benefit?
#
# 795
# 00:43:27,207 --> 00:43:29,861
# William, you really do have a
# low opinion of me sometimes.
#
# 796
# 00:43:30,057 --> 00:43:31,080
# Only sometimes?
#
# 797
# 00:43:38,917 --> 00:43:40,407
# So any plans for this evening?
#
# 798
# 00:43:40,792 --> 00:43:42,232
# Well, I did have
#
# 799
# 00:43:42,387 --> 00:43:43,745
# till Ivy buggered them up.
#
# 800
# 00:43:44,247 --> 00:43:46,327
# Oh yes, Betsy wasn't it?
#
# 801
# 00:43:47,497 --> 00:43:48,497
# Sorry about that.
#
# 802
# 00:43:55,707 --> 00:43:57,010
# Miss Scarlet.
#
# 803
# 00:43:57,667 --> 00:43:58,807
# Inspector Wellington.
#
# 804
# 00:44:00,815 --> 00:44:01,815
# I'll leave you to it.
#
# 805
# 00:44:05,593 --> 00:44:09,317
# Mr Potts, before you say
# anything, please let me apologise.
#
# 806
# 00:44:09,343 --> 00:44:11,405
# I'm not here to see
# you Miss Scarlet.
#
# 807
# 00:44:12,163 --> 00:44:15,123
# Mr Potts, you
# received my message
#
# 808
# 00:44:15,452 --> 00:44:18,061
# and I would be delighted to
# take you up on your offer
#
# 809
# 00:44:18,092 --> 00:44:20,467
# of that homemade steamed
# pudding, Miss Woods.
#
# 810
# 00:44:20,557 --> 00:44:21,917
# Prince Albert's favorite,
#
# 811
# 00:44:21,997 --> 00:44:23,637
# and I've added
# some extra raisins.
#
# 812
# 00:44:24,967 --> 00:44:25,967
# Come on in.
#
# 813
# 00:44:37,098 --> 00:44:41,645
# You can go on another adventure
# with Eliza in a Victorian London.
#
# 814
# 00:44:41,730 --> 00:44:47,810
# Miss Scarlet and the Duke continues new and
# exclusive to alibi on Tuesday night at 9:00.
#
# 815
# 00:44:47,934 --> 00:44:50,794
# Next..Frankie Drake mysteries.
#
# 816
# 00:45:01,137 --> 00:45:02,137
# Oh
#
# 817
# 00:45:03,305 --> 00:46:03,315
# Advertise your product or brand here
# contact www.OpenSubtitles.org today

# %% [markdown]
# **Look's like it worked.**

# %% [markdown]
# ## **Step 6 - Applying the above Function on the Entire Data**

# %%
import zipfile
import io

count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])

    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df['file_content'] = df['content'].apply(decode_method)

df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           82498 non-null  int64
#  1   name          82498 non-null  object
#  2   content       82498 non-null  object
#  3   file_content  82498 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.5+ MB

# %%
df.tail()
# Out:
#            num                                        name  \
# 82493  9521935            the.prophets.game.(2000).eng.1cd
# 82494  9521937                  west.beirut.(1998).eng.1cd
# 82495  9521938  frankenstein.the.true.story.(1973).eng.1cd
# 82496  9521940  frankenstein.the.true.story.(1973).eng.1cd
# 82497  9521941       zombie.island.massacre.(1984).eng.1cd
#
#                                                  content  \
# 82493  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xb8\xa6\x...
# 82494  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x13\x97\x...
# 82495  b'PK\x03\x04\x14\x00\x00\x00\x08\x00$\x97\x9aV...
# 82496  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x00\x97\x...
# 82497  b'PK\x03\x04\x14\x00\x00\x00\x08\x00,\x97\x9aV...
#
#                                             file_content
# 82493  ï»¿1\r\n00:01:16,284 --> 00:01:19,537\r\nGod,\...
# 82494  1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 82495  1\r\n00:00:01,001 --> 00:00:04,630\r\n(Dramati...
# 82496  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 82497  1\r\n00:00:01,919 --> 00:00:03,253\r\n(Sharp w...

# %% [markdown]
# # Clean the “file_content” by removing html tags¶

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()

# %% [markdown]
# # special characters, digits, and applying lemmatization.

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", text)

    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens = sentence.split()

    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           82498 non-null  int64
#  1   name          82498 non-null  object
#  2   content       82498 non-null  object
#  3   file_content  82498 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.5+ MB

# %%
# df['clean_content'] = df['content'].progress_apply(preprocess)
# df['clean_name'] = df['name'].progress_apply(preprocess)
df['clean_file_content'] = df['file_content'].progress_apply(preprocess)

# it is done
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 82498/82498 [00:05<00:00, 13937.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 82498/82498 [50:59<00:00, 26.97it/s]

# %%
# df['clean_content'] = df['content'].progress_apply(preprocess)

# it is showing some error

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content  \
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
#
#                                           clean_name  \
# 0                                 the message eng cd
# 1  here come the grump s e joltin jack in boxia e...
# 2                      yumis cell s e episode eng cd
# 3                      yumis cell s e episode eng cd
# 4                                      broker eng cd
#
#                                   clean_file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
# import pandas as pd
# from bs4 import BeautifulSoup

# def remove_html_tags(html_text):
#     # Parse the HTML text
#     soup = BeautifulSoup(html_text, 'html.parser')

#     # Extract the text content without HTML tags
#     text_content = soup.get_text(separator=' ', strip=True)

#     return text_content

# # df['Text_Content'] = df['File_Content'].progress_apply(remove_html_tags)

# %%
# s = str(df.content)

# %%
# htmltext = s.read().decode('utf-8')

# %%
# df['clean_content'] = df['content'].progress_apply(remove_html_tags)

# %%
# df['clean_content'] = df['content'].progress_apply(preprocess)

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content  \
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
#
#                                           clean_name  \
# 0                                 the message eng cd
# 1  here come the grump s e joltin jack in boxia e...
# 2                      yumis cell s e episode eng cd
# 3                      yumis cell s e episode eng cd
# 4                                      broker eng cd
#
#                                   clean_file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
df.to_csv('df.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv("df_30k.csv")
df.head()
# Out:
#    Unnamed: 0      num                                               name  \
# 0           0  9180533                         the.message.(1976).eng.1cd
# 1           1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2           2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3           3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4           4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'num', 'name', 'file_content'], dtype='object')

# %%
df.drop(columns='Unnamed: 0', inplace =True)

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
# import pandas as pd

# # Assuming df is your DataFrame

# # Define the size of each chunk
# chunk_size = 4

# # Create an iterator to iterate through chunks
# chunk_iterator = pd.read_csv('/content/drive/MyDrive/df_30k.csv', chunksize=chunk_size)

# # Iterate over the chunks
# for i, chunk in enumerate(chunk_iterator):
#     # Process each chunk as needed
#     # For example, you can apply operations on each chunk or save them to separate files
#     # For demonstration, let's print the first few rows of each chunk
#     print(f"Chunk {i+1}:")
#     display(chunk.head())  # Print the first few rows of each chunk

# %%
# chunk.head()

# %%
# #non -overlapping chunk
# import pandas as pd

# # Assuming df contains a column named 'srt_content' containing the content of each .srt file
# # You may need to adjust column names accordingly

# # Define a function to chunk the .srt content
# def chunk_srt(srt_content, chunk_size=1000):
#     chunks = []
#     current_chunk = ''
#     for line in srt_content.split('\n'):
#         current_chunk += line + '\n'
#         if line.strip() == '':
#             if current_chunk.strip() != '':
#                 chunks.append(current_chunk)
#                 current_chunk = ''
#     if current_chunk.strip() != '':
#         chunks.append(current_chunk)
#     return chunks

# # Apply the chunking function to each .srt file content in the DataFrame
# df['chunks'] = df['srt_content'].apply(lambda x: chunk_srt(x))

# # Now df['chunks'] contains a list of chunks for each .srt file
# # Each chunk is a string containing a part of the .srt content

# %%
# #overlapping chunks
# import pandas as pd

# # Assuming df contains a column named 'file_content' containing the content of each .srt file

# # Define a function to create overlapping chunks for each .srt file content
# def overlapping_chunks(file_content, chunk_size=4, overlap_size=5):
#     chunks = []
#     lines = file_content.split('\n')
#     total_lines = len(lines)
#     for i in range(0, total_lines, chunk_size - overlap_size):
#         chunk = '\n'.join(lines[i:i + chunk_size])
#         chunks.append(chunk)
#     return chunks

# # Apply the overlapping chunks function to each .srt file content in the DataFrame
# df['overlapping_chunks_file_content'] = df['file_content'].apply(lambda x: overlapping_chunks(x))

# # Now df['overlapping_chunks'] contains a list of overlapping chunks for each .srt file
# # Each chunk is a string containing a part of the .srt content with overlap

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
# import pandas as pd

# # Assuming df contains a column named 'srt_content' containing the content of each .srt file
# # You may need to adjust column names accordingly

# # Define a function to create overlapping chunks for each .srt file content
# def overlapping_chunks(file_content, chunk_size=4, overlap_size=50):
#     chunks = []
#     lines = file_content.split('\n')
#     total_lines = len(lines)
#     for i in range(0, total_lines - chunk_size + 1, chunk_size - overlap_size):
#         chunk = '\n'.join(lines[i:i + chunk_size])
#         chunks.append(chunk)
#     return chunks

# # Apply the overlapping chunks function to each .srt file content in the DataFrame
# df['overlapping_chunks_file_content'] = df['file_content'].apply(lambda x: overlapping_chunks(x))

# # Now df['overlapping_chunks'] contains a list of overlapping chunks for each .srt file
# # Each chunk is a string containing a part of the .srt content with overlap
# df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                      overlapping_chunks_file_content
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...

# %%
# df = df.loc[:200]
# df.reset_index(inplace=True)
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 10000 to 20000
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   num              10001 non-null  int64
#  1   name             10001 non-null  object
#  2   file_content     10001 non-null  object
#  3   chunked_content  10001 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.7+ KB

# %%
def chunk_document(document, token_window=250, overlap=50):
    """
    Chunk a large document into smaller chunks with specified token window size and overlap.
    
    Parameters:
        document (str): The large document to be chunked.
        token_window (int): The desired token window size for each chunk.
        overlap (int): The amount of overlap (in tokens) between consecutive chunks.
    
    Returns:
        List of smaller document chunks.
    """
    # Split the document into tokens
    tokens = document.split()
    
    # Initialize variables
    chunks = []
    start_idx = 0

    
    # Iterate through the tokens with overlap
    while start_idx < len(tokens):
        # Calculate the end index of the chunk
        end_idx = min(start_idx + token_window, len(tokens))
        
        # Append the chunk to the list
        chunks.append(' '.join(tokens[start_idx:end_idx]))
        
        # Move the start index forward with overlap
        start_idx += token_window - overlap
    
    return chunks

# Apply document chunking to the 'clean_content' column of the sampled DataFrame
df['chunked_content'] = df['file_content'].apply(lambda x: chunk_document(x))
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...

# %%
df.head()
# Out:
#    index      num                   name  \
# 0  10000  9223792  recess.(1997).eng.1cd
# 1  10001  9223793  recess.(1997).eng.1cd
# 2  10002  9223794  recess.(1997).eng.1cd
# 3  10003  9223795  recess.(1997).eng.1cd
# 4  10004  9223796  recess.(1997).eng.1cd
#
#                                         file_content  \
# 0  bell ring child cheer ah api opensubtitles org...
# 1  bell ring door slammed and child screaming pop...
# 2  bell ring child cheering waa umph support u an...
# 3  bell ringing kid screaming uh oh advertise you...
# 4  bell ring child cheer waah watch any video onl...
#
#                                      chunked_content
# 0  [bell ring child cheer ah api opensubtitles or...
# 1  [bell ring door slammed and child screaming po...
# 2  [bell ring child cheering waa umph support u a...
# 3  [bell ringing kid screaming uh oh advertise yo...
# 4  [bell ring child cheer waah watch any video on...

# %%
df.chunked_content
# Out:
# 0        [watch any video online with open subtitle fre...
# 1        [ah there s princess dawn and terry with the b...
# 2        [i yumi s cell i i episode extremely polite yu...
# 3        [watch any video online with open subtitle fre...
# 4        [watch any video online with open subtitle fre...
#                                ...
# 29996    [no audio light music light music light music ...
# 29997    [api opensubtitles org is deprecated please im...
# 29998    [watch any video online with open subtitle fre...
# 29999    [ah thanks tracy taking an early lunch jeff ye...
# 30000    [suspenseful music playing advertise your prod...
# Name: chunked_content, Length: 30001, dtype: object

# %%
# ! pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in e:\python\lib\site-packages (2.6.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in e:\python\lib\site-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in e:\python\lib\site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.11.0 in e:\python\lib\site-packages (from sentence-transformers) (2.2.1)
# Requirement already satisfied: numpy in e:\python\lib\site-packages (from sentence-transformers) (1.26.2)
# Requirement already satisfied: scikit-learn in e:\python\lib\site-packages (from sentence-transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in e:\python\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in e:\python\lib\site-packages (from sentence-transformers) (0.21.4)
# Requirement already satisfied: Pillow in e:\python\lib\site-packages (from sentence-transformers) (10.1.0)
# Requirement already satisfied: filelock in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.0)
# Requirement already satisfied: requests in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in e:\python\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in e:\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in e:\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in e:\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in e:\python\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in e:\python\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in e:\python\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in e:\python\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.2.0 in e:\python\lib\site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\python\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\python\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\python\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\python\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\python\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in e:\python\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# from sentence_transformers import SentenceTransformer, util

# model = SentenceTransformer('all-MiniLM-L6-v2')
def encode_text(text):
  embedding = model.encode(text)
  return embedding

# %%
df1 = df.loc[:2000,:]
df1.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...

# %%
df1['embedding'] = df1['chunked_content'].apply(encode_text)
df1.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2435163098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['embedding'] = df1['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df2 = df.loc[2001:4000,:]
df2.head()
# Out:
#           num                                               name  \
# 2001  9189883               betty.danger.vice.cop.(2020).eng.1cd
# 2002  9189909      the.teenie.weenie.bikini.squad.(2012).eng.1cd
# 2003  9189910  bikini.jones.and.the.temple.of.eros.(2010).eng...
# 2004  9189912       the.seduction.of.rose.parrish.(2021).eng.1cd
# 2005  9189919                         off.the.lip.(2004).eng.1cd
#
#                                            file_content  \
# 2001  cricket chirping upbeat music api opensubtitle...
# 2002  twangy rock music api opensubtitles org is dep...
# 2003  projector rattling dramatic music explosion wh...
# 2004  bat squeaking wolf howling mysterious music su...
# 2005  upbeat music graphic whooshing wave crashing s...
#
#                                         chunked_content
# 2001  [cricket chirping upbeat music api opensubtitl...
# 2002  [twangy rock music api opensubtitles org is de...
# 2003  [projector rattling dramatic music explosion w...
# 2004  [bat squeaking wolf howling mysterious music s...
# 2005  [upbeat music graphic whooshing wave crashing ...

# %%
df2['embedding'] = df2['chunked_content'].apply(encode_text)
df2.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2575804733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['embedding'] = df2['chunked_content'].apply(encode_text)
#           num                                               name  \
# 2001  9189883               betty.danger.vice.cop.(2020).eng.1cd
# 2002  9189909      the.teenie.weenie.bikini.squad.(2012).eng.1cd
# 2003  9189910  bikini.jones.and.the.temple.of.eros.(2010).eng...
# 2004  9189912       the.seduction.of.rose.parrish.(2021).eng.1cd
# 2005  9189919                         off.the.lip.(2004).eng.1cd
#
#                                            file_content  \
# 2001  cricket chirping upbeat music api opensubtitle...
# 2002  twangy rock music api opensubtitles org is dep...
# 2003  projector rattling dramatic music explosion wh...
# 2004  bat squeaking wolf howling mysterious music su...
# 2005  upbeat music graphic whooshing wave crashing s...
#
#                                         chunked_content  \
# 2001  [cricket chirping upbeat music api opensubtitl...
# 2002  [twangy rock music api opensubtitles org is de...
# 2003  [projector rattling dramatic music explosion w...
# 2004  [bat squeaking wolf howling mysterious music s...
# 2005  [upbeat music graphic whooshing wave crashing ...
#
#                                               embedding
# 2001  [[-0.03349987, -0.061510466, 0.029355139, -0.0...
# 2002  [[-0.039968226, 0.035003703, -0.0064153518, -0...
# 2003  [[-0.024186479, -0.022270437, -0.0075046164, -...
# 2004  [[-0.040527362, -0.01084912, 0.06816627, -0.07...
# 2005  [[-0.026077606, -0.058352977, 0.071203, 0.0218...

# %%
df_new = pd.concat([df1,df2],ignore_index=True, axis=0)
df_new.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df3 = df.loc[4001:6000,:]
df3['embedding'] = df3['chunked_content'].apply(encode_text)
df3.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\3285145037.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['embedding'] = df3['chunked_content'].apply(encode_text)
#           num                                               name  \
# 4001  9199218       empire.s03.e07.what.we.may.be.(2016).eng.1cd
# 4002  9199219    empire.s03.e08.the.unkindest.cut.(2016).eng.1cd
# 4003  9199220  empire.s03.e09.a.furnace.for.your.foe.(2016).e...
# 4004  9199221           empire.s03.e10.sound.fury.(2017).eng.1cd
# 4005  9199222              empire.s03.e11.play.on.(2017).eng.1cd
#
#                                            file_content  \
# 4001  i previously on i empire what is that i wouldn...
# 4002  i previously on i empire i you got shot i your...
# 4003  i previously on i empire i want you to write a...
# 4004  i previously on i empire we are empire s origi...
# 4005  i previously on i empire i inferno i is an alb...
#
#                                         chunked_content  \
# 4001  [i previously on i empire what is that i would...
# 4002  [i previously on i empire i you got shot i you...
# 4003  [i previously on i empire i want you to write ...
# 4004  [i previously on i empire we are empire s orig...
# 4005  [i previously on i empire i inferno i is an al...
#
#                                               embedding
# 4001  [[-0.041658957, -0.09661416, 0.0013693264, -0....
# 4002  [[-0.057505704, -0.04033067, 0.01015596, -0.05...
# 4003  [[-0.042650774, -0.03094323, -0.0051559196, -0...
# 4004  [[-0.052542172, -0.08518107, 0.010912725, -0.0...
# 4005  [[-0.0542408, -0.12611762, -0.048472945, -0.13...

# %%
df_new = pd.concat([df_new,df3],ignore_index=True, axis=0)
df_new.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df4 = df.loc[6001:8000,:]
df4['embedding'] = df4['chunked_content'].apply(encode_text)
df4.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2598318094.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['embedding'] = df4['chunked_content'].apply(encode_text)
#           num                                               name  \
# 6001  9207415  the.jeffersons.s06.e01.the.announcement.(1979)...
# 6002  9207416  the.jeffersons.s06.e02.a.short.story.(1979).en...
# 6003  9207417  the.jeffersons.s06.e03.louises.old.boyfriend.(...
# 6004  9207418  the.jeffersons.s06.e04.now.you.see.it.now.you....
# 6005  9207419  the.jeffersons.s06.e05.now.you.see.it.now.you....
#
#                                            file_content  \
# 6001  i well we re movin on up movin on up i i to th...
# 6002  i well we re movin on up movin on up i i to th...
# 6003  i well we re movin on up movin on up i i to th...
# 6004  i well we re movin on up movin on up i i to th...
# 6005  i well we re movin on up movin on up i i to th...
#
#                                         chunked_content  \
# 6001  [i well we re movin on up movin on up i i to t...
# 6002  [i well we re movin on up movin on up i i to t...
# 6003  [i well we re movin on up movin on up i i to t...
# 6004  [i well we re movin on up movin on up i i to t...
# 6005  [i well we re movin on up movin on up i i to t...
#
#                                               embedding
# 6001  [[-0.06978582, -0.029881814, 0.016883716, -0.0...
# 6002  [[-0.09514737, -0.04934125, -0.0064340895, -0....
# 6003  [[-0.025038512, -0.04996716, -0.016983239, -0....
# 6004  [[-0.065551475, -0.0044518393, 0.00813088, -0....
# 6005  [[-0.05058959, -0.03531585, -0.0012658216, -0....

# %%
df_new = pd.concat([df_new,df4],ignore_index=True, axis=0)
df_new.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df5 = df.loc[8001:10000,:]
df5['embedding'] = df5['chunked_content'].apply(encode_text)
df5.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2339449871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['embedding'] = df5['chunked_content'].apply(encode_text)
#           num                                               name  \
# 8001  9214938  united.states.of.tara.s02.e10.open.house.(2010...
# 8002  9214939  united.states.of.tara.s02.e11.to.have.and.to.h...
# 8003  9214940  united.states.of.tara.s02.e12.from.this.day.fo...
# 8004  9214941              children.of.camp.blood.(2020).eng.1cd
# 8005  9214943  united.states.of.tara.s03.e01.youwillnotwin.(2...
#
#                                            file_content  \
# 8001  i previously on united state of tara i so on t...
# 8002  i previously on united state of tara i let s g...
# 8003  i previously on united state of tara i max i r...
# 8004  suspenseful music advertise your product or br...
# 8005  i previously on united state of tara i are you...
#
#                                         chunked_content  \
# 8001  [i previously on united state of tara i so on ...
# 8002  [i previously on united state of tara i let s ...
# 8003  [i previously on united state of tara i max i ...
# 8004  [suspenseful music advertise your product or b...
# 8005  [i previously on united state of tara i are yo...
#
#                                               embedding
# 8001  [[-0.07934143, -0.099133424, 0.017863601, -0.0...
# 8002  [[-0.08671663, -0.08847381, 0.02160982, -0.005...
# 8003  [[-0.06490324, -0.06776245, 0.085882254, -0.01...
# 8004  [[0.011157505, -0.06438216, 0.024798673, -0.04...
# 8005  [[-0.11709833, -0.12667039, 0.030737886, -0.00...

# %%
df_new = pd.concat([df_new,df5],ignore_index=True, axis=0)
df_new.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df6 = df.loc[10001:12000,:]
df6['embedding'] = df6['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df6],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2594223756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['embedding'] = df6['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df7 = df.loc[12001:14000,:]
df7['embedding'] = df7['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df7],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\3550537911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['embedding'] = df7['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df8 = df.loc[14001:16000,:]
df8['embedding'] = df8['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df8],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2134562496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8['embedding'] = df8['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df9 = df.loc[16001:18000,:]
df9['embedding'] = df9['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df9],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2765103186.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9['embedding'] = df9['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df10 = df.loc[18001:20000,:]
df10['embedding'] = df10['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df10],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\1908514550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10['embedding'] = df10['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df11 = df.loc[20001:22000,:]
df11['embedding'] = df11['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df11],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\3247466772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11['embedding'] = df11['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df12 = df.loc[22001:24000,:]
df12['embedding'] = df12['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df12],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\1341975618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['embedding'] = df12['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df13 = df.loc[24001:26000,:]
df13['embedding'] = df13['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df13],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\1409295408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13['embedding'] = df13['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df14 = df.loc[26001:28000,:]
df14['embedding'] = df14['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df14],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\2643146813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['embedding'] = df14['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
df15 = df.loc[28001:,:]
df15['embedding'] = df15['chunked_content'].apply(encode_text)
df_new = pd.concat([df_new,df15],ignore_index=True, axis=0)
df_new.head()
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_13864\1506314164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15['embedding'] = df15['chunked_content'].apply(encode_text)
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
# df_new.to_csv('embedding.csv')

# %%
import pandas as pd

# %%
df_emb = pd.read_csv('embedding.csv')
df_emb.drop(columns = 'Unnamed: 0' , inplace = True)
df_emb.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  ['watch any video online with open subtitle fr...
# 1  ['ah there s princess dawn and terry with the ...
# 2  ['i yumi s cell i i episode extremely polite y...
# 3  ['watch any video online with open subtitle fr...
# 4  ['watch any video online with open subtitle fr...
#
#                                            embedding
# 0  [[-0.04548948  0.10605931 -0.05575116 ... -0.0...
# 1  [[-0.0816742  -0.00562783  0.04651853 ... -0.0...
# 2  [[-1.4068541e-01 -1.5667278e-01  6.6977121e-02...
# 3  [[-0.09335469 -0.10753913  0.04193733 ...  0.0...
# 4  [[-0.08041111 -0.02626064  0.05431385 ...  0.1...

# %%
df_emb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   num              30001 non-null  int64
#  1   name             30001 non-null  object
#  2   file_content     30001 non-null  object
#  3   chunked_content  30001 non-null  object
#  4   embedding        30001 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df_emb.embedding[0]
# Out:
# '[[-0.04548948  0.10605931 -0.05575116 ... -0.03221984  0.03973673\n  -0.01685703]\n [ 0.01061917  0.11946609  0.0040393  ... -0.0344262  -0.01158409\n  -0.04801248]\n [-0.00196127  0.10313164 -0.0204013  ... -0.04394552  0.02881121\n  -0.03886633]\n ...\n [-0.02714827  0.13265875 -0.02498526 ... -0.06658785  0.00752406\n  -0.03631395]\n [-0.00024475  0.0624979  -0.02359401 ... -0.02522611  0.00748727\n  -0.03956302]\n [-0.03241341  0.00616958  0.00667954 ...  0.03616384  0.00052885\n   0.02536997]]'

# %%
embeddings = df_emb.embedding

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')
def encode_text(text):
  embedding = model.encode(text)
  return embedding

# %%
dtm = df_emb.embedding

# %%
def similarity_finder(search_query, k, model, dtm):

    # Transform the search query into a TF-IDF vector
    search_query_vector = model.encode([search_query])

    # Calculate cosine similarity between the query and the documents
    similarity_scores = cosine_similarity(search_query_vector, dtm)

    # Sort the similarity scores and get the indices of most similar documents
    similar_doc_indices = similarity_scores.argsort()[0][::-1][:min(k, len(df))]

    # Retrieve and return the most similar documents
    similar_texts = [df_emb['name'].iloc[i] for i in similar_doc_indices]
    # df = pd.DataFrame(similar_texts)
    # return df
    return similar_texts

# %%
search_query=input("Enter a Query: ")

similar_text = similarity_finder(search_query, 10, model, dtm)  # Get up to 10 most similar documents

for text in enumerate(similar_text):
    # print(dtm(idx))
    print(text)
    print()
# Out:
# Enter a Query:  peter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 search_query=input("Enter a Query: ")
# ----> 3 similar_text = similarity_finder(search_query, 10, model, dtm)  # Get up to 10 most similar documents
#       5 for text in enumerate(similar_text):
#       6     # print(dtm(idx))
#       7     print(text)
#
# Cell In[50], line 7, in similarity_finder(search_query, k, model, dtm)
#       4 search_query_vector = model.encode([search_query])
#       6 # Calculate cosine similarity between the query and the documents
# ----> 7 similarity_scores = cosine_similarity(search_query_vector, dtm)
#       9 # Sort the similarity scores and get the indices of most similar documents
#      10 similar_doc_indices = similarity_scores.argsort()[0][::-1][:min(k, len(df))]
#
# File e:\python\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File e:\python\lib\site-packages\sklearn\metrics\pairwise.py:1657, in cosine_similarity(X, Y, dense_output)
#    1613 """Compute cosine similarity between samples in X and Y.
#    1614
#    1615 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1653        [0.57..., 0.81...]])
#    1654 """
#    1655 # to avoid recursive import
# -> 1657 X, Y = check_pairwise_arrays(X, Y)
#    1659 X_normalized = normalize(X, copy=True)
#    1660 if X is Y:
#
# File e:\python\lib\site-packages\sklearn\metrics\pairwise.py:172, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     163 else:
#     164     X = check_array(
#     165         X,
#     166         accept_sparse=accept_sparse,
#    (...)
#     170         estimator=estimator,
#     171     )
# --> 172     Y = check_array(
#     173         Y,
#     174         accept_sparse=accept_sparse,
#     175         dtype=dtype,
#     176         copy=copy,
#     177         force_all_finite=force_all_finite,
#     178         estimator=estimator,
#     179     )
#     181 if precomputed:
#     182     if X.shape[1] != Y.shape[0]:
#
# File e:\python\lib\site-packages\sklearn\utils\validation.py:997, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995         array = xp.astype(array, dtype, copy=False)
#     996     else:
# --> 997         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998 except ComplexWarning as complex_warning:
#     999     raise ValueError(
#    1000         "Complex data not supported\n{}\n".format(array)
#    1001     ) from complex_warning
#
# File e:\python\lib\site-packages\sklearn\utils\_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# ValueError: could not convert string to float: '[[-0.04548948  0.10605931 -0.05575116 ... -0.03221984  0.03973673\n  -0.01685703]\n [ 0.01061917  0.11946609  0.0040393  ... -0.0344262  -0.01158409\n  -0.04801248]\n [-0.00196127  0.10313164 -0.0204013  ... -0.04394552  0.02881121\n  -0.03886633]\n ...\n [-0.02714827  0.13265875 -0.02498526 ... -0.06658785  0.00752406\n  -0.03631395]\n [-0.00024475  0.0624979  -0.02359401 ... -0.02522611  0.00748727\n  -0.03956302]\n [-0.03241341  0.00616958  0.00667954 ...  0.03616384  0.00052885\n   0.02536997]]'

# %%
# # Assuming you have already encoded your text using BERT and stored the embeddings in the 'embeddings' variable
# # Convert each embedding array to a byte string
# embedding_bytes = [embedding.tobytes() for embedding in embeddings]

# # Now, 'embedding_bytes' contains byte strings, which you can store in the SQLite database

# %%
# Assuming 'embedding' is a BERT embedding (list of floating-point numbers)
# Convert the list of floats to a string representation
embedding_str = ','.join(map(str, df_emb.embedding))

# Now, 'embedding_str' contains the embedding as a comma-separated string
# Store 'embedding_str' in the database

# %%
# Assuming 'embedding_str' is a string retrieved from the database
# Convert the string back to a list of floats
embedding = list(map(float, embedding_str.split(',')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Assuming 'embedding_str' is a string retrieved from the database
#       2 # Convert the string back to a list of floats
# ----> 3 embedding = list(map(float, embedding_str.split(',')))
#
# ValueError: could not convert string to float: '[[-0.04548948  0.10605931 -0.05575116 ... -0.03221984  0.03973673\n  -0.01685703]\n [ 0.01061917  0.11946609  0.0040393  ... -0.0344262  -0.01158409\n  -0.04801248]\n [-0.00196127  0.10313164 -0.0204013  ... -0.04394552  0.02881121\n  -0.03886633]\n ...\n [-0.02714827  0.13265875 -0.02498526 ... -0.06658785  0.00752406\n  -0.03631395]\n [-0.00024475  0.0624979  -0.02359401 ... -0.02522611  0.00748727\n  -0.03956302]\n [-0.03241341  0.00616958  0.00667954 ...  0.03616384  0.00052885\n   0.02536997]]'

# %%
import numpy as np
import re

# Assuming 'embedding_str' is a string retrieved from the database
# Parse the string representation of the embedding to extract the numbers
embedding_str = re.sub(r'[\[\]]', '', embedding_str)  # Remove square brackets
numbers = re.findall(r'-?\d+\.\d+', embedding_str)  # Extract numbers as strings

# Convert the list of number strings to floats
embedding = [float(num) for num in numbers]

# %%
len(embedding)
# Out:
# 1305216

# %%
# from sklearn.metrics.pairwise import cosine_similarity

# %%
# # Assuming 'query_embedding' is the embedding of the user's query obtained from BERT
# # Assuming 'database_embeddings' is a list of embeddings retrieved from your database

# # Calculate cosine similarity between query embedding and database embeddings
# similarities = [cosine_similarity(query_embedding, embedding) for embedding in embedding]

# # Sort the results based on cosine similarity
# sorted_results = sorted(zip(similarities, database_records), key=lambda x: x[0], reverse=True)

# # Retrieve top results (e.g., top 10)
# top_results = sorted_results[:10]

# # Display the top results to the user
# for i, (similarity, record) in enumerate(top_results, start=1):
#     print(f"Top {i}: Similarity={similarity}, Record={record}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       1 # Assuming 'query_embedding' is the embedding of the user's query obtained from BERT
#       2 # Assuming 'database_embeddings' is a list of embeddings retrieved from your database
#       3
#       4 # Calculate cosine similarity between query embedding and database embeddings
# ----> 5 similarities = [cosine_similarity(query_embedding, embedding) for embedding in embedding]
#       7 # Sort the results based on cosine similarity
#       8 sorted_results = sorted(zip(similarities, database_records), key=lambda x: x[0], reverse=True)
#
# Cell In[38], line 5, in <listcomp>(.0)
#       1 # Assuming 'query_embedding' is the embedding of the user's query obtained from BERT
#       2 # Assuming 'database_embeddings' is a list of embeddings retrieved from your database
#       3
#       4 # Calculate cosine similarity between query embedding and database embeddings
# ----> 5 similarities = [cosine_similarity(query_embedding, embedding) for embedding in embedding]
#       7 # Sort the results based on cosine similarity
#       8 sorted_results = sorted(zip(similarities, database_records), key=lambda x: x[0], reverse=True)
#
# NameError: name 'query_embedding' is not defined

# %%
# Initialize SQLite database in the specified path
db_path = 'chromadb.db'
conn = sqlite3.connect(db_path)

# Save DataFrame to SQLite
df_emb.to_sql("df_n", conn, if_exists="replace", index=False)

print(f"DataFrame from {df_emb} is successfully saved to ChromaDB using SQLite: {db_path}")
# Out:
# DataFrame from            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4      9180600                              broker.(2022).eng.1cd
# ...        ...                                                ...
# 29996  9301692                  renfroes.christmas.(1997).eng.1cd
# 29997  9301705                              whiffs.(1975).eng.1cd
# 29998  9301706                   american.murderer.(2022).eng.1cd
# 29999  9301708                             rapture.(1993).eng.1cd
# 30000  9301709                        shutterspeed.(2000).eng.1cd
#
#                                             file_content  \
# 0      watch any video online with open subtitle free...
# 1      ah there s princess dawn and terry with the bl...
# 2      i yumi s cell i i episode extremely polite yum...
# 3      watch any video online with open subtitle free...
# 4      watch any video online with open subtitle free...
# ...                                                  ...
# 29996  no audio light music light music light music l...
# 29997  api opensubtitles org is deprecated please imp...
# 29998  watch any video online with open subtitle free...
# 29999  ah thanks tracy taking an early lunch jeff yea...
# 30000  suspenseful music playing advertise your produ...
#
#                                          chunked_content  \
# 0      ['watch any video online with open subtitle fr...
# 1      ['ah there s princess dawn and terry with the ...
# 2      ['i yumi s cell i i episode extremely polite y...
# 3      ['watch any video online with open subtitle fr...
# 4      ['watch any video online with open subtitle fr...
# ...                                                  ...
# 29996  ['no audio light music light music light music...
# 29997  ['api opensubtitles org is deprecated please i...
# 29998  ['watch any video online with open subtitle fr...
# 29999  ['ah thanks tracy taking an early lunch jeff y...
# 30000  ['suspenseful music playing advertise your pro...
#
#                                                embedding
# 0      [[-0.04548948  0.10605931 -0.05575116 ... -0.0...
# 1      [[-0.0816742  -0.00562783  0.04651853 ... -0.0...
# 2      [[-1.4068541e-01 -1.5667278e-01  6.6977121e-02...
# 3      [[-0.09335469 -0.10753913  0.04193733 ...  0.0...
# 4      [[-0.08041111 -0.02626064  0.05431385 ...  0.1...
# ...                                                  ...
# 29996  [[-0.0075547  -0.01356359  0.02246689 ...  0.0...
# 29997  [[-0.06533542 -0.03443768 -0.036445   ... -0.0...
# 29998  [[-0.08249727 -0.10524355 -0.04609581 ... -0.0...
# 29999  [[-0.04223537 -0.0670395   0.0362065  ...  0.0...
# 30000  [[-0.05458867 -0.06045799  0.0300915  ... -0.0...
#
# [30001 rows x 5 columns] is successfully saved to ChromaDB using SQLite: chromadb.db

# %%
# import sqlite3

# # Specify the path to your desired location (e.g., /content/drive/MyDrive)
# db_path = 'chromadb.db'

# # Connect to the SQLite database (creates the file if it doesn't exist)
# conn = sqlite3.connect(db_path)
# conn.close()  # Close the connection

# print(f"SQLite database '{db_path}' created successfully.")
# Out:
# SQLite database 'chromadb.db' created successfully.

# %%
# import sqlite3

# try:
#     # Specify the path to your desired location (e.g., /content/drive/MyDrive)
#     db_path = r'E:\innomatics\AI ELITE 13\23.INTERNSHIP_INNO\Tasks\8_\chromadb.db'

#     # Connect to the SQLite database (creates the file if it doesn't exist)
#     conn = sqlite3.connect(db_path)
#     conn.close()  # Close the connection

#     print(f"SQLite database '{db_path}' created successfully.")
# except Exception as e:
#     print("An error occurred:", e)
# Out:
# SQLite database 'E:\innomatics\AI ELITE 13\23.INTERNSHIP_INNO\Tasks\8_\chromadb.db' created successfully.

# %%
# !pip install chromadb -U

# %%
# !pip install sqlite3==3.35.0
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3==3.35.0 (from versions: none)
# ERROR: No matching distribution found for sqlite3==3.35.0

# %%
import csv
from chromadb import ChromaClient

# Connect to ChromaDB
client = ChromaClient('localhost', 6379)

# Function to parse embeddings from CSV and store in ChromaDB
def store_embeddings_from_csv(csv_file, column_name):
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            embedding = row[column_name]
            # Store embedding in ChromaDB
            client.store_embedding(embedding)

# Specify your CSV file name and column name
csv_file = 'df_new_1.csv'
column_name = 'embedding'

# Call the function to store embeddings in ChromaDB
store_embeddings_from_csv(csv_file, column_name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 import csv
# ----> 2 from chromadb import ChromaClient
#       4 # Connect to ChromaDB
#       5 client = ChromaClient('localhost', 6379)
#
# File e:\python\lib\site-packages\chromadb\__init__.py:79
#      77             sys.modules["sqlite3"] = sys.modules.pop("pysqlite3")
#      78         else:
# ---> 79             raise RuntimeError(
#      80                 "\033Your system has an unsupported version of sqlite3. Chroma \
#      81                     requires sqlite3 >= 3.35.0.\033\n"
#      82                 "\033Please visit \
#      83                     https://docs.trychroma.com/troubleshooting#sqlite to learn how \
#      84                     to upgrade.\033"
#      85             )
#      88 def configure(**kwargs) -> None:  # type: ignore
#      89     """Override Chroma's default settings, environment variables or .env files"""
#
# RuntimeError: Your system has an unsupported version of sqlite3. Chroma                     requires sqlite3 >= 3.35.0.
# Please visit                     https://docs.trychroma.com/troubleshooting#sqlite to learn how                     to upgrade.

# %%
from chromadb import Documents, EmbeddingFunction, Embeddings

class MyEmbeddingFunction(EmbeddingFunction):
    def __call__(self, input: Documents) -> Embeddings:
        # embed the documents somehow
        return embeddings
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from chromadb import Documents, EmbeddingFunction, Embeddings
#       3 class MyEmbeddingFunction(EmbeddingFunction):
#       4     def __call__(self, input: Documents) -> Embeddings:
#       5         # embed the documents somehow
#
# File e:\python\lib\site-packages\chromadb\__init__.py:79
#      77             sys.modules["sqlite3"] = sys.modules.pop("pysqlite3")
#      78         else:
# ---> 79             raise RuntimeError(
#      80                 "\033Your system has an unsupported version of sqlite3. Chroma \
#      81                     requires sqlite3 >= 3.35.0.\033\n"
#      82                 "\033Please visit \
#      83                     https://docs.trychroma.com/troubleshooting#sqlite to learn how \
#      84                     to upgrade.\033"
#      85             )
#      88 def configure(**kwargs) -> None:  # type: ignore
#      89     """Override Chroma's default settings, environment variables or .env files"""
#
# RuntimeError: Your system has an unsupported version of sqlite3. Chroma                     requires sqlite3 >= 3.35.0.
# Please visit                     https://docs.trychroma.com/troubleshooting#sqlite to learn how                     to upgrade.

# %%
# !pip install --upgrade SomePackage

# %%
# import csv
# from chromadb import ChromaClient

# # Connect to ChromaDB
# client = ChromaClient('localhost', 6379)

# # Function to parse embeddings from CSV and store in ChromaDB
# def store_embeddings_from_csv(csv_file, column_name):
#     with open(csv_file, 'r') as file:
#         reader = csv.DictReader(file)
#         for row in reader:
#             embedding = row[column_name]
#             # Store embedding in ChromaDB
#             client.store_embedding(embedding)

# # Specify your CSV file name and column name
# csv_file = 'df_new_1.csv'
# column_name = 'embeddings'

# # Call the function to store embeddings in ChromaDB
# store_embeddings_from_csv(csv_file, column_name)

# %%
a = list(df1.embedding[0][0])
len(a)
# Out:
# 384

# %%
a = list(df1.embedding[0][1])
len(a)
# Out:
# 384

# %%
a = list(df1.embedding[1][0])
len(a)
# Out:
# 384

# %%
a = list(df1.embedding[9][1])
len(a)
# Out:
# 384

# %%
df1.tail()
# Out:
#           num                                           name  \
# 996   9185839  the.rising.s01.e06.episode.1.6.(2022).eng.1cd
# 997   9185840  the.rising.s01.e07.episode.1.7.(2022).eng.1cd
# 998   9185841  the.rising.s01.e08.episode.1.8.(2022).eng.1cd
# 999   9185844  the.rising.s01.e01.episode.1.1.(2022).eng.1cd
# 1000  9185845  the.rising.s01.e02.episode.1.2.(2022).eng.1cd
#
#                                            file_content  \
# 996   alex i he can t even see you i neve i he can n...
# 997   we found trace of blood in room seven of keato...
# 998   alex neve neve stop it neve i victoria i i you...
# 999   use the free code joinnow at www playships eu ...
# 1000  i my daughter hasn t come home i i her name s ...
#
#                                         chunked_content  \
# 996   [alex i he can t even see you i neve i he can ...
# 997   [we found trace of blood in room seven of keat...
# 998   [alex neve neve stop it neve i victoria i i yo...
# 999   [use the free code joinnow at www playships eu...
# 1000  [i my daughter hasn t come home i i her name s...
#
#                                               embedding
# 996   [[-0.08525071, -0.042879637, 0.07155471, -0.02...
# 997   [[-0.06101237, -0.0004974004, 0.004478765, -0....
# 998   [[-0.05081622, -0.03507485, 0.02548889, -0.005...
# 999   [[-0.05711211, -0.08905575, 0.029912557, -0.08...
# 1000  [[-0.028831206, -0.11441327, 0.018926123, 0.03...

# %%
df2 = df.loc[1001:2000,:]
df2.head()
# Out:
#           num                                           name  \
# 1001  9185846  the.rising.s01.e03.episode.1.3.(2022).eng.1cd
# 1002  9185847  the.rising.s01.e04.episode.1.4.(2022).eng.1cd
# 1003  9185848  the.rising.s01.e05.episode.1.5.(2022).eng.1cd
# 1004  9185849  the.rising.s01.e06.episode.1.6.(2022).eng.1cd
# 1005  9185850  the.rising.s01.e07.episode.1.7.(2022).eng.1cd
#
#                                            file_content  \
# 1001  i my daughter hasn t come home i i her name s ...
# 1002  they say you were murdered there s so much i d...
# 1003  i all i can think about is neve i i whatever s...
# 1004  i he can t even see you i i he can now i i i d...
# 1005  we found trace of blood in room seven of keato...
#
#                                         chunked_content
# 1001  [i my daughter hasn t come home i i her name s...
# 1002  [they say you were murdered there s so much i ...
# 1003  [i all i can think about is neve i i whatever ...
# 1004  [i he can t even see you i i he can now i i i ...
# 1005  [we found trace of blood in room seven of keat...

# %%
df2['embedding'] = df2['chunked_content'].apply(encode_text)
df2.head()

# %%
# Embeddings_1= model.encode(df.chunked_content)

# %%
df1.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                                      chunked_content  \
# 0  [watch any video online with open subtitle fre...
# 1  [ah there s princess dawn and terry with the b...
# 2  [i yumi s cell i i episode extremely polite yu...
# 3  [watch any video online with open subtitle fre...
# 4  [watch any video online with open subtitle fre...
#
#                                            embedding
# 0  [[-0.045489475, 0.10605931, -0.055751156, -0.0...
# 1  [[-0.0816742, -0.005627826, 0.046518527, -0.06...
# 2  [[-0.14068541, -0.15667278, 0.06697712, -0.054...
# 3  [[-0.09335469, -0.10753913, 0.041937325, -0.03...
# 4  [[-0.08041111, -0.026260642, 0.054313846, -0.0...

# %%
# BERT

# %%
# from transformers import BertTokenizer, BertModel
# import torch

# # Load pre-trained BERT tokenizer and model
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# model = BertModel.from_pretrained('bert-base-uncased')

# # Define a function to apply BERT on text data
# def apply_bert(text):
#     # Tokenize text
#     inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=128)

#     # Get BERT model outputs
#     outputs = model(**inputs)

#     # Extract relevant features from BERT output if needed
#     pooled_output = outputs.pooler_output

#     return pooled_output

# # Example usage: Apply BERT on the 'overlapping_chunks' column in your DataFrame
# df['bert_features'] = df['overlapping_chunks_file_content'].apply(lambda x: apply_bert(x))

# %%
# !pip install huggingface_hub
# python -c"from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('MY_HUGGINGFACE_TOKEN_HERE')"

# %%
# import pandas as pd

# # Assuming you already have a DataFrame named 'df'

# # Example DataFrame
# # df = pd.DataFrame({'overlapping_chunks_file_content': [[1, 2, 3], [4, 5, 6], [7, 8, 9]]})

# # Explode the list-like column
# df = df.explode('overlapping_chunks_file_content')

# # Reset index if needed
# df.reset_index(drop=True, inplace=True)

# # Now each value in the list is in its own row
# print(df)
# Out:
#            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4      9180600                              broker.(2022).eng.1cd
# ...        ...                                                ...
# 29996  9301692                  renfroes.christmas.(1997).eng.1cd
# 29997  9301705                              whiffs.(1975).eng.1cd
# 29998  9301706                   american.murderer.(2022).eng.1cd
# 29999  9301708                             rapture.(1993).eng.1cd
# 30000  9301709                        shutterspeed.(2000).eng.1cd
#
#                                             file_content  \
# 0      watch any video online with open subtitle free...
# 1      ah there s princess dawn and terry with the bl...
# 2      i yumi s cell i i episode extremely polite yum...
# 3      watch any video online with open subtitle free...
# 4      watch any video online with open subtitle free...
# ...                                                  ...
# 29996  no audio light music light music light music l...
# 29997  api opensubtitles org is deprecated please imp...
# 29998  watch any video online with open subtitle free...
# 29999  ah thanks tracy taking an early lunch jeff yea...
# 30000  suspenseful music playing advertise your produ...
#
#                          overlapping_chunks_file_content
# 0      watch any video online with open subtitle free...
# 1      ah there s princess dawn and terry with the bl...
# 2      i yumi s cell i i episode extremely polite yum...
# 3      watch any video online with open subtitle free...
# 4      watch any video online with open subtitle free...
# ...                                                  ...
# 29996  no audio light music light music light music l...
# 29997  api opensubtitles org is deprecated please imp...
# 29998  watch any video online with open subtitle free...
# 29999  ah thanks tracy taking an early lunch jeff yea...
# 30000  suspenseful music playing advertise your produ...
#
# [30001 rows x 4 columns]

# %%
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                         file_content  \
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...
#
#                      overlapping_chunks_file_content
# 0  watch any video online with open subtitle free...
# 1  ah there s princess dawn and terry with the bl...
# 2  i yumi s cell i i episode extremely polite yum...
# 3  watch any video online with open subtitle free...
# 4  watch any video online with open subtitle free...

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# import pandas as pd

# # Assuming df contains a column named 'text_column' containing the text data
# # You may need to adjust column names accordingly

# # Initialize the TF-IDF vectorizer
# tfidf_vectorizer = TfidfVectorizer()

# # Fit and transform the text data in your new column
# tfidf_matrix = tfidf_vectorizer.fit_transform(df['overlapping_chunks_file_content'])

# # Convert the TF-IDF matrix into a DataFrame
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# # Concatenate the TF-IDF DataFrame with the original DataFrame if needed
# # df = pd.concat([df, tfidf_df], axis=1)
# tfidf_df.head()

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import CountVectorizer

# # Assuming you already have a DataFrame named 'df' with the 'overlapping_chunks_file_content' column exploded

# # Example DataFrame
# # df = pd.DataFrame({'overlapping_chunks_file_content': [[1, 2, 3], [4, 5, 6], [7, 8, 9]]})

# # Convert the column into strings
# df['overlapping_chunks_file_content'] = df['overlapping_chunks_file_content'].astype(str)

# # Initialize CountVectorizer
# vectorizer = CountVectorizer()

# # Fit and transform the text data
# bow_representation = vectorizer.fit_transform(df['overlapping_chunks_file_content'])

# # Convert the BoW representation into a DataFrame
# bow_df = pd.DataFrame(bow_representation.toarray(), columns=vectorizer.get_feature_names_out())

# # Concatenate the BoW DataFrame with the original DataFrame
# df_bow = pd.concat([df, bow_df], axis=1)

# # Print the resulting DataFrame with BoW representation
# print(df_bow)

# %%
# pip install chromadb
# chroma run # run the server

# %%
import pandas as pd

# %%
dd = pd.read_csv("anu.csv")
dd.head()
# Out:
#    SubtitleID_index  subtitle_id  \
# 0                 5      9180607
# 1                 6      9180608
# 2                 9      9180694
# 3                10      9180695
# 4                11      9180696
#
#                                                 name  \
# 0                            the.myth.(2005).eng.1cd
# 1                    the.great.beauty.(2013).eng.1cd
# 2  rudrabinar.obhishaap.s02.e03.anandagarher.akhh...
# 3  rudrabinar.obhishaap.s02.e04.udara.(2022).eng.1cd
# 4  rudrabinar.obhishaap.s02.e05.saat.surer.mejaj....
#
#                                              content  \
# 0   general the princesss convoy has entered our ...
# 1   apiopensubtitlesorg is deprecated please impl...
# 2   so youre assuming that my grandma mumtaz  is ...
# 3   you know that naads have less patience  who s...
# 4   use the free code joinnow at wwwplayshipseu  ...
#
#                                     clean_text_lemma  text_length_lemma  \
# 0  general the princess convoy ha entered our rea...               4005
# 1  apiopensubtitlesorg is deprecated please imple...               9208
# 2  so youre assuming that my grandma mumtaz is ab...               1178
# 3  you know that naads have le patience who smugg...               1359
# 4  use the free code joinnow at wwwplayshipseu ge...               1017
#
#                                     final_embeddings  \
# 0  [-0.1895383894443512, 0.1699831336736679, 0.49...
# 1  [-0.13504022359848022, 0.17723196744918823, 0....
# 2  [-0.13107889890670776, 0.1428164541721344, 0.2...
# 3  [-0.08960047364234924, 0.04438433051109314, 0....
# 4  [-0.11988365650177002, 0.22249145805835724, 0....
#
#                                               chunks
# 0  ['general the princess convoy ha entered our r...
# 1  ['apiopensubtitlesorg is deprecated please imp...
# 2  ['so youre assuming that my grandma mumtaz is ...
# 3  ['you know that naads have le patience who smu...
# 4  ['use the free code joinnow at wwwplayshipseu ...

# %%
dd.final_embeddings[0]
# Out:
# '[-0.1895383894443512, 0.1699831336736679, 0.49176275730133057, -0.2788313627243042, 0.10992535948753357, -0.24937047064304352, 0.28042855858802795, 0.294384241104126, -0.006988018751144409, -0.3986762762069702, 0.023242846131324768, -0.5627375841140747, -0.2581726014614105, 0.3621686100959778, -0.30477577447891235, 0.5283430814743042, 0.1338929533958435, 0.16766758263111115, -0.2732051610946655, 0.5424041748046875, 0.34570762515068054, -0.013714262284338474, 0.1275763213634491, 0.18283139169216156, 0.5182170867919922, 0.0532633513212204, 0.20835082232952118, 0.02890435978770256, -0.07623176276683807, -0.20010600984096527, 0.40540367364883423, 0.26352956891059875, -0.1218508630990982, -0.1834336370229721, -0.10975711047649384, 0.08223343640565872, 0.09358371794223785, -0.1507522016763687, -0.06572076678276062, 0.3185150921344757, -0.6149031519889832, -0.5085240006446838, 0.12051786482334137, -0.019797172397375107, -0.24596992135047913, -0.7106381058692932, 0.21036896109580994, 0.12266439199447632, 0.15822920203208923, -0.02071494609117508, -0.31344011425971985, 0.32240092754364014, -0.19178476929664612, -0.19657330214977264, 0.5037378072738647, 0.426121324300766, -0.29975277185440063, -0.5429506301879883, -0.3994765877723694, -0.3286226987838745, 0.21307459473609924, -0.1167132556438446, 0.2920278310775757, -0.40796518325805664, 0.01524136308580637, 0.3397357165813446, 0.06975896656513214, 0.2586488425731659, -0.686347246170044, -0.3015947639942169, -0.19200879335403442, -0.08952313661575317, 0.16478127241134644, 0.127493217587471, -0.028082091361284256, -0.059950124472379684, -0.2791959047317505, 0.3313560485839844, -0.004049124661833048, -0.030053064227104187, -0.17262661457061768, 0.10534396767616272, -0.3403511941432953, 0.5865764617919922, -0.10220696032047272, -0.019728854298591614, 0.12597282230854034, 0.14552906155586243, -0.4626367390155792, 0.8637995719909668, 0.07702651619911194, -0.18512704968452454, -0.03621918335556984, -0.2384319305419922, 0.17217731475830078, -0.1694187968969345, 0.26790380477905273, 0.13949653506278992, -0.1958082765340805, 0.6442023515701294, 0.21454940736293793, -0.044456902891397476, 0.2181905210018158, -0.2082158476114273, -0.09230325371026993, -0.2419636994600296, 0.1065727174282074, 0.3719615936279297, -0.09580338001251221, 0.2596324682235718, 0.28238850831985474, -0.12275945395231247, -0.1739208996295929, -0.5049012899398804, -0.1290528029203415, -0.004245009273290634, 0.10068686306476593, -0.15053583681583405, -0.17399869859218597, 0.06369158625602722, 0.23237435519695282, -0.06144331023097038, 0.036454781889915466, 0.7645975351333618, 0.214355006814003, 0.10174901783466339, -0.22308717668056488, 0.3590396046638489, -0.06094444543123245, -0.012370054610073566, 0.13969528675079346, 0.12929190695285797, -0.19860368967056274, -0.09510369598865509, -0.19251501560211182, -0.05779678747057915, 0.003032864071428776, -0.30792587995529175, -0.4247749447822571, 0.14961037039756775, -0.017799612134695053, -0.22846809029579163, 0.29865261912345886, 0.13396358489990234, 0.10927927494049072, 0.05222782865166664, -0.42839646339416504, -0.1471262276172638, -0.14901050925254822, 0.20848600566387177, 0.006689564324915409, -0.2603958249092102, 0.02508174628019333, -0.07123667001724243, -0.5614305734634399, -0.01950075663626194, -0.26724696159362793, 0.2521359324455261, -0.09254900366067886, 0.23896916210651398, 0.14992523193359375, 0.01758451573550701, -0.18875601887702942, 0.16947023570537567, 0.06432636827230453, 0.2102695256471634, -0.22290176153182983, 0.7092457413673401, -0.14167791604995728, -0.11030471324920654, 0.03743657097220421, 0.03684128075838089, 0.6801767349243164, 0.057156726717948914, 0.22270141541957855, 0.027677753940224648, -0.028402961790561676, -0.0652647465467453, -0.10887069255113602, 0.0838523656129837, -0.396353155374527, 0.40951383113861084, -0.12109756469726562, 0.43803083896636963, 0.14135228097438812, -0.1543775200843811, 0.1007494181394577, -0.047613244503736496, 0.15963658 ...

# %%
# Initialize SQLite database in the specified path
db_path = 'chromadb_2.db'
conn = sqlite3.connect(db_path)

# Save DataFrame to SQLite
df_emb.to_sql("dd", conn, if_exists="replace", index=False)

print(f"DataFrame from {df_emb} is successfully saved to ChromaDB using SQLite: {db_path}")
# Out:
# DataFrame from            num                                               name  \
# 0      9180533                         the.message.(1976).eng.1cd
# 1      9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2      9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3      9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4      9180600                              broker.(2022).eng.1cd
# ...        ...                                                ...
# 29996  9301692                  renfroes.christmas.(1997).eng.1cd
# 29997  9301705                              whiffs.(1975).eng.1cd
# 29998  9301706                   american.murderer.(2022).eng.1cd
# 29999  9301708                             rapture.(1993).eng.1cd
# 30000  9301709                        shutterspeed.(2000).eng.1cd
#
#                                             file_content  \
# 0      watch any video online with open subtitle free...
# 1      ah there s princess dawn and terry with the bl...
# 2      i yumi s cell i i episode extremely polite yum...
# 3      watch any video online with open subtitle free...
# 4      watch any video online with open subtitle free...
# ...                                                  ...
# 29996  no audio light music light music light music l...
# 29997  api opensubtitles org is deprecated please imp...
# 29998  watch any video online with open subtitle free...
# 29999  ah thanks tracy taking an early lunch jeff yea...
# 30000  suspenseful music playing advertise your produ...
#
#                                          chunked_content  \
# 0      ['watch any video online with open subtitle fr...
# 1      ['ah there s princess dawn and terry with the ...
# 2      ['i yumi s cell i i episode extremely polite y...
# 3      ['watch any video online with open subtitle fr...
# 4      ['watch any video online with open subtitle fr...
# ...                                                  ...
# 29996  ['no audio light music light music light music...
# 29997  ['api opensubtitles org is deprecated please i...
# 29998  ['watch any video online with open subtitle fr...
# 29999  ['ah thanks tracy taking an early lunch jeff y...
# 30000  ['suspenseful music playing advertise your pro...
#
#                                                embedding
# 0      [[-0.04548948  0.10605931 -0.05575116 ... -0.0...
# 1      [[-0.0816742  -0.00562783  0.04651853 ... -0.0...
# 2      [[-1.4068541e-01 -1.5667278e-01  6.6977121e-02...
# 3      [[-0.09335469 -0.10753913  0.04193733 ...  0.0...
# 4      [[-0.08041111 -0.02626064  0.05431385 ...  0.1...
# ...                                                  ...
# 29996  [[-0.0075547  -0.01356359  0.02246689 ...  0.0...
# 29997  [[-0.06533542 -0.03443768 -0.036445   ... -0.0...
# 29998  [[-0.08249727 -0.10524355 -0.04609581 ... -0.0...
# 29999  [[-0.04223537 -0.0670395   0.0362065  ...  0.0...
# 30000  [[-0.05458867 -0.06045799  0.0300915  ... -0.0...
#
# [30001 rows x 5 columns] is successfully saved to ChromaDB using SQLite: chromadb_2.db

# %%
import sqlite3
import numpy as np

# Connect to SQLite database
CHROMA_DB_FILE = "subtitle_embeddings5.db"
chroma_conn = sqlite3.connect(CHROMA_DB_FILE)
chroma_c = chroma_conn.cursor()

# Create table with columns 'num', 'name', 'clean_content', and 'content_embeddings'
chroma_c.execute('''
    CREATE TABLE embeddings (
        num INTEGER,
        name TEXT,
        clean_content TEXT,
        content_embeddings BLOB
    )
''')

# Function to insert data into the SQLite database
def insert_data(row):
    num = row['num']
    name = row['name']
    clean_content = row['clean_content']
    content_embeddings = row['content_embeddings']

    content_embeddings_array = np.array(content_embeddings)
    
    # Convert the numpy array to binary format using tobytes()
    content_embeddings_blob = sqlite3.Binary(content_embeddings_array.tobytes())
    
    # Insert data into the database
    chroma_c.execute('''
        INSERT INTO embeddings (num, name, clean_content, content_embeddings)
        VALUES (?, ?, ?, ?)
    ''', (num, name, clean_content, content_embeddings_blob))

# Iterate through each row in df and insert data
for idx, row in dd.iterrows():
    insert_data(row)

# Commit the changes and close the connection
chroma_conn.commit()
chroma_conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[65], line 10
#       7 chroma_c = chroma_conn.cursor()
#       9 # Create table with columns 'num', 'name', 'clean_content', and 'content_embeddings'
# ---> 10 chroma_c.execute('''
#      11     CREATE TABLE embeddings (
#      12         num INTEGER,
#      13         name TEXT,
#      14         clean_content TEXT,
#      15         content_embeddings BLOB
#      16     )
#      17 ''')
#      19 # Function to insert data into the SQLite database
#      20 def insert_data(row):
#
# OperationalError: table embeddings already exists

# %%
import PIL
print('PIL',PIL.__version__)
# Out:
# PIL 10.1.0

# %%
import pandas as pd

# %%
dg = pd.read_csv('df_e.csv')
dg.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dg = pd.read_csv('df_e.csv')
#       2 dg.head()
#
# File e:\python\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File e:\python\lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File e:\python\lib\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File e:\python\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory
